# %% [markdown]
# # Applied Stats - Thống kê Ứng dụng

# %% [markdown]
# ## Phase 1: Phân tích dữ liệu:

# %% [markdown]
# ### 1) Import các thư viện cần thiết:
# - `pandas` (pd): Thư viện này được sử dụng để xử lý và phân tích dữ liệu. Nó cung cấp các đối tượng như DataFrame và Series để làm việc với dữ liệu dạng bảng.
# - `pyscipy.io.arff`: Đây là một module trong thư viện SciPy, được sử dụng để đọc và ghi dữ liệu trong định dạng ARFF (Attribute-Relation File Format), một định dạng phổ biến trong lĩnh vực khoa học dữ liệu.
# - `numpy` (np): Thư viện này cung cấp hỗ trợ cho mảng và ma trận lớn, cùng với một bộ sưu tập lớn các hàm toán học để thao tác với các mảng này.
# - `matplotlib.pyplot` (plt): Đây là một thư viện vẽ đồ thị 2D trong Python, cho phép bạn vẽ nhiều loại đồ thị như đồ thị dạng line, bar, scatter, histogram, etc.
# - `warnings`: Ngăn chặn việc hiển thị các cảnh báo từ Python hoặc các thư viện khác. Giúp cho output trông gọn hơn.
# - `seaborn` (sns): Vẽ biểu đồ

# %%
import pandas as pd
from scipy.io import arff
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

plt.style.use('ggplot')

# %% [markdown]
# ### 2) Đọc file dataset và biểu diễn dạng bảng

# %% [markdown]
# a) VPN Dataset:

# %%
data = arff.loadarff('data/train_test/Merge-A1-A2-ARFF/Merged_VPN_15s.arff')
vpn15s = pd.DataFrame(data[0])
vpn15s.head()
# Out:
#      duration  total_fiat  total_biat   min_fiat   min_biat     max_fiat  \
# 0  11552328.0    201874.0    201138.0  5834505.0  5833801.0  2888057.750
# 1   6082219.0      9457.0     48233.0  5092501.0  4885150.0  1520554.750
# 2  13466300.0      1392.0     40153.0  6138030.0  6136317.0  1346630.000
# 3  13764893.0    200273.0    200191.0  5797648.0  5591580.0  2752964.400
# 4  12306851.0       967.0       950.0  5430769.0  5426974.0  1538356.375
#
#        max_biat     mean_fiat     mean_biat  flowPktsPerSecond  ...  \
# 0  2.888055e+06  2.881316e+06  2.881293e+06           0.865626  ...
# 1  1.481219e+06  2.404067e+06  2.291113e+06           1.644137  ...
# 2  1.330034e+06  1.883529e+06  1.886693e+06           1.633708  ...
# 3  2.752954e+06  2.362064e+06  2.339293e+06           0.871783  ...
# 4  1.344278e+06  2.048348e+06  1.923066e+06           1.543856  ...
#
#     std_flowiat  min_active   mean_active  max_active    std_active  \
# 0  2.329982e+06   5717726.0  5.776116e+06   5834505.0  8.257522e+04
# 1  1.588967e+06   4885236.0  4.885236e+06   4885236.0  0.000000e+00
# 2  1.390557e+06   1506391.0  3.263053e+06   7010161.0  2.536930e+06
# 3  2.016971e+06   1026809.0  3.441206e+06   5591669.0  2.104913e+06
# 4  1.440157e+06   2905845.0  4.032853e+06   6038944.0  1.741742e+06
#
#     min_idle     mean_idle   max_idle      std_idle  class1
# 0  4876225.0  5.354964e+06  5833704.0  6.770399e+05  b'VPN'
# 1  4885150.0  4.885150e+06  4885150.0  0.000000e+00  b'VPN'
# 2  1306411.0  2.893614e+06  5930227.0  2.092512e+06  b'VPN'
# 3  1026695.0  3.339582e+06  5591580.0  2.098630e+06  b'VPN'
# 4  2488259.0  3.620838e+06  5220546.0  1.424782e+06  b'VPN'
#
# [5 rows x 24 columns]

# %% [markdown]
# b) No-VPN Dataset:

# %%
data = arff.loadarff('data/train_test/Merge-A1-A2-ARFF/Merged_Non_VPN_15s.arff')
novpn15s = pd.DataFrame(data[0])
novpn15s.head()
# Out:
#      duration  total_fiat  total_biat   min_fiat   min_biat       max_fiat  \
# 0   9368711.0        16.0         4.0  1564818.0  1549373.0  190205.285714
# 1   7340238.0        18.0         4.0  1567554.0  1527893.0  165686.977273
# 2   4644225.0        29.0        15.0  1270547.0  1079974.0  165865.178571
# 3   4978735.0        19.0         8.0  2492050.0  2457286.0  239543.250000
# 4  11838189.0        19.0        10.0  3094089.0  3093543.0  243766.500000
#
#         max_biat      mean_fiat      mean_biat  flowPktsPerSecond  ...  \
# 0  203290.456522  389822.391917  370323.719754          10.353612  ...
# 1  186914.846154  317267.548742  304370.651301          11.580006  ...
# 2  195302.130435  329473.126261  300492.588227          11.412022  ...
# 3  276596.388889  612435.304238  628339.573544           8.034169  ...
# 4  295954.725000  599721.781709  625632.703972           7.602514  ...
#
#      std_flowiat  min_active   mean_active  max_active    std_active  \
# 0  267600.198443   1871488.0  1.983656e+06   2195089.0  1.832197e+05
# 1  221462.862028   1491627.0  3.572433e+06   5653239.0  2.942704e+06
# 2  217475.425246   1758922.0  1.758922e+06   1758922.0  0.000000e+00
# 3  436959.716436   1710925.0  2.382905e+06   3054885.0  9.503232e+05
# 4  436129.639296   1747431.0  2.400446e+06   3240696.0  6.232744e+05
#
#     min_idle  mean_idle   max_idle       std_idle      class1
# 0  1234883.0  1420565.0  1523088.0  161096.539275  b'Non-VPN'
# 1  1131498.0  1324636.0  1517774.0  273138.379008  b'Non-VPN'
# 2  1079974.0  1079974.0  1079974.0       0.000000  b'Non-VPN'
# 3  1346073.0  1894031.5  2441990.0  774930.342317  b'Non-VPN'
# 4  1394455.0  1983227.0  3042717.0  725987.829075  b'Non-VPN'
#
# [5 rows x 24 columns]

# %% [markdown]
# ### 3) Nhận định cấu trúc dữ liệu

# %% [markdown]
# ##### - Đầu tiên, chúng ta sẽ chạy lệnh `describe()` để lấy thông tin đã được thống kê lại từ các cột trong dataset:

# %% [markdown]
# - count: Số lượng quan sát (entries) không bị thiếu trong dataset.
# - mean: Giá trị trung bình của dữ liệu.
# - std: Độ lệch chuẩn, đo lường mức độ phân tán của dữ liệu so với giá trị trung bình.
# - min: Giá trị nhỏ nhất trong dataset.
# - 25%: Phân vị thứ 25, còn được gọi là phân vị thứ nhất hoặc Q1, là giá trị mà 25% dữ liệu nằm dưới nó.
# - 50%: Phân vị thứ 50, còn được gọi là trung vị, là giá trị chia dataset làm đôi.
# - 75%: Phân vị thứ 75, còn được gọi là phân vị thứ ba hoặc Q3, là giá trị mà 75% dữ liệu nằm dưới nó.
# - max: Giá trị lớn nhất trong dataset.

# %% [markdown]
# ##### - Sau đó chúng ta sẽ chạy lệnh `columns` để in ra thông tin các cột trong bảng dữ liệu

# %% [markdown]
# a) VPN Dataset:

# %%
vpn15s.describe()
# Out:
#            duration    total_fiat    total_biat      min_fiat      min_biat  \
# count  1.958600e+04  1.958600e+04  1.958600e+04  1.958600e+04  1.958600e+04
# mean   8.758938e+06  4.474766e+06  4.595373e+06  2.007788e+06  2.126265e+06
# std    1.302758e+07  6.543341e+06  9.819971e+06  4.439081e+06  8.582671e+06
# min    0.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00
# 25%
# min   -1.000000e+00 -1.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.806297e+04  1.350449e+04  2.227739e+03  1.562233e+03
# 50%    3.801700e+04  3.960300e+04  1.915968e+04  1.920725e+04
# 75%    9.615907e+05  9.614904e+05  3.865185e+05  3.421008e+05
# max    3.035957e+08  1.322552e+08  2.150000e+08  6.030000e+07
#
#        flowPktsPerSecond  ...  mean_flowiat   std_flowiat    min_active  \
# count       17930.000000  ...  1.793000e+04  1.793000e+04  1.793000e+04
# mean         1653.957849  ...  4.016421e+05  1.019776e+06  3.396296e+06
# std         18999.356109  ...  1.597533e+06  4.324698e+06  1.497528e+07
# min             0.000000  ...  0.000000e+00  0.000000e+00 -1.000000e+00
# 25%             4.319775  ...  9.547843e+03  4.910198e+03 -1.000000e+00
# 50%            39.060593  ...  1.862487e+04  1.220884e+04 -1.000000e+00
# 75%           104.625823  ...  2.237895e+05  5.644617e+05  2.018821e+06
# max       1000000.000000  ...  6.070000e+07  1.360000e+08  3.036184e+08
#
#         mean_active    max_active    std_active      min_idle     mean_idle  \
# count  1.793000e+04  1.793000e+04  1.793000e+04  1.793000e+04  1.793000e+04
# mean   3.791869e+06  4.251225e+06  5.179756e+05  3.222947e+06  3.583473e+06
# std    1.510689e+07  1.552807e+07  2.925502e+06  1.490323e+07  1.503542e+07
# min    0.000000e+00 -1.000000e+00  0.000000e+00 -1.000000e+00  0.000000e+00
# 25%    0.000000e+00 -1.000000e+00  0.000000e+00 -1.000000e+00  0.000000e+00
# 50%    0.000000e+00 -1.000000e+00  0.000000e+00 -1.000000e+00  0.000000e+00
# 75%    3.610281e+06  4.992390e+06  0.000000e+00  1.750417e+06  2.954255e+06
# max    3.040000e+08  3.036184e+08  8.960000e+07  3.035957e+08  3.040000e+08
#
#            max_idle      std_idle
# count  1.793000e+04  1.793000e+04
# mean   4.001298e+06  4.765593e+05
# std    1.544355e+07  2.901666e+06
# min   -1.000000e+00  0.000000e+00
# 25%   -1.000000e+00  0.000000e+00
# 50%   -1.000000e+00  0.000000e+00
# 75%    3.907977e+06  0.000000e+00
# max    3.035957e+08  8.980000e+07
#
# [8 rows x 23 columns]

# %%
novpn15s.columns
# Out:
# Index(['duration', 'total_fiat', 'total_biat', 'min_fiat', 'min_biat',
#        'max_fiat', 'max_biat', 'mean_fiat', 'mean_biat', 'flowPktsPerSecond',
#        'flowBytesPerSecond', 'min_flowiat', 'max_flowiat', 'mean_flowiat',
#        'std_flowiat', 'min_active', 'mean_active', 'max_active', 'std_active',
#        'min_idle', 'mean_idle', 'max_idle', 'std_idle', 'class1'],
#       dtype='object')

# %% [markdown]
# c) Tìm hiểu thêm về dataset này:

# %%
vpn15s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19586 entries, 0 to 19585
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   duration            19586 non-null  float64
#  1   total_fiat          19586 non-null  float64
#  2   total_biat          19586 non-null  float64
#  3   min_fiat            19586 non-null  float64
#  4   min_biat            19586 non-null  float64
#  5   max_fiat            19586 non-null  float64
#  6   max_biat            19586 non-null  float64
#  7   mean_fiat           19586 non-null  float64
#  8   mean_biat           19586 non-null  float64
#  9   flowPktsPerSecond   19586 non-null  float64
#  10  flowBytesPerSecond  19586 non-null  float64
#  11  min_flowiat         19586 non-null  float64
#  12  max_flowiat         19586 non-null  float64
#  13  mean_flowiat        19586 non-null  float64
#  14  std_flowiat         19586 non-null  float64
#  15  min_active          19586 non-null  float64
#  16  mean_active         19586 non-null  float64
#  17  max_active          19586 non-null  float64
#  18  std_active          19586 non-null  float64
#  19  min_idle            19586 non-null  float64
#  20  mean_idle           19586 non-null  float64
#  21  max_idle            19586 non-null  float64
#  22  std_idle            19586 non-null  float64
#  23  class1              19586 non-null  object
# dtypes: float64(23), object(1)
# memory usage: 3.6+ MB

# %%
novpn15s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17930 entries, 0 to 17929
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   duration            17930 non-null  float64
#  1   total_fiat          17930 non-null  float64
#  2   total_biat          17930 non-null  float64
#  3   min_fiat            17930 non-null  float64
#  4   min_biat            17930 non-null  float64
#  5   max_fiat            17930 non-null  float64
#  6   max_biat            17930 non-null  float64
#  7   mean_fiat           17930 non-null  float64
#  8   mean_biat           17930 non-null  float64
#  9   flowPktsPerSecond   17930 non-null  float64
#  10  flowBytesPerSecond  17930 non-null  float64
#  11  min_flowiat         17930 non-null  float64
#  12  max_flowiat         17930 non-null  float64
#  13  mean_flowiat        17930 non-null  float64
#  14  std_flowiat         17930 non-null  float64
#  15  min_active          17930 non-null  float64
#  16  mean_active         17930 non-null  float64
#  17  max_active          17930 non-null  float64
#  18  std_active          17930 non-null  float64
#  19  min_idle            17930 non-null  float64
#  20  mean_idle           17930 non-null  float64
#  21  max_idle            17930 non-null  float64
#  22  std_idle            17930 non-null  float64
#  23  class1              17930 non-null  object
# dtypes: float64(23), object(1)
# memory usage: 3.3+ MB

# %% [markdown]
# ##### - Giải thích qua về các cột trong dataset này:

# %% [markdown]
# - `duration`: Đây là thời gian tồn tại của một kết nối mạng.<br>

# %% [markdown]
# - `total_fiat` and `total_biat`: Đây là tổng thời gian chờ giữa các gói tin (FIAT và BIAT) theo hướng đi (từ nguồn đến đích) và hướng về (từ đích về nguồn) tương ứng.<br>

# %% [markdown]
# - `class1`: Đây có thể là nhãn hoặc phân loại được gán cho luồng mạng dựa trên các tiêu chí nhất định, như loại lưu lượng hoặc ứng dụng tạo ra lưu lượng (hiện tại chưa chắc chắn).<br>

# %% [markdown]
# - `min_idle`, `mean_idle`, `max_idle`, `std_idle`: Đây là thời gian nhàn rỗi tối thiểu, trung bình, tối đa, và độ lệch chuẩn trong một luồng mạng. Thời gian nhàn rỗi là khoảng thời gian khi luồng không truyền dữ liệu.<br>

# %% [markdown]
# - `min_active`, `mean_active`, `max_active`, `std_active`: Đây là thời gian hoạt động tối thiểu, trung bình, tối đa, và độ lệch chuẩn trong một luồng mạng. Thời gian hoạt động là khoảng thời gian khi luồng đang truyền dữ liệu một cách tích cực.<br>

# %% [markdown]
# - `min_flowiat`, `max_flowiat`, `mean_flowiat`, `std_flowiat`: Đây là thời gian chờ giữa các gói tin tối thiểu, tối đa, trung bình, và độ lệch chuẩn trong một luồng mạng.<br>

# %% [markdown]
# - `flowBytesPerSecond`: Đây là tốc độ dữ liệu được gửi hoặc nhận trong một luồng mạng, được đo bằng byte mỗi giây.<br>

# %% [markdown]
# - `flowPktsPerSecond`: Đây là tốc độ gói tin được gửi hoặc nhận trong một luồng mạng, được đo bằng gói tin mỗi giây.<br>

# %% [markdown]
# - `min_fiat`, `min_biat`, `max_fiat`, `max_biat`, `mean_fiat`, `mean_biat`: Đây là thời gian chờ giữa các gói tin tối thiểu, tối đa, và trung bình (trung bình cộng) theo hướng đi và hướng về tương ứng.<br>

# %% [markdown]
# ## Phase 2: Xử lý dữ liệu

# %% [markdown]
# ### 1) Khám phá dữ liệu ban đầu

# %% [markdown]
# - Khám phá dữ liệu ban đầu, kiểm tra xem có dữ liệu nào bị thiếu không

# %%
vpn15s.isna().sum()
# Out:
# duration              0
# total_fiat            0
# total_biat            0
# min_fiat              0
# min_biat              0
# max_fiat              0
# max_biat              0
# mean_fiat             0
# mean_biat             0
# flowPktsPerSecond     0
# flowBytesPerSecond    0
# min_flowiat           0
# max_flowiat           0
# mean_flowiat          0
# std_flowiat           0
# min_active            0
# mean_active           0
# max_active            0
# std_active            0
# min_idle              0
# mean_idle             0
# max_idle              0
# std_idle              0
# class1                0
# dtype: int64

# %%
novpn15s.isna().sum()
# Out:
# duration              0
# total_fiat            0
# total_biat            0
# min_fiat              0
# min_biat              0
# max_fiat              0
# max_biat              0
# mean_fiat             0
# mean_biat             0
# flowPktsPerSecond     0
# flowBytesPerSecond    0
# min_flowiat           0
# max_flowiat           0
# mean_flowiat          0
# std_flowiat           0
# min_active            0
# mean_active           0
# max_active            0
# std_active            0
# min_idle              0
# mean_idle             0
# max_idle              0
# std_idle              0
# class1                0
# dtype: int64

# %% [markdown]
# - Để dễ nhìn hơn thì chúng ta sẽ mô hình hóa dưới dạng bar chart sử dụng thư viện `missingno` (msno)

# %%
import missingno as msno

msno.bar(vpn15s)
plt.show()
msno.bar(novpn15s)
plt.show()

# %% [markdown]
# ### 2) Làm sạch dữ liệu:
#
# - Xử lí các giá trị bị thiếu (nếu có).
# - Loại bỏ hoặc điền (fill) các giá trị cho các hàng/cột bị thiếu đó.

# %%
# Giả sử có giá trị nào bị thiếu, bạn có thể xử lý như sau:
# vpn15s = vpn15s.fillna(method='ffill')
# novpn15s = novpn15s.fillna(method='ffill')

# %% [markdown]
# ### 3) Phân tích dữ liệu
#
# - Tính toán các thống kê dữ liệu mô tả (như `mean`, `median`, `std`, ...) và so sánh giữa hai nhóm VPN và No-VPN

# %%
# Thống kê mô tả
vpn_stats = vpn15s.describe()
novpn_stats = novpn15s.describe()

# So sánh thống kê mô tả
stats_comparison = pd.concat([vpn_stats, novpn_stats], axis=1, keys=['VPN', 'No-VPN'])
print(stats_comparison)
# Out:
#                 VPN                                                          \
#            duration    total_fiat    total_biat      min_fiat      min_biat
# count  1.958600e+04  1.958600e+04  1.958600e+04  1.958600e+04  1.958600e+04
# mean   8.758938e+06  4.474766e+06  4.595373e+06  2.007788e+06  2.126265e+06
# std    1.302758e+07  6.543341e+06  9.819971e+06  4.439081e+06  8.582671e+06
# min    0.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00
# 25%    4.134140e+05  2.300000e+01  9.000000e+00  2.300000e+01  9.000000e+00
# 50%    1.007813e+07  1.398195e+05  3.103050e+04  2.820750e+04  2.307300e+04
# 75%    1.449381e+07  1.003937e+07  1.003937e+07  1.459740e+06  1.386965e+06
# max    6.014050e+08  1.919551e+08  6.011851e+08  1.913169e+08  6.001097e+08
#
#                                                                \
#            max_fiat      max_biat     mean_fiat     mean_biat
# count  1.958600e+04  1.958600e+04  1.958600e+04  1.958600e+04
# mean   2.164579e+06  2.275340e+06  9.350471e+05  9.278479e+05
# std    4.421619e+06  8.582888e+06  2.432452e+06  2.846763e+06
# min   -1.000000e+00 -1.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.989497e+04  1.371830e+04  6.090555e+02  0.000000e+00
# 50%    2.754475e+05  2.468693e+05  8.546726e+04  6.144076e+04
# 75%    2.010671e+06  2.004238e+06  7.094170e+05  6.419573e+05
# max    1.913169e+08  6.001097e+08  7.230000e+07  9.800000e+07
#
#                          ...        No-VPN                              \
#       flowPktsPerSecond  ...  mean_flowiat   std_flowiat    min_active
# count      19586.000000  ...  1.793000e+04  1.793000e+04  1.793000e+04
# mean        2458.106292  ...  4.016421e+05  1.019776e+06  3.396296e+06
# std        19213.573691  ...  1.597533e+06  4.324698e+06  1.497528e+07
# min            0.000000  ...  0.000000e+00  0.000000e+00 -1.000000e+00
# 25%            2.215682  ...  9.547843e+03  4.910198e+03 -1.000000e+00
# 50%            8.541311  ...  1.862487e+04  1.220884e+04 -1.000000e+00
# 75%           79.218379  ...  2.237895e+05  5.644617e+05  2.018821e+06
# max       666666.666667  ...  6.070000e+07  1.360000e+08  3.036184e+08
#
#                                                                              \
#         mean_active    max_active    std_active      min_idle     mean_idle
# count  1.793000e+04  1.793000e+04  1.793000e+04  1.793000e+04  1.793000e+04
# mean   3.791869e+06  4.251225e+06  5.179756e+05  3.222947e+06  3.583473e+06
# std    1.510689e+07  1.552807e+07  2.925502e+06  1.490323e+07  1.503542e+07
# min    0.000000e+00 -1.000000e+00  0.000000e+00 -1.000000e+00  0.000000e+00
# 25%    0.000000e+00 -1.000000e+00  0.000000e+00 -1.000000e+00  0.000000e+00
# 50%    0.000000e+00 -1.000000e+00  0.000000e+00 -1.000000e+00  0.000000e+00
# 75%    3.610281e+06  4.992390e+06  0.000000e+00  1.750417e+06  2.954255e+06
# max    3.040000e+08  3.036184e+08  8.960000e+07  3.035957e+08  3.040000e+08
#
#
#            max_idle      std_idle
# count  1.793000e+04  1.793000e+04
# mean   4.001298e+06  4.765593e+05
# std    1.544355e+07  2.901666e+06
# min   -1.000000e+00  0.000000e+00
# 25%   -1.000000e+00  0.000000e+00
# 50%   -1.000000e+00  0.000000e+00
# 75%    3.907977e+06  0.000000e+00
# max    3.035957e+08  8.980000e+07
#
# [8 rows x 46 columns]

# %% [markdown]
# - Vẽ biểu đồ phân phối cho mỗi cột để so sánh giữa VPN và No-VPN

# %%
# Vẽ biểu đồ phân phối cho mỗi cột
import matplotlib.pyplot as plt
import seaborn as sns

# Số lượng biểu đồ bạn muốn hiển thị trên mỗi hàng và cột
num_rows = 6
num_cols = 4

# Tạo figure và axes
fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 30))

# Duyệt qua mỗi cột và vẽ biểu đồ
for i, column in enumerate(vpn15s.columns):
    if column != 'class1':  # Loại trừ cột 'class1' vì không rõ cột này để làm gì
        row = i // num_cols
        col = i % num_cols
        sns.distplot(vpn15s[column], ax=axes[row, col], label='VPN')
        sns.distplot(novpn15s[column], ax=axes[row, col], label='No-VPN')
        axes[row, col].set_title(f'Phân phối của {column}')
        axes[row, col].legend()

# Điều chỉnh layout để không có chồng chéo
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### - Phân tích biểu đồ phân phối:
# - Dữ liệu phân phối lệch nhiều về bên phải ở cả 2 dataset VPN và No-VPN.
# - Ta có thể thấy rằng:
#     + VPN: Phân phối nhiều hơn ở cột `duration`, `total_biat`, `max_biat`, `mean_biat`, `flowPktsPerSecond`, `min_flowiat`, `max_flowiat`, `min_active`, `mean_active`, `max_active`, `std_active`, `mean_idle`, `max_idle`, `std_idle`.
#     + Trong khi No-VPN sẽ phân phối nhiều hơn ở những cột còn lại.
# - Kết luận:
#     + VPN: Các cột như `duration`, `total_biat`, và `mean_biat` có phân phối nhiều hơn có thể liên quan đến đặc điểm của lưu lượng VPN, chẳng hạn như thời gian kết nối dài hơn hoặc thời gian giữa các gói tin lớn hơn.
#     + No-VPN: Các cột có phân phối nhiều hơn trong No-VPN có thể phản ánh đặc điểm của lưu lượng internet thông thường mà không qua VPN.
#
# <br>

# %% [markdown]
# - Thực hiện kiểm định thống kê cho mỗi cột để xác định sự khác biệt có ý nghĩa.

# %%
from scipy.stats import ttest_ind
from IPython.display import display

# Giả sử vpn15s và novpn15s là DataFrames của bạn chứa dữ liệu VPN và no-VPN

# Kiểm định t-test cho mỗi cột
results = []
for column in vpn15s.columns:
    if column != 'class1':  # Loại trừ cột 'class1'
        t_stat, p_val = ttest_ind(vpn15s[column].dropna(), novpn15s[column].dropna())
        results.append((column, t_stat, p_val))

# Chuyển kết quả thành DataFrame để dễ dàng xem và phân tích
results_df = pd.DataFrame(results, columns=['Column', 'T-statistic', 'P-value'])

# Hiển thị DataFrame
print(results_df)
# Out:
#                 Column  T-statistic       P-value
# 0             duration   -14.575463  5.444986e-48
# 1           total_fiat    -8.165441  3.301724e-16
# 2           total_biat    -0.676530  4.987085e-01
# 3             min_fiat     1.203779  2.286824e-01
# 4             min_biat    10.895266  1.335488e-27
# 5             max_fiat     0.140955  8.879059e-01
# 6             max_biat    10.928756  9.249624e-28
# 7            mean_fiat     0.570219  5.685325e-01
# 8            mean_biat    12.949013  2.875159e-38
# 9    flowPktsPerSecond     4.070956  4.691656e-05
# 10  flowBytesPerSecond    -6.033835  1.616105e-09
# 11         min_flowiat     5.542702  2.998392e-08
# 12         max_flowiat    -3.299120  9.707862e-04
# 13        mean_flowiat     9.932719  3.204456e-23
# 14         std_flowiat     0.799665  4.239100e-01
# 15          min_active    -1.965844  4.932401e-02
# 16         mean_active    -2.134824  3.278187e-02
# 17          max_active    -2.118043  3.417796e-02
# 18          std_active    -1.019195  3.081171e-01
# 19            min_idle    -3.322612  8.926422e-04
# 20           mean_idle    -3.553603  3.804595e-04
# 21            max_idle    -3.584411  3.382683e-04
# 22            std_idle    -1.558184  1.191981e-01

# %% [markdown]
# ##### - Phân tích kết quả kiểm định thống kê:
# - Giá trị `T-statistic`: Giá trị cao (về âm hay dương) cho thấy sự khác biệt lớn giữa 2 nhóm.
# - Giá trị `P-value`: Một P-value thấp (thường dưới 0.05) cho thấy sự khác biệt có ý nghĩa thống kê. Trong trường hợp trên, các cột như `duration`, `total_fiat`, `min_fiat`, v.v., có P-value rất thấp, cho thấy sự khác biệt đáng kể giữa VPN và No-VPN.
#     + VD: `duration` có `T-statistic` là -10.306134 và `P-value` là 7.700747e−25 có nghĩa rằng có sự khác biệt rất lớn về thời gian kết nối (duration) giữa VPN và No-VPN
#
# <br>

# %% [markdown]
# - Tính toán ma trận tương quan cho toàn bộ cột và so sánh giữa hai nhóm.

# %%
# Loại bỏ cột 'class1' hoặc bất kỳ cột nào chứa chuỗi
vpn_numeric = vpn15s.select_dtypes(include=[np.number])
novpn_numeric = novpn15s.select_dtypes(include=[np.number])

# Ma trận tương quan cho VPN
vpn_corr = vpn_numeric.corr()

# Ma trận tương quan cho no-VPN
novpn_corr = novpn_numeric.corr()

# Thiết lập kích thước của biểu đồ
plt.figure(figsize=(30, 10))

# So sánh ma trận tương quan
corr_comparison = pd.concat([vpn_corr, novpn_corr], axis=1, keys=['VPN', 'No-VPN'])
sns.heatmap(corr_comparison, annot=True, fmt=".2f", annot_kws={'size': 8})
plt.show()

# %% [markdown]
# ##### - Trong ma trận tương quan, cần chú ý:
# - Đường chéo sẽ luôn bằng 1 vì một giá trị sẽ luôn có quan hệ chặt chẽ với chính nó.
# - Màu càng tối thì quan hệ càng yếu, màu càng sáng thì quan hệ với nhau càng chặt chẽ.
#
# <br>

# %% [markdown]
# - Mình sẽ remove đi một vài giá trị không sử dụng đến để quá trình phân tích trở nên đơn giản hơn:

# %%
to_drop = ['class1']

vpn15s.drop(to_drop, inplace = True, axis = 1)
novpn15s.drop(to_drop, inplace = True, axis = 1)

vpn15s.head(21)
# Out:
#       duration  total_fiat  total_biat   min_fiat   min_biat      max_fiat  \
# 0   11552328.0    201874.0    201138.0  5834505.0  5833801.0  2.888058e+06
# 1    6082219.0      9457.0     48233.0  5092501.0  4885150.0  1.520555e+06
# 2   13466300.0      1392.0     40153.0  6138030.0  6136317.0  1.346630e+06
# 3   13764893.0    200273.0    200191.0  5797648.0  5591580.0  2.752964e+06
# 4   12306851.0       967.0       950.0  5430769.0  5426974.0  1.538356e+06
# 5   11566360.0       218.0     38404.0  5852512.0  5646046.0  2.839842e+06
.000000e+00        -1.0  0.000000e+00        -1.0  0.000000e+00
# 20  0.000000e+00        -1.0  0.000000e+00        -1.0  0.000000e+00
#
# [21 rows x 23 columns]

# %% [markdown]
# ##### - Kiểm tra lại mức độ chặt chẽ:

# %%
plt.figure(figsize = (18, 12))

vpn_corr = vpn15s.corr()
novpn_corr = novpn15s.corr()

# Thiết lập kích thước của biểu đồ
plt.figure(figsize=(30, 10))

# So sánh ma trận tương quan
corr_comparison = pd.concat([vpn_corr, novpn_corr], axis=1, keys=['VPN', 'No-VPN'])
sns.heatmap(corr_comparison, annot=True, fmt=".2f", annot_kws={'size': 8})
plt.show()

# %%
vpn15s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19586 entries, 0 to 19585
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   duration            19586 non-null  float64
#  1   total_fiat          19586 non-null  float64
#  2   total_biat          19586 non-null  float64
#  3   min_fiat            19586 non-null  float64
#  4   min_biat            19586 non-null  float64
#  5   max_fiat            19586 non-null  float64
#  6   max_biat            19586 non-null  float64
#  7   mean_fiat           19586 non-null  float64
#  8   mean_biat           19586 non-null  float64
#  9   flowPktsPerSecond   19586 non-null  float64
#  10  flowBytesPerSecond  19586 non-null  float64
#  11  min_flowiat         19586 non-null  float64
#  12  max_flowiat         19586 non-null  float64
#  13  mean_flowiat        19586 non-null  float64
#  14  std_flowiat         19586 non-null  float64
#  15  min_active          19586 non-null  float64
#  16  mean_active         19586 non-null  float64
#  17  max_active          19586 non-null  float64
#  18  std_active          19586 non-null  float64
#  19  min_idle            19586 non-null  float64
#  20  mean_idle           19586 non-null  float64
#  21  max_idle            19586 non-null  float64
#  22  std_idle            19586 non-null  float64
# dtypes: float64(23)
# memory usage: 3.4 MB

# %%
novpn15s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17930 entries, 0 to 17929
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   duration            17930 non-null  float64
#  1   total_fiat          17930 non-null  float64
#  2   total_biat          17930 non-null  float64
#  3   min_fiat            17930 non-null  float64
#  4   min_biat            17930 non-null  float64
#  5   max_fiat            17930 non-null  float64
#  6   max_biat            17930 non-null  float64
#  7   mean_fiat           17930 non-null  float64
#  8   mean_biat           17930 non-null  float64
#  9   flowPktsPerSecond   17930 non-null  float64
#  10  flowBytesPerSecond  17930 non-null  float64
#  11  min_flowiat         17930 non-null  float64
#  12  max_flowiat         17930 non-null  float64
#  13  mean_flowiat        17930 non-null  float64
#  14  std_flowiat         17930 non-null  float64
#  15  min_active          17930 non-null  float64
#  16  mean_active         17930 non-null  float64
#  17  max_active          17930 non-null  float64
#  18  std_active          17930 non-null  float64
#  19  min_idle            17930 non-null  float64
#  20  mean_idle           17930 non-null  float64
#  21  max_idle            17930 non-null  float64
#  22  std_idle            17930 non-null  float64
# dtypes: float64(23)
# memory usage: 3.1 MB

# %% [markdown]
# - Chuyển lại dataset đã được làm sạch về dạng csv để chuẩn bị cho việc train model

# %%
vpn15s.to_csv('./clean_data/vpn15s_cleaned.csv', index=False)
novpn15s.to_csv('./clean_data/novpn15s_cleaned.csv', index=False)

# %% [markdown]
# ## Phase 3: Huấn luyện Model

# %% [markdown]
# #### Ở đây, với 2 dataset đã được xử lý, mình sẽ thử train thuật toán K-Nearest Neighbors và Decision Tree để xác định model nào hiệu quả hơn trong việc phân loại

# %% [markdown]
# ##### K-Nearest Neighbors:

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

#read data
yes_df = pd.read_csv('clean_data/vpn15s_cleaned.csv')
no_df = pd.read_csv('clean_data/novpn15s_cleaned.csv')


# Create labels for dataset
yes_df['label'] = 1  
no_df['label'] = 0   

#combine 2 dataset
combined_df = pd.concat([yes_df, no_df], ignore_index=True)

# separate features and specify target variable
X = combined_df.drop(columns=['label'])
y = combined_df['label']

#split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#specifying the category and numerical columns
cate_cols=[cname for cname in X_train.columns if X_train[cname].dtype=="object"]
nume_cols=[cname for cname in X_train.columns if X_train[cname].dtype in ['int64','float64']]

# preprocessing to deal with different type of datas
# Preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy='constant')

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, nume_cols),
        ('cat', categorical_transformer, cate_cols)
    ])


# train the model
knn = Pipeline(steps=[('preprocessor', preprocessor),
                    ('model', KNeighborsClassifier(n_neighbors=5))
                             ])
knn.fit(X_train, y_train)

# predicting some value
y_pred = knn.predict(X_test)

# evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# print the report
print(classification_report(y_test, y_pred))

# view some first prediction
print("First few predictions:", y_pred[:5])
print("First few actual values:", y_test[:5].values)

# Generate matrix
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No VPN', 'VPN'], yticklabels=['No VPN', 'VPN'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy: 0.81
#               precision    recall  f1-score   support
#
#            0       0.81      0.79      0.80      5378
#            1       0.81      0.83      0.82      5877
#
#     accuracy                           0.81     11255
#    macro avg       0.81      0.81      0.81     11255
# weighted avg       0.81      0.81      0.81     11255
#
# First few predictions: [1 0 1 1 0]
# First few actual values: [0 0 1 0 0]

# %% [markdown]
# ##### Decision Tree

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

#read data
yes_df = pd.read_csv('clean_data/vpn15s_cleaned.csv')
no_df = pd.read_csv('clean_data/novpn15s_cleaned.csv')


# Create labels for dataset
yes_df['label'] = 1  
no_df['label'] = 0   

#combine 2 dataset
combined_df = pd.concat([yes_df, no_df], ignore_index=True)

# separate features and specify target variable
X = combined_df.drop(columns=['label'])
y = combined_df['label']

#split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#specifying the category and numerical columns
cate_cols=[cname for cname in X_train.columns if X_train[cname].dtype=="object"]
nume_cols=[cname for cname in X_train.columns if X_train[cname].dtype in ['int64','float64']]

# preprocessing to deal with different type of datas
# Preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy='constant')

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, nume_cols),
        ('cat', categorical_transformer, cate_cols)
    ])


# train the model
knn = Pipeline(steps=[('preprocessor', preprocessor),
                    ('model', DecisionTreeClassifier(max_leaf_nodes=1000))
                             ])
knn.fit(X_train, y_train)

# predicting some value
y_pred = knn.predict(X_test)

# evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# print the report
print(classification_report(y_test, y_pred))

# view some first prediction
print("First few predictions:", y_pred[:5])
print("First few actual values:", y_test[:5].values)

# Generate matrix
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No VPN', 'VPN'], yticklabels=['No VPN', 'VPN'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy: 0.92
#               precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91      5378
#            1       0.91      0.93      0.92      5877
#
#     accuracy                           0.92     11255
#    macro avg       0.92      0.92      0.92     11255
# weighted avg       0.92      0.92      0.92     11255
#
# First few predictions: [0 0 1 0 0]
# First few actual values: [0 0 1 0 0]

# %% [markdown]
# ##### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegressionCV
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

#read data
yes_df = pd.read_csv('clean_data/vpn15s_cleaned.csv')
no_df = pd.read_csv('clean_data/novpn15s_cleaned.csv')


# Create labels for dataset
yes_df['label'] = 1  
no_df['label'] = 0   

#combine 2 dataset
combined_df = pd.concat([yes_df, no_df], ignore_index=True)

# separate features and specify target variable
X = combined_df.drop(columns=['label'])
y = combined_df['label']

#split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#specifying the category and numerical columns
cate_cols=[cname for cname in X_train.columns if X_train[cname].dtype=="object"]
nume_cols=[cname for cname in X_train.columns if X_train[cname].dtype in ['int64','float64']]

# preprocessing to deal with different type of datas
# Preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy='constant')

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, nume_cols),
        ('cat', categorical_transformer, cate_cols)
    ])
cpu_cores=8
lr=Pipeline(steps=[('preprocessor', preprocessor),
                    ('model', LogisticRegressionCV(n_jobs=cpu_cores,solver='liblinear'))
                             ])
lr.fit(X_train,y_train)

# predicting some value
y_pred = lr.predict(X_test)

# evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# print the report
print(classification_report(y_test, y_pred))

# view some first prediction
print("First few predictions:", y_pred[:5])
print("First few actual values:", y_test[:5].values)

# Generate matrix
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No VPN', 'VPN'], yticklabels=['No VPN', 'VPN'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy: 0.62
#               precision    recall  f1-score   support
#
#            0       0.64      0.48      0.55      5378
#            1       0.61      0.75      0.67      5877
#
#     accuracy                           0.62     11255
#    macro avg       0.62      0.61      0.61     11255
# weighted avg       0.62      0.62      0.61     11255
#
# First few predictions: [0 1 0 1 0]
# First few actual values: [0 0 1 0 0]

# %% [markdown]
# ##### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

#read data
yes_df = pd.read_csv('clean_data/vpn15s_cleaned.csv')
no_df = pd.read_csv('clean_data/novpn15s_cleaned.csv')


# Create labels for dataset
yes_df['label'] = 1  
no_df['label'] = 0   

#combine 2 dataset
combined_df = pd.concat([yes_df, no_df], ignore_index=True)

# separate features and specify target variable
X = combined_df.drop(columns=['label'])
y = combined_df['label']

#split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#specifying the category and numerical columns
cate_cols=[cname for cname in X_train.columns if X_train[cname].dtype=="object"]
nume_cols=[cname for cname in X_train.columns if X_train[cname].dtype in ['int64','float64']]

# preprocessing to deal with different type of datas
# Preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy='constant')

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, nume_cols),
        ('cat', categorical_transformer, cate_cols)
    ])
cpu_cores=8
# Train the model based on best optimized args
rf=Pipeline(steps=[('preprocessor', preprocessor),
                    ('model', RandomForestClassifier(n_jobs=cpu_cores,n_estimators=500))
                             ])
rf.fit(X_train,y_train)

# predicting some value
y_pred = rf.predict(X_test)

# evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# print the report
print(classification_report(y_test, y_pred))

# view some first prediction
print("First few predictions:", y_pred[:5])
print("First few actual values:", y_test[:5].values)

# Generate matrix
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No VPN', 'VPN'], yticklabels=['No VPN', 'VPN'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy: 0.93
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.93      5378
#            1       0.92      0.95      0.93      5877
#
#     accuracy                           0.93     11255
#    macro avg       0.93      0.93      0.93     11255
# weighted avg       0.93      0.93      0.93     11255
#
# First few predictions: [0 0 1 0 0]
# First few actual values: [0 0 1 0 0]

# %% [markdown]
# XG BOOST

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, FunctionTransformer
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from xgboost.sklearn import XGBClassifier
import matplotlib.pyplot as plt
import seaborn as sns

def main():
    # 1. Đọc dữ liệu
    yes_df = pd.read_csv('clean_data/vpn60s_cleaned.csv')
    no_df  = pd.read_csv('clean_data/novpn60s_cleaned.csv')

    # 2. Gán nhãn
    yes_df['label'] = 1
    no_df['label']  = 0

    # 3. Kết hợp dữ liệu
    combined_df = pd.concat([yes_df, no_df], ignore_index=True)

    # 4. Tách features và target
    X = combined_df.drop(columns=['label'])
    y = combined_df['label']

    # 5. Chia train/test (giữ tỷ lệ nhãn với stratify)
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.3, random_state=42, stratify=y
    )

    # 6. Xác định cột số và cột phân loại
    cate_cols = [c for c in X_train.columns if X_train[c].dtype == "object"]
    nume_cols = [c for c in X_train.columns if X_train[c].dtype in ['int64', 'float64']]

    # 7. Tạo transformers cho preprocessing
    numerical_transformer = SimpleImputer(strategy='constant')
    categorical_transformer = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
    ])

    # 8. Kết hợp preprocessing với ColumnTransformer
    preprocessor = ColumnTransformer(transformers=[
        ('num', numerical_transformer, nume_cols),
        ('cat', categorical_transformer, cate_cols)
    ])

    # 9. Ép dtype về float32 (không bắt buộc với CPU, nhưng giữ để thống nhất)
    to_float32 = FunctionTransformer(lambda X: X.astype(np.float32))

    # 10. Định nghĩa XGBClassifier chạy trên CPU
    xgb_clf = XGBClassifier(
        tree_method='hist',           # histogram trên CPU
        predictor='cpu_predictor',    # predictor trên CPU
        use_label_encoder=False,
        eval_metric='logloss',
        random_state=42
    )

    # 11. Xây dựng pipeline hoàn chỉnh
    pipeline = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('cast', to_float32),
        ('model', xgb_clf)
    ])

    # 12. Huấn luyện model
    pipeline.fit(X_train, y_train)

    # 13. Dự đoán
    y_pred = pipeline.predict(X_test)

    # 14. Đánh giá
    accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy: {accuracy:.2f}\n")
    print("Classification Report:")
    print(classification_report(y_test, y_pred))
    print("First few predictions:", y_pred[:5])
    print("First few actual values:", y_test.values[:5])

    # 15. Vẽ ma trận nhầm lẫn
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(
        cm, annot=True, fmt='d', cmap='Blues',
        xticklabels=['No VPN', 'VPN'],
        yticklabels=['No VPN', 'VPN']
    )
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()

if __name__ == '__main__':
    main()
# Out:
# Accuracy: 0.95
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95      5148
#            1       0.93      0.94      0.94      4161
#
#     accuracy                           0.95      9309
#    macro avg       0.94      0.95      0.94      9309
# weighted avg       0.95      0.95      0.95      9309
#
# First few predictions: [0 1 1 1 1]
# First few actual values: [0 1 1 1 1]

# %% [markdown]
# # PHASE 4: Evaluate Model

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, roc_curve, auc, confusion_matrix
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# Define the evaluation function
def evaluate_model(model, X_train, y_train, X_test, y_test, model_name="Model", cv=5):
    """
    Function to evaluate a model with Cross-Validation, ROC/AUC, and other metrics.
    """
    print(f"\n=== Đánh giá {model_name} ===")
    
    # 1. Cross-Validation (5-fold)
    cv_scores = cross_val_score(model, X_train, y_train, cv=cv, scoring='accuracy')
    print("Cross-Validation Scores (5-fold):", cv_scores)
    print("Mean CV Accuracy:", cv_scores.mean())
    print("Standard Deviation:", cv_scores.std())
    
    # 2. Predict on test set
    y_pred = model.predict(X_test)
    
    # 3. Evaluate accuracy on test set
    accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy on Test Set: {accuracy:.2f}")
    
    # 4. Print classification report
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred))
    
    # 5. View some first predictions
    print("First few predictions:", y_pred[:5])
    print("First few actual values:", y_test[:5].values)
    
    # 6. Calculate ROC Curve and AUC Score (if model supports predict_proba)
    if hasattr(model, 'predict_proba'):
        y_pred_prob = model.predict_proba(X_test)[:, 1]
        fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
        roc_auc = auc(fpr, tpr)
        
        plt.figure(figsize=(8, 6))
        plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
        plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title(f'Receiver Operating Characteristic (ROC) Curve - {model_name}')
        plt.legend(loc="lower right")
        plt.show()
        
        print(f"AUC Score: {roc_auc:.2f}")
    else:
        print("Model does not support predict_proba, cannot calculate ROC/AUC.")
    
    # 7. Plot Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No VPN', 'VPN'], yticklabels=['No VPN', 'VPN'])
    plt.title(f'Confusion Matrix - {model_name}')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()

# %%
# Read data
yes_df = pd.read_csv('clean_data/vpn15s_cleaned.csv')
no_df = pd.read_csv('clean_data/novpn15s_cleaned.csv')

# Create labels for dataset
yes_df['label'] = 1  
no_df['label'] = 0   

# Combine 2 datasets
combined_df = pd.concat([yes_df, no_df], ignore_index=True)

# Check for invalid values (NaN, inf)
print("Checking for invalid values:")
print("NaN values:\n", combined_df.isna().sum())
print("Infinite values:\n", combined_df.select_dtypes(include=[np.number]).apply(lambda x: np.isinf(x)).sum())

# Replace infinite values with NaN and then handle them
combined_df = combined_df.replace([np.inf, -np.inf], np.nan)

# Separate features and target variable
X = combined_df.drop(columns=['label'])
y = combined_df['label']

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Specify category and numerical columns
cate_cols = [cname for cname in X_train.columns if X_train[cname].dtype == "object"]
nume_cols = [cname for cname in X_train.columns if X_train[cname].dtype in ['int64', 'float64']]

# Preprocessing for numerical data
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant')),
    ('scaler', StandardScaler())  # Scaling for numerical columns
])

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, nume_cols),
        ('cat', categorical_transformer, cate_cols)
    ])

cpu_cores = 8
# Out:
# Checking for invalid values:
# NaN values:
#  duration              0
# total_fiat            0
# total_biat            0
# min_fiat              0
# min_biat              0
# max_fiat              0
# max_biat              0
# mean_fiat             0
# mean_biat             0
# flowPktsPerSecond     0
# flowBytesPerSecond    0
# min_flowiat           0
# max_flowiat           0
# mean_flowiat          0
# std_flowiat           0
# min_active            0
# mean_active           0
# max_active            0
# std_active            0
# min_idle              0
# mean_idle             0
# max_idle              0
# std_idle              0
# label                 0
# dtype: int64
# Infinite values:
#  duration              0
# total_fiat            0
# total_biat            0
# min_fiat              0
# min_biat              0
# max_fiat              0
# max_biat              0
# mean_fiat             0
# mean_biat             0
# flowPktsPerSecond     0
# flowBytesPerSecond    0
# min_flowiat           0
# max_flowiat           0
# mean_flowiat          0
# std_flowiat           0
# min_active            0
# mean_active           0
# max_active            0
# std_active            0
# min_idle              0
# mean_idle             0
# max_idle              0
# std_idle              0
# label                 0
# dtype: int64

# %% [markdown]
# Random Forest

# %%
# Random Forest
rf = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', RandomForestClassifier(n_jobs=cpu_cores, n_estimators=500))
])

# Train the model
rf.fit(X_train, y_train)

# Evaluate the model
evaluate_model(rf, X_train, y_train, X_test, y_test, model_name="Random Forest")
# Out:
# === Đánh giá Random Forest ===
# Cross-Validation Scores (5-fold): [0.92632781 0.92003046 0.92612338 0.92326733 0.92288652]
# Mean CV Accuracy: 0.9237271009972325
# Standard Deviation: 0.002327614759894566
# Accuracy on Test Set: 0.93
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93      5378
#            1       0.92      0.95      0.93      5877
#
#     accuracy                           0.93     11255
#    macro avg       0.93      0.93      0.93     11255
# weighted avg       0.93      0.93      0.93     11255
#
# First few predictions: [0 0 1 0 0]
# First few actual values: [0 0 1 0 0]
# AUC Score: 0.98

# %% [markdown]
# K-Nearest Neighbors

# %%
# KNN
knn = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', KNeighborsClassifier(n_neighbors=5))
])

# Train the model
knn.fit(X_train, y_train)

# Evaluate the model
evaluate_model(knn, X_train, y_train, X_test, y_test, model_name="KNN")
# Out:
# === Đánh giá KNN ===
# Cross-Validation Scores (5-fold): [0.81819912 0.82444783 0.81626047 0.81321401 0.8124524 ]
# Mean CV Accuracy: 0.8169147677408869
# Standard Deviation: 0.004299604791145732
# Accuracy on Test Set: 0.82
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.80      0.81      5378
#            1       0.82      0.85      0.83      5877
#
#     accuracy                           0.82     11255
#    macro avg       0.82      0.82      0.82     11255
# weighted avg       0.82      0.82      0.82     11255
#
# First few predictions: [1 0 1 1 0]
# First few actual values: [0 0 1 0 0]
# AUC Score: 0.91

# %% [markdown]
# Decision Tree

# %%
# Decision Tree
dt = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', DecisionTreeClassifier(random_state=42))
])

# Train the model
dt.fit(X_train, y_train)

# Evaluate the model
evaluate_model(dt, X_train, y_train, X_test, y_test, model_name="Decision Tree")
# Out:
# === Đánh giá Decision Tree ===
# Cross-Validation Scores (5-fold): [0.9053874  0.90498858 0.91507997 0.90575019 0.90365575]
# Mean CV Accuracy: 0.9069723767175294
# Standard Deviation: 0.004115201985839951
# Accuracy on Test Set: 0.92
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91      5378
#            1       0.91      0.93      0.92      5877
#
#     accuracy                           0.92     11255
#    macro avg       0.92      0.92      0.92     11255
# weighted avg       0.92      0.92      0.92     11255
#
# First few predictions: [0 0 1 0 0]
# First few actual values: [0 0 1 0 0]
# AUC Score: 0.93

# %% [markdown]
# Logistic Regression

# %%
# Logistic Regression
lr = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', LogisticRegression(max_iter=1000, random_state=42))
])

# Train the model
lr.fit(X_train, y_train)

# Evaluate the model
evaluate_model(lr, X_train, y_train, X_test, y_test, model_name="Logistic Regression")
# Out:
# === Đánh giá Logistic Regression ===
# Cross-Validation Scores (5-fold): [0.61298306 0.61214775 0.62376238 0.61919269 0.60491241]
# Mean CV Accuracy: 0.61459965791861
# Standard Deviation: 0.006442348323537273
# Accuracy on Test Set: 0.62
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.65      0.43      0.52      5378
#            1       0.60      0.78      0.68      5877
#
#     accuracy                           0.62     11255
#    macro avg       0.62      0.61      0.60     11255
# weighted avg       0.62      0.62      0.60     11255
#
# First few predictions: [1 1 0 1 0]
# First few actual values: [0 0 1 0 0]
# AUC Score: 0.66

# %% [markdown]
# XG BOOST

# %%
from xgboost import XGBClassifier

xgb = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', XGBClassifier(n_estimators=100, random_state=42))
])

xgb.fit(X_train, y_train)

evaluate_model(xgb, X_train, y_train, X_test, y_test, model_name="XGBoost")
# Out:
# === Đánh giá XGBoost ===
# Cross-Validation Scores (5-fold): [0.92689891 0.92840823 0.92936024 0.92555217 0.92231531]
# Mean CV Accuracy: 0.9265069726231948
# Standard Deviation: 0.0024654100007737508
# Accuracy on Test Set: 0.94
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93      5378
#            1       0.93      0.95      0.94      5877
#
#     accuracy                           0.94     11255
#    macro avg       0.94      0.93      0.94     11255
# weighted avg       0.94      0.94      0.94     11255
#
# First few predictions: [0 0 1 0 0]
# First few actual values: [0 0 1 0 0]
# AUC Score: 0.99

# %% [markdown]
# ### Kết luận:
#
# - KNN: Mô hình này có độ chính xác khá cao (0.82) và sự cân bằng giữa precision và recall cho cả hai lớp, cho thấy khả năng phân loại tốt. Tuy nhiên, KNN có thể không phải là lựa chọn tối ưu nếu kích thước dữ liệu lớn do độ phức tạp tính toán cao và thời gian dự đoán chậm.
# - Decision Tree: Với độ chính xác 0.92, mô hình này cho thấy khả năng phân biệt tốt giữa VPN và No VPN. Cây quyết định cũng dễ diễn giải và triển khai, nhưng có thể dễ bị overfitting nếu không được cắt tỉa đúng cách.
# - Logistic Regression: Mặc dù có độ chính xác thấp nhất (0.62), logistic regression là mô hình đơn giản và nhanh chóng trong việc huấn luyện và dự đoán. Tuy nhiên, kết quả cho thấy mô hình này có xu hướng dự đoán ‘VPN’ nhiều hơn, có thể không phù hợp cho việc điều chỉnh băng thông mạng một cách chính xác.
# - Random Forest: Đây là mô hình có hiệu suất cao nhất với độ chính xác 0.93 và sự cân bằng giữa precision và recall. Random Forest là sự kết hợp của nhiều cây quyết định, giúp giảm thiểu nguy cơ overfitting và tăng cường độ tin cậy của dự đoán.
# - XGBoost: Với độ chính xác 0.94, mô hình này đạt hiệu suất tương đương với Random Forest. Nhờ kỹ thuật boosting và khả năng xử lý dữ liệu thiếu, XGBoost tỏ ra mạnh mẽ, linh hoạt và ít bị overfitting hơn so với Decision Tree đơn lẻ. Thêm vào đó, XGBoost hỗ trợ các công cụ diễn giải như feature importance và SHAP, rất hữu ích trong việc kiểm tra mô hình. Với sự kết hợp giữa hiệu năng cao và tốc độ huấn luyện nhanh, XGBoost là một lựa chọn lý tưởng trong các hệ thống phát hiện VPN theo thời gian thực.
#
#
#
# ##### -> Kết luận: XG Boost là mô hình phù hợp nhất cho mục tiêu của nhóm (phân loại VPN/No-VPN để điều chỉnh băng thông mạng) với hiệu suất cao và khả năng phân loại chính xác nhất.
