# %% [markdown]
# # Applied Stats - Thống kê Ứng dụng

# %% [markdown]
# ## Phrase 1: Phân tích dữ liệu:

# %% [markdown]
# ### 1) Import các thư viện cần thiết:
# - `pandas` (pd): Thư viện này được sử dụng để xử lý và phân tích dữ liệu. Nó cung cấp các đối tượng như DataFrame và Series để làm việc với dữ liệu dạng bảng.
# - `pyscipy.io.arff`: Đây là một module trong thư viện SciPy, được sử dụng để đọc và ghi dữ liệu trong định dạng ARFF (Attribute-Relation File Format), một định dạng phổ biến trong lĩnh vực khoa học dữ liệu.
# - `numpy` (np): Thư viện này cung cấp hỗ trợ cho mảng và ma trận lớn, cùng với một bộ sưu tập lớn các hàm toán học để thao tác với các mảng này.
# - `matplotlib.pyplot` (plt): Đây là một thư viện vẽ đồ thị 2D trong Python, cho phép bạn vẽ nhiều loại đồ thị như đồ thị dạng line, bar, scatter, histogram, etc.
# - `warnings`: Ngăn chặn việc hiển thị các cảnh báo từ Python hoặc các thư viện khác. Giúp cho output trông gọn hơn.
# - `seaborn` (sns): Vẽ biểu đồ

# %%
import pandas as pd
from scipy.io import arff
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

plt.style.use('ggplot')

# %% [markdown]
# ### 2) Đọc file dataset và biểu diễn dạng bảng

# %% [markdown]
# a) VPN Dataset:

# %%
data = arff.loadarff('data/Scenario-A2-ARFF/TimeBasedFeatures-Dataset-120s-VPN.arff')
vpn120s = pd.DataFrame(data[0])
vpn120s.head()
# Out:
#       duration   total_fiat   total_biat  min_fiat  min_biat    max_fiat  \
# 0  119364082.0  119364082.0  119338343.0       9.0      17.0  58714597.0
# 1   93952224.0   93736153.0   93738835.0       6.0       7.0  45211965.0
# 2   73934090.0   73802530.0   73804692.0       3.0      14.0  27749148.0
# 3   42933658.0   42803851.0   42933658.0       0.0       0.0   5957694.0
# 4     270207.0     203681.0     244006.0      15.0      10.0     27147.0
#
#      max_biat     mean_fiat     mean_biat  flowPktsPerSecond  ...  \
# 0  58776480.0  32702.488219  20131.299426          80.258649  ...
# 1  45220727.0  37645.041365  28319.889728          61.754791  ...
# 2  27746116.0  55117.647498  25189.314676          57.767668  ...
# 3   5958561.0  31706.556296  16055.967838          93.772583  ...
# 4     66572.0    593.822157    363.104167        3763.781101  ...
#
#      std_flowiat  min_active  mean_active  max_active    std_active  \
# 0  845678.238767  58776675.0  59700000.00  60561891.0  1.262338e+06
# 1  835567.164239  45211965.0  46900000.00  48524188.0  2.342095e+06
# 2  518176.184990   1498361.0   9157562.25  27923646.0  9.267157e+06
# 3  162363.675416   1630161.0   5265231.00  11355159.0  3.133671e+06
# 4    2648.293598        -1.0         0.00        -1.0  0.000000e+00
#
#      min_idle     mean_idle    max_idle      std_idle           class1
# 0  58343493.0  5.850000e+07  58714597.0  2.624102e+05  b'VPN-BROWSING'
# 1  44997633.0  4.500000e+07  45006375.0  6.181527e+03  b'VPN-BROWSING'
# 2   1115996.0  7.350662e+06  27617038.0  1.010000e+07  b'VPN-BROWSING'
# 3   1308911.0  3.334210e+06   5828435.0  1.382747e+06  b'VPN-BROWSING'
# 4        -1.0  0.000000e+00        -1.0  0.000000e+00  b'VPN-BROWSING'
#
# [5 rows x 24 columns]

# %% [markdown]
# b) No-VPN Dataset:

# %%
data = arff.loadarff('data/Scenario-A2-ARFF/TimeBasedFeatures-Dataset-120s-NO-VPN.arff')
novpn120s = pd.DataFrame(data[0])
novpn120s.head()
# Out:
#       duration   total_fiat   total_biat  min_fiat  min_biat     max_fiat  \
# 0  119994459.0  119994459.0  119970125.0       0.0       0.0    1399330.0
# 1  143704195.0  143704195.0   42106019.0       0.0       0.0  101572528.0
# 2  119994980.0  119994980.0  119966891.0       7.0       0.0     819852.0
# 3  119292282.0  119292282.0  119260024.0       3.0       0.0     912990.0
# 4  119772966.0  119772917.0  119772939.0       4.0       0.0    2894671.0
#
#     max_biat     mean_fiat    mean_biat  flowPktsPerSecond  ...  \
# 0  1211310.0   2348.136257   513.267526        2373.792943  ...
# 1   854818.0   6986.105737   636.898837         603.204381  ...
# 2   819602.0  10201.919742  2341.411304         525.030297  ...
# 3   866900.0  11947.148923  3354.712349         381.726288  ...
# 4  2923147.0  18210.873803  3644.280989         329.331412  ...
#
#      std_flowiat   min_active  mean_active   max_active    std_active  \
# 0    9107.759178    1753114.0   11300000.0   39438693.0  1.600000e+07
# 1  345078.175888  143704195.0  144000000.0  143704195.0  0.000000e+00
# 2   17736.017265         -1.0          0.0         -1.0  0.000000e+00
# 3   24218.472201         -1.0          0.0         -1.0  0.000000e+00
# 4   31326.437353    2210292.0    8688035.0   15165778.0  9.160912e+06
#
#       min_idle    mean_idle     max_idle       std_idle       class1
# 0    1014624.0    1139537.6    1208289.0   74997.385381  b'BROWSING'
# 1  101572528.0  102000000.0  101572528.0       0.000000  b'BROWSING'
# 2         -1.0          0.0         -1.0       0.000000  b'BROWSING'
# 3         -1.0          0.0         -1.0       0.000000  b'BROWSING'
# 4    1799762.0    2347216.5    2894671.0  774217.578682  b'BROWSING'
#
# [5 rows x 24 columns]

# %% [markdown]
# ### 3) Nhận định cấu trúc dữ liệu

# %% [markdown]
# ##### - Đầu tiên, chúng ta sẽ chạy lệnh `describe()` để lấy thông tin đã được thống kê lại từ các cột trong dataset:

# %% [markdown]
# - count: Số lượng quan sát (entries) không bị thiếu trong dataset.
# - mean: Giá trị trung bình của dữ liệu.
# - std: Độ lệch chuẩn, đo lường mức độ phân tán của dữ liệu so với giá trị trung bình.
# - min: Giá trị nhỏ nhất trong dataset.
# - 25%: Phân vị thứ 25, còn được gọi là phân vị thứ nhất hoặc Q1, là giá trị mà 25% dữ liệu nằm dưới nó.
# - 50%: Phân vị thứ 50, còn được gọi là trung vị, là giá trị chia dataset làm đôi.
# - 75%: Phân vị thứ 75, còn được gọi là phân vị thứ ba hoặc Q3, là giá trị mà 75% dữ liệu nằm dưới nó.
# - max: Giá trị lớn nhất trong dataset.

# %% [markdown]
# ##### - Sau đó chúng ta sẽ chạy lệnh `columns` để in ra thông tin các cột trong bảng dữ liệu

# %% [markdown]
# a) VPN Dataset:

# %%
vpn120s.describe()
# Out:
#            duration    total_fiat    total_biat      min_fiat      min_biat  \
# count
#
#            max_fiat      max_biat     mean_fiat     mean_biat  \
# count  5.151000e+03  5.151000e+03  5.151000e+03  5.151000e+03
# mean   2.045334e+07  1.696148e+07  7.657249e+06  6.821238e+06
# std    3.620206e+07  2.424019e+07  1.636485e+07  1.515139e+07
# min   -1.000000e+00 -1.000000e+00  0.000000e+00  0.000000e+00
# 25%    3.446950e+04  2.717450e+04  1.166752e+04  3.273078e+03
# 50%    1.403821e+06  1.274730e+06  1.964546e+05  1.603255e+05
# 75%    4.197700e+07  3.000558e+07  6.937913e+06  6.021583e+06
# max    4.417303e+08  1.322552e+08  1.520000e+08  1.190000e+08
#
#        flowPktsPerSecond  ...  mean_flowiat   std_flowiat    min_active  \
# count        5151.000000  ...  5.151000e+03  5.151000e+03  5.151000e+03
# mean         2357.320297  ...  3.283806e+06  7.160425e+06  1.578281e+07
# std         24975.977796  ...  6.346622e+06  1.293992e+07  3.499111e+07
# min             0.000000  ...  0.000000e+00  0.000000e+00 -1.000000e+00
# 25%             0.255202  ...  9.861980e+03  7.035706e+03 -1.000000e+00
# 50%             2.096373  ...  2.911828e+05  9.497327e+05  1.663298e+06
# 75%            96.883388  ...  3.526639e+06  1.040000e+07  1.464846e+07
# max       1000000.000000  ...  6.070000e+07  1.430000e+08  4.420073e+08
#
#         mean_active    max_active    std_active      min_idle     mean_idle  \
# count  5.151000e+03  5.151000e+03  5.151000e+03  5.151000e+03  5.151000e+03
# mean   1.894104e+07  2.267081e+07  3.640134e+06  1.550653e+07  1.856391e+07
# std    3.515323e+07  3.704655e+07  9.542981e+06  3.480966e+07  3.498430e+07
# min    0.000000e+00 -1.000000e+00  0.000000e+00 -1.000000e+00  0.000000e+00
# 25%    0.000000e+00 -1.000000e+00  0.000000e+00 -1.000000e+00  0.000000e+00
# 50%    4.913739e+06  7.994498e+06  0.000000e+00  1.359206e+06  4.079993e+06
# 75%    2.810000e+07  4.505602e+07  1.160392e+06  1.460718e+07  2.640000e+07
# max    4.420000e+08  4.420073e+08  1.400000e+08  4.417303e+08  4.420000e+08
#
#            max_idle      std_idle
# count  5.151000e+03  5.151000e+03
# mean   2.209973e+07  3.509836e+06
# std    3.681077e+07  9.340621e+06
# min   -1.000000e+00  0.000000e+00
# 25%   -1.000000e+00  0.000000e+00
# 50%    6.827102e+06  0.000000e+00
# 75%    4.499416e+07  7.761793e+05
# max    4.417303e+08  1.400000e+08
#
# [8 rows x 23 columns]

# %%
novpn120s.columns
# Out:
# Index(['duration', 'total_fiat', 'total_biat', 'min_fiat', 'min_biat',
#        'max_fiat', 'max_biat', 'mean_fiat', 'mean_biat', 'flowPktsPerSecond',
#        'flowBytesPerSecond', 'min_flowiat', 'max_flowiat', 'mean_flowiat',
#        'std_flowiat', 'min_active', 'mean_active', 'max_active', 'std_active',
#        'min_idle', 'mean_idle', 'max_idle', 'std_idle', 'class1'],
#       dtype='object')

# %% [markdown]
# c) Tìm hiểu thêm về dataset này:

# %%
vpn120s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5631 entries, 0 to 5630
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   duration            5631 non-null   float64
#  1   total_fiat          5631 non-null   float64
#  2   total_biat          5631 non-null   float64
#  3   min_fiat            5631 non-null   float64
#  4   min_biat            5631 non-null   float64
#  5   max_fiat            5631 non-null   float64
#  6   max_biat            5631 non-null   float64
#  7   mean_fiat           5631 non-null   float64
#  8   mean_biat           5631 non-null   float64
#  9   flowPktsPerSecond   5631 non-null   float64
#  10  flowBytesPerSecond  5631 non-null   float64
#  11  min_flowiat         5631 non-null   float64
#  12  max_flowiat         5631 non-null   float64
#  13  mean_flowiat        5631 non-null   float64
#  14  std_flowiat         5631 non-null   float64
#  15  min_active          5631 non-null   float64
#  16  mean_active         5631 non-null   float64
#  17  max_active          5631 non-null   float64
#  18  std_active          5631 non-null   float64
#  19  min_idle            5631 non-null   float64
#  20  mean_idle           5631 non-null   float64
#  21  max_idle            5631 non-null   float64
#  22  std_idle            5631 non-null   float64
#  23  class1              5631 non-null   object
# dtypes: float64(23), object(1)
# memory usage: 1.0+ MB

# %%
novpn120s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5151 entries, 0 to 5150
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   duration            5151 non-null   float64
#  1   total_fiat          5151 non-null   float64
#  2   total_biat          5151 non-null   float64
#  3   min_fiat            5151 non-null   float64
#  4   min_biat            5151 non-null   float64
#  5   max_fiat            5151 non-null   float64
#  6   max_biat            5151 non-null   float64
#  7   mean_fiat           5151 non-null   float64
#  8   mean_biat           5151 non-null   float64
#  9   flowPktsPerSecond   5151 non-null   float64
#  10  flowBytesPerSecond  5151 non-null   float64
#  11  min_flowiat         5151 non-null   float64
#  12  max_flowiat         5151 non-null   float64
#  13  mean_flowiat        5151 non-null   float64
#  14  std_flowiat         5151 non-null   float64
#  15  min_active          5151 non-null   float64
#  16  mean_active         5151 non-null   float64
#  17  max_active          5151 non-null   float64
#  18  std_active          5151 non-null   float64
#  19  min_idle            5151 non-null   float64
#  20  mean_idle           5151 non-null   float64
#  21  max_idle            5151 non-null   float64
#  22  std_idle            5151 non-null   float64
#  23  class1              5151 non-null   object
# dtypes: float64(23), object(1)
# memory usage: 965.9+ KB

# %% [markdown]
# ##### - Giải thích qua về các cột trong dataset này:

# %% [markdown]
# - `duration`: Đây là thời gian tồn tại của một kết nối mạng.<br>

# %% [markdown]
# - `total_fiat` and `total_biat`: Đây là tổng thời gian chờ giữa các gói tin (FIAT và BIAT) theo hướng đi (từ nguồn đến đích) và hướng về (từ đích về nguồn) tương ứng.<br>

# %% [markdown]
# - `class1`: Đây có thể là nhãn hoặc phân loại được gán cho luồng mạng dựa trên các tiêu chí nhất định, như loại lưu lượng hoặc ứng dụng tạo ra lưu lượng (hiện tại chưa chắc chắn).<br>

# %% [markdown]
# - `min_idle`, `mean_idle`, `max_idle`, `std_idle`: Đây là thời gian nhàn rỗi tối thiểu, trung bình, tối đa, và độ lệch chuẩn trong một luồng mạng. Thời gian nhàn rỗi là khoảng thời gian khi luồng không truyền dữ liệu.<br>

# %% [markdown]
# - `min_active`, `mean_active`, `max_active`, `std_active`: Đây là thời gian hoạt động tối thiểu, trung bình, tối đa, và độ lệch chuẩn trong một luồng mạng. Thời gian hoạt động là khoảng thời gian khi luồng đang truyền dữ liệu một cách tích cực.<br>

# %% [markdown]
# - `min_flowiat`, `max_flowiat`, `mean_flowiat`, `std_flowiat`: Đây là thời gian chờ giữa các gói tin tối thiểu, tối đa, trung bình, và độ lệch chuẩn trong một luồng mạng.<br>

# %% [markdown]
# - `flowBytesPerSecond`: Đây là tốc độ dữ liệu được gửi hoặc nhận trong một luồng mạng, được đo bằng byte mỗi giây.<br>

# %% [markdown]
# - `flowPktsPerSecond`: Đây là tốc độ gói tin được gửi hoặc nhận trong một luồng mạng, được đo bằng gói tin mỗi giây.<br>

# %% [markdown]
# - `min_fiat`, `min_biat`, `max_fiat`, `max_biat`, `mean_fiat`, `mean_biat`: Đây là thời gian chờ giữa các gói tin tối thiểu, tối đa, và trung bình (trung bình cộng) theo hướng đi và hướng về tương ứng.<br>

# %% [markdown]
# ## Phase 2: Xử lý dữ liệu

# %% [markdown]
# ### 1) Khám phá dữ liệu ban đầu

# %% [markdown]
# - Khám phá dữ liệu ban đầu, kiểm tra xem có dữ liệu nào bị thiếu không

# %%
vpn120s.isna().sum()
# Out:
# duration              0
# total_fiat            0
# total_biat            0
# min_fiat              0
# min_biat              0
# max_fiat              0
# max_biat              0
# mean_fiat             0
# mean_biat             0
# flowPktsPerSecond     0
# flowBytesPerSecond    0
# min_flowiat           0
# max_flowiat           0
# mean_flowiat          0
# std_flowiat           0
# min_active            0
# mean_active           0
# max_active            0
# std_active            0
# min_idle              0
# mean_idle             0
# max_idle              0
# std_idle              0
# class1                0
# dtype: int64

# %%
novpn120s.isna().sum()
# Out:
# duration              0
# total_fiat            0
# total_biat            0
# min_fiat              0
# min_biat              0
# max_fiat              0
# max_biat              0
# mean_fiat             0
# mean_biat             0
# flowPktsPerSecond     0
# flowBytesPerSecond    0
# min_flowiat           0
# max_flowiat           0
# mean_flowiat          0
# std_flowiat           0
# min_active            0
# mean_active           0
# max_active            0
# std_active            0
# min_idle              0
# mean_idle             0
# max_idle              0
# std_idle              0
# class1                0
# dtype: int64

# %% [markdown]
# - Để dễ nhìn hơn thì chúng ta sẽ mô hình hóa dưới dạng bar chart sử dụng thư viện `missingno` (msno)

# %%
import missingno as msno

msno.bar(vpn120s)
plt.show()
msno.bar(novpn120s)
plt.show()

# %% [markdown]
# ### 2) Làm sạch dữ liệu:
#
# - Xử lí các giá trị bị thiếu (nếu có).
# - Loại bỏ hoặc điền (fill) các giá trị cho các hàng/cột bị thiếu đó.

# %%
# Giả sử có giá trị nào bị thiếu, bạn có thể xử lý như sau:
# vpn15s = vpn15s.fillna(method='ffill')
# novpn15s = novpn15s.fillna(method='ffill')

# %% [markdown]
# ### 3) Phân tích dữ liệu
#
# - Tính toán các thống kê dữ liệu mô tả (như `mean`, `median`, `std`, ...) và so sánh giữa hai nhóm VPN và No-VPN

# %%
# Thống kê mô tả
vpn_stats = vpn120s.describe()
novpn_stats = novpn120s.describe()

# So sánh thống kê mô tả
stats_comparison = pd.concat([vpn_stats, novpn_stats], axis=1, keys=['VPN', 'No-VPN'])
print(stats_comparison)
# Out:
#                 VPN                                                          \
#            duration    total_fiat    total_biat      min_fiat      min_biat
# count  5.631000e+03  5.631000e+03  5.631000e+03  5.631000e+03  5.631000e+03
# mean   4.035293e+07  3.873382e+07  3.835560e+07  3.522667e+06  2.738856e+06
# std    5.069784e+07  4.867924e+07  5.010963e+07  1.147094e+07  1.005417e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00 -1.000000e+00 -1.000000e+00
# 25%    2.771000e+03  2.800000e+01  0.000000e+00  0.000000e+00 -1.000000e+00
# 50%    3.478805e+06  2.932728e+06  2.107118e+06  3.200000e+01  1.200000e+01
# 75%    9.124183e+07  9.042393e+07  9.042678e+07  1.060500e+03  5.500000e+01
# max    6.014050e+08  1.919551e+08  6.011851e+08  1.199139e+08  1.199996e+08
#
#                                                                \
#            max_fiat      max_biat     mean_fiat     mean_biat
# count  5.631000e+03  5.631000e+03  5.631000e+03  5.631000e+03
# mean   1.318796e+07  1.310114e+07  5.311396e+06  4.876923e+06
# std    2.104680e+07  2.464532e+07  1.239277e+07  1.138836e+07
# min   -1.000000e+00 -1.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.800000e+01 -1.000000e+00  2.800000e+01  0.000000e+00
# 50%    4.864120e+05  2.718000e+05  1.423310e+05  2.132494e+04
# 75%    1.999126e+07  1.987886e+07  3.923385e+06  2.938475e+06
# max    1.913169e+08  6.001097e+08  1.200000e+08  1.200000e+08
#
#                          ...        No-VPN                              \
#       flowPktsPerSecond  ...  mean_flowiat   std_flowiat    min_active
# count      5.631000e+03  ...  5.151000e+03  5.151000e+03  5.151000e+03
# mean       1.569948e+04  ...  3.283806e+06  7.160425e+06  1.578281e+07
# std        5.535933e+04  ...  6.346622e+06  1.293992e+07  3.499111e+07
# min        0.000000e+00  ...  0.000000e+00  0.000000e+00 -1.000000e+00
# 25%        3.080741e-01  ...  9.861980e+03  7.035706e+03 -1.000000e+00
# 50%        7.107169e+00  ...  2.911828e+05  9.497327e+05  1.663298e+06
# 75%        2.043008e+02  ...  3.526639e+06  1.040000e+07  1.464846e+07
# max        2.000000e+06  ...  6.070000e+07  1.430000e+08  4.420073e+08
#
#                                                                              \
#         mean_active    max_active    std_active      min_idle     mean_idle
# count  5.151000e+03  5.151000e+03  5.151000e+03  5.151000e+03  5.151000e+03
# mean   1.894104e+07  2.267081e+07  3.640134e+06  1.550653e+07  1.856391e+07
# std    3.515323e+07  3.704655e+07  9.542981e+06  3.480966e+07  3.498430e+07
# min    0.000000e+00 -1.000000e+00  0.000000e+00 -1.000000e+00  0.000000e+00
# 25%    0.000000e+00 -1.000000e+00  0.000000e+00 -1.000000e+00  0.000000e+00
# 50%    4.913739e+06  7.994498e+06  0.000000e+00  1.359206e+06  4.079993e+06
# 75%    2.810000e+07  4.505602e+07  1.160392e+06  1.460718e+07  2.640000e+07
# max    4.420000e+08  4.420073e+08  1.400000e+08  4.417303e+08  4.420000e+08
#
#
#            max_idle      std_idle
# count  5.151000e+03  5.151000e+03
# mean   2.209973e+07  3.509836e+06
# std    3.681077e+07  9.340621e+06
# min   -1.000000e+00  0.000000e+00
# 25%   -1.000000e+00  0.000000e+00
# 50%    6.827102e+06  0.000000e+00
# 75%    4.499416e+07  7.761793e+05
# max    4.417303e+08  1.400000e+08
#
# [8 rows x 46 columns]

# %% [markdown]
# - Vẽ biểu đồ phân phối cho mỗi cột để so sánh giữa VPN và No-VPN

# %%
# Vẽ biểu đồ phân phối cho mỗi cột
import matplotlib.pyplot as plt
import seaborn as sns

# Số lượng biểu đồ bạn muốn hiển thị trên mỗi hàng và cột
num_rows = 6
num_cols = 4

# Tạo figure và axes
fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 30))

# Duyệt qua mỗi cột và vẽ biểu đồ
for i, column in enumerate(vpn120s.columns):
    if column != 'class1':  # Loại trừ cột 'class1' vì không rõ cột này để làm gì
        row = i // num_cols
        col = i % num_cols
        sns.distplot(vpn120s[column], ax=axes[row, col], label='VPN')
        sns.distplot(novpn120s[column], ax=axes[row, col], label='No-VPN')
        axes[row, col].set_title(f'Phân phối của {column}')
        axes[row, col].legend()

# Điều chỉnh layout để không có chồng chéo
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### - Phân tích biểu đồ phân phối:
# - Dữ liệu phân phối lệch nhiều về bên phải ở cả 2 dataset VPN và No-VPN.
# - Ta có thể thấy rằng:
#     + VPN: Phân phối nhiều hơn ở cột `duration`, `total_biat`, `max_biat`, `mean_biat`, `flowPktsPerSecond`, `min_flowiat`, `max_flowiat`, `min_active`, `mean_active`, `max_active`, `std_active`, `mean_idle`, `max_idle`, `std_idle`.
#     + Trong khi No-VPN sẽ phân phối nhiều hơn ở những cột còn lại.
# - Kết luận:
#     + VPN: Các cột như `duration`, `total_biat`, và `mean_biat` có phân phối nhiều hơn có thể liên quan đến đặc điểm của lưu lượng VPN, chẳng hạn như thời gian kết nối dài hơn hoặc thời gian giữa các gói tin lớn hơn.
#     + No-VPN: Các cột có phân phối nhiều hơn trong No-VPN có thể phản ánh đặc điểm của lưu lượng internet thông thường mà không qua VPN.
#
# <br>

# %% [markdown]
# - Thực hiện kiểm định thống kê cho mỗi cột để xác định sự khác biệt có ý nghĩa.

# %%
from scipy.stats import ttest_ind
from IPython.display import display

# Giả sử vpn15s và novpn15s là DataFrames của bạn chứa dữ liệu VPN và no-VPN

# Kiểm định t-test cho mỗi cột
results = []
for column in vpn120s.columns:
    if column != 'class1':  # Loại trừ cột 'class1'
        t_stat, p_val = ttest_ind(vpn120s[column].dropna(), novpn120s[column].dropna())
        results.append((column, t_stat, p_val))

# Chuyển kết quả thành DataFrame để dễ dàng xem và phân tích
results_df = pd.DataFrame(results, columns=['Column', 'T-statistic', 'P-value'])

# Hiển thị DataFrame
print(results_df)
# Out:
#                 Column  T-statistic       P-value
# 0             duration    -8.814782  1.383415e-18
# 1           total_fiat    -8.117289  5.285921e-16
# 2           total_biat    -5.303997  1.155373e-07
# 3             min_fiat    -5.299375  1.184930e-07
# 4             min_biat    -5.966351  2.502444e-09
# 5             max_fiat   -12.868853  1.274558e-37
# 6             max_biat    -8.188195  2.950911e-16
# 7            mean_fiat    -8.433347  3.787689e-17
# 8            mean_biat    -7.571307  3.996885e-14
# 9    flowPktsPerSecond    15.881879  3.659072e-56
# 10  flowBytesPerSecond    -0.525397  5.993183e-01
# 11         min_flowiat     5.503796  3.802060e-08
# 12         max_flowiat   -13.239269  1.061825e-39
# 13        mean_flowiat    -7.442965  1.059554e-13
# 14         std_flowiat   -13.314057  3.975429e-40
# 15          min_active   -11.408261  5.648214e-30
# 16         mean_active   -12.481187  1.663129e-35
# 17          max_active   -12.956367  4.161059e-38
# 18          std_active    -5.846656  5.161085e-09
# 19            min_idle   -11.381036  7.692097e-30
# 20           mean_idle   -12.585431  4.551394e-36
# 21            max_idle   -13.290022  5.454552e-40
# 22            std_idle    -6.281291  3.487157e-10

# %% [markdown]
# ##### - Phân tích kết quả kiểm định thống kê:
# - Giá trị `T-statistic`: Giá trị cao (về âm hay dương) cho thấy sự khác biệt lớn giữa 2 nhóm.
# - Giá trị `P-value`: Một P-value thấp (thường dưới 0.05) cho thấy sự khác biệt có ý nghĩa thống kê. Trong trường hợp trên, các cột như `duration`, `total_fiat`, `min_fiat`, v.v., có P-value rất thấp, cho thấy sự khác biệt đáng kể giữa VPN và No-VPN.
#     + VD: `duration` có `T-statistic` là -10.306134 và `P-value` là 7.700747e−25 có nghĩa rằng có sự khác biệt rất lớn về thời gian kết nối (duration) giữa VPN và No-VPN
#
# <br>

# %% [markdown]
# - Tính toán ma trận tương quan cho toàn bộ cột và so sánh giữa hai nhóm.

# %%
# Loại bỏ cột 'class1' hoặc bất kỳ cột nào chứa chuỗi
vpn_numeric = vpn120s.select_dtypes(include=[np.number])
novpn_numeric = novpn120s.select_dtypes(include=[np.number])

# Ma trận tương quan cho VPN
vpn_corr = vpn_numeric.corr()

# Ma trận tương quan cho no-VPN
novpn_corr = novpn_numeric.corr()

# Thiết lập kích thước của biểu đồ
plt.figure(figsize=(30, 10))

# So sánh ma trận tương quan
corr_comparison = pd.concat([vpn_corr, novpn_corr], axis=1, keys=['VPN', 'No-VPN'])
sns.heatmap(corr_comparison, annot=True, fmt=".2f", annot_kws={'size': 8})
plt.show()

# %% [markdown]
# ##### - Trong ma trận tương quan, cần chú ý:
# - Đường chéo sẽ luôn bằng 1 vì một giá trị sẽ luôn có quan hệ chặt chẽ với chính nó.
# - Màu càng tối thì quan hệ càng yếu, màu càng sáng thì quan hệ với nhau càng chặt chẽ.
#
# <br>

# %% [markdown]
# - Mình sẽ remove đi một vài giá trị không sử dụng đến để quá trình phân tích trở nên đơn giản hơn:

# %%
to_drop = ['class1']

vpn120s.drop(to_drop, inplace = True, axis = 1)
novpn120s.drop(to_drop, inplace = True, axis = 1)

vpn120s.head(21)
# Out:
#        duration   total_fiat   total_biat  min_fiat  min_biat    max_fiat  \
# 0   119364082.0  119364082.0  119338343.0       9.0      17.0  58714597.0
# 1    93952224.0   93736153.0   93738835.0       6.0       7.0  45211965.0
# 2    73934090.0   73802530.0   73804692.0       3.0      14.0  27749148.0
# 3    42933658.0   42803851.0   42933658.0       0.0       0.0   5957694.0
# 4      270207.0     203681.0     244006.0      15.0      10.0     27147.0
# 5   118033511.0  118033511.0  118007383.0      23.0      10.0  58938340.0
# 6    55595001.0   55424950.0   55464526.0      32.0      23.0  23772662.0
# 7    70879295.0   55916114.0   70739980.0      13.0      10.0  45018141.0
# 8     1314540.0    1314535.0    1183635.0       7.0      17.0    132666.0
# 9    74937639.0   74937639.0   74873632.0       8.0      11.0  58039272.0
# 10   98166217.0   98166184.0   98166106.0       3.0       9.0  23243452.0
# 11   64999929.0   64999929.0   64934941.0      11.0      11.0  58386458.0
# 12  119960661.0  119483773.0  119908114.0       3.0       0.0   7010702.0
# 13  100207594.0  100182057.0  100181910.0      22.0      14.0  58246240.0
# 14  116066649.0  116001269.0  116041089.0       2.0      12.0  17885264.0
# 15   91725424.0   91524990.0   91524139.0       2.0      17.0  45199951.0
# 16  119941617.0  119864941.0  119941617.0      26.0       0.0   9773573.0
# 17  119845953.0  119845953.0  119765192.0       3.0       0.0  12866575.0
# 18   65251194.0   65251194.0   65189640.0      28.0      18.0  58758072.0
# 19  116676775.0  116612417.0  116651166.0       3.0      14.0  58275355.0
# 20  119860656.0  119814722.0  119860656.0       3.0       0.0  20044543.0
#
#       max_biat      mean_fiat      mean_biat  flowPktsPerSecond  ...  \
# 0   58776480.0   32702.488219   20131.299426          80.258649  ...
# 1   45220727.0   37645.041365   28319.889728          61.754791  ...
# 2   27746116.0   55117.647498   25189.314676          57.767668  ...
# 3    5958561.0   31706.556296   16055.967838          93.772583  ...
# 4      66572.0     593.822157     363.104167        3763.781101  ...
# 5   59002394.0  379528.974277  172022.424198           8.463698  ...
# 6   23731260.0  170015.184049   88038.930159          17.231765  ...
# 7   45157574.0  122354.735230  123455.462478          14.559964  ...
# 8     131525.0    4095.124611    2320.852941         633.681744  ...
# 9   58039496.0  291586.143969  136880.497258          10.755610  ...
# 10  23306900.0  229360.242991  137873.744382          11.633330  ...
# 11  58346734.0  335051.180412  170881.423684           8.861548  ...
# 12   6909339.0  330979.980609  201188.110738           7.994287  ...
# 13  58246482.0  753248.548872  461667.788018           3.512708  ...
# 14  17796079.0  290729.997494  231618.940120           7.771397  ...
# 15  45262593.0  933928.469388  520023.517045           3.008980  ...
# 15    112797.0    497.058357    261.200674        5734.424671  ...
# 16     24285.0   1392.396277    325.990440        3716.904082  ...
# 17  11622388.0  59691.169199  39510.643750          42.044593  ...
# 18     77009.0   1014.788749    290.781345        4333.831709  ...
# 19  14421490.0  75430.107712  57084.022694          30.773172  ...
# 20     24629.0    825.453815    231.071217        5315.111946  ...
#
#     mean_flowiat    std_flowiat   min_active   mean_active   max_active  \
# 0     421.268213    9107.759178    1753114.0  1.130000e+07   39438693.0
# 1    1657.832018  345078.175888  143704195.0  1.440000e+08  143704195.0
# 2    1904.682222   17736.017265         -1.0  0.000000e+00         -1.0
# 3    2619.735638   24218.472201         -1.0  0.000000e+00         -1.0
# 4    3036.531944   31326.437353    2210292.0  8.688035e+06   15165778.0
# 5    3014.615650   28418.981942         -1.0  0.000000e+00         -1.0
# 6    4076.584542   53848.830612    3440026.0  5.681338e+06    7922650.0
# 7    7843.381009  224119.728399    1409457.0  1.190000e+07   29243722.0
# 8   22219.712961  994088.926543   45019979.0  4.550000e+07   45992960.0
# 9     293.563595    4089.822648         -1.0  0.000000e+00         -1.0
# 10  14000.002917  156903.753329    1366163.0  8.209418e+06   38692017.0
# 11  14214.601335  218950.795536    2716695.0  1.160000e+07   29462960.0
# 12   2179.458838   43961.755182   14129077.0  1.410000e+07   14129077.0
# 13    861.604499    6416.809427         -1.0  0.000000e+00         -1.0
# 14    214.595489    1762.201003         -1.0  0.000000e+00         -1.0
# 15    174.420080    2022.359043         -1.0  0.000000e+00         -1.0
# 16    269.110254    1372.431146         -1.0  0.000000e+00         -1.0
# 17  23789.236326  311135.801535    3092223.0  8.127424e+06   13607283.0
# 18    230.802924    1705.938993         -1.0  0.000000e+00         -1.0
# 19  32504.762153  339725.561766    2161725.0  7.395747e+06   16737937.0
# 20    188.228938    1221.175777         -1.0  0.000000e+00         -1.0
#
#       std_active     min_idle     mean_idle     max_idle      std_idle
# 0   1.600000e+07    1014624.0  1.139538e+06    1208289.0  7.499739e+04
# 1   0.000000e+00  101572528.0  1.020000e+08  101572528.0  0.000000e+00
# 2   0.000000e+00         -1.0  0.000000e+00         -1.0  0.000000e+00
# 3   0.000000e+00         -1.0  0.000000e+00         -1.0  0.000000e+00
# 4   9.160912e+06    1799762.0  2.347216e+06    2894671.0  7.742176e+05
# 5   0.000000e+00         -1.0  0.000000e+00         -1.0  0.000000e+00
# 6   3.169694e+06    1015521.0  4.077856e+06    7140191.0  4.330796e+06
# 7   1.230000e+07    1034854.0  4.654979e+06   26261644.0  7.768970e+06
# 8   6.880015e+05   44997352.0  4.500000e+07   44999613.0  1.598768e+03
# 9   0.000000e+00         -1.0  0.000000e+00         -1.0  0.000000e+00
# 10  9.445402e+06    1299990.0  3.119350e+06    9249677.0  2.268340e+06
# 11  8.623568e+06    1184206.0  5.158412e+06   12039477.0  3.678602e+06
# 12  0.000000e+00    3374489.0  3.374489e+06    3374489.0  0.000000e+00
# 13  0.000000e+00         -1.0  0.000000e+00         -1.0  0.000000e+00
# 14  0.000000e+00         -1.0  0.000000e+00         -1.0  0.000000e+00
# 15  0.000000e+00         -1.0  0.000000e+00         -1.0  0.000000e+00
# 16  0.000000e+00         -1.0  0.000000e+00         -1.0  0.000000e+00
# 17  3.929384e+06    1522390.0  4.983243e+06   11493074.0  2.922692e+06
# 18  0.000000e+00         -1.0  0.000000e+00         -1.0  0.000000e+00
# 19  3.924867e+06    1231324.0  4.230546e+06   14421490.0  3.546079e+06
# 20  0.000000e+00         -1.0  0.000000e+00         -1.0  0.000000e+00
#
# [21 rows x 23 columns]

# %% [markdown]
# ##### - Kiểm tra lại mức độ chặt chẽ:

# %%
plt.figure(figsize = (18, 12))

vpn_corr = vpn120s.corr()
novpn_corr = novpn120s.corr()

# Thiết lập kích thước của biểu đồ
plt.figure(figsize=(30, 10))

# So sánh ma trận tương quan
corr_comparison = pd.concat([vpn_corr, novpn_corr], axis=1, keys=['VPN', 'No-VPN'])
sns.heatmap(corr_comparison, annot=True, fmt=".2f", annot_kws={'size': 8})
plt.show()

# %%
vpn120s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5631 entries, 0 to 5630
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   duration            5631 non-null   float64
#  1   total_fiat          5631 non-null   float64
#  2   total_biat          5631 non-null   float64
#  3   min_fiat            5631 non-null   float64
#  4   min_biat            5631 non-null   float64
#  5   max_fiat            5631 non-null   float64
#  6   max_biat            5631 non-null   float64
#  7   mean_fiat           5631 non-null   float64
#  8   mean_biat           5631 non-null   float64
#  9   flowPktsPerSecond   5631 non-null   float64
#  10  flowBytesPerSecond  5631 non-null   float64
#  11  min_flowiat         5631 non-null   float64
#  12  max_flowiat         5631 non-null   float64
#  13  mean_flowiat        5631 non-null   float64
#  14  std_flowiat         5631 non-null   float64
#  15  min_active          5631 non-null   float64
#  16  mean_active         5631 non-null   float64
#  17  max_active          5631 non-null   float64
#  18  std_active          5631 non-null   float64
#  19  min_idle            5631 non-null   float64
#  20  mean_idle           5631 non-null   float64
#  21  max_idle            5631 non-null   float64
#  22  std_idle            5631 non-null   float64
# dtypes: float64(23)
# memory usage: 1011.9 KB

# %%
novpn120s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5151 entries, 0 to 5150
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   duration            5151 non-null   float64
#  1   total_fiat          5151 non-null   float64
#  2   total_biat          5151 non-null   float64
#  3   min_fiat            5151 non-null   float64
#  4   min_biat            5151 non-null   float64
#  5   max_fiat            5151 non-null   float64
#  6   max_biat            5151 non-null   float64
#  7   mean_fiat           5151 non-null   float64
#  8   mean_biat           5151 non-null   float64
#  9   flowPktsPerSecond   5151 non-null   float64
#  10  flowBytesPerSecond  5151 non-null   float64
#  11  min_flowiat         5151 non-null   float64
#  12  max_flowiat         5151 non-null   float64
#  13  mean_flowiat        5151 non-null   float64
#  14  std_flowiat         5151 non-null   float64
#  15  min_active          5151 non-null   float64
#  16  mean_active         5151 non-null   float64
#  17  max_active          5151 non-null   float64
#  18  std_active          5151 non-null   float64
#  19  min_idle            5151 non-null   float64
#  20  mean_idle           5151 non-null   float64
#  21  max_idle            5151 non-null   float64
#  22  std_idle            5151 non-null   float64
# dtypes: float64(23)
# memory usage: 925.7 KB

# %% [markdown]
# - Chuyển lại dataset đã được làm sạch về dạng csv để chuẩn bị cho việc train model

# %%
vpn120s.to_csv('./clean_data/vpn120s_cleaned.csv', index=False)
novpn120s.to_csv('./clean_data/novpn120s_cleaned.csv', index=False)

# %% [markdown]
# ## Phrase 3: Huấn luyện Model

# %% [markdown]
# #### Ở đây, với 2 dataset đã được xử lý, mình sẽ thử train thuật toán K-Nearest Neighbors và Decision Tree để xác định model nào hiệu quả hơn trong việc phân loại

# %% [markdown]
# ##### K-Nearest Neighbors:

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

#read data
yes_df = pd.read_csv('clean_data/vpn120s_cleaned.csv')
no_df = pd.read_csv('clean_data/novpn120s_cleaned.csv')


# Create labels for dataset
yes_df['label'] = 1  
no_df['label'] = 0   

#combine 2 dataset
combined_df = pd.concat([yes_df, no_df], ignore_index=True)

# separate features and specify target variable
X = combined_df.drop(columns=['label'])
y = combined_df['label']

#split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#specifying the category and numerical columns
cate_cols=[cname for cname in X_train.columns if X_train[cname].dtype=="object"]
nume_cols=[cname for cname in X_train.columns if X_train[cname].dtype in ['int64','float64']]

# preprocessing to deal with different type of datas
# Preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy='constant')

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, nume_cols),
        ('cat', categorical_transformer, cate_cols)
    ])


# train the model
knn = Pipeline(steps=[('preprocessor', preprocessor),
                    ('model', KNeighborsClassifier(n_neighbors=5))
                             ])
knn.fit(X_train, y_train)

# predicting some value
y_pred = knn.predict(X_test)

# evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# print the report
print(classification_report(y_test, y_pred))

# view some first prediction
print("First few predictions:", y_pred[:5])
print("First few actual values:", y_test[:5].values)

# Generate matrix
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No VPN', 'VPN'], yticklabels=['No VPN', 'VPN'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy: 0.78
#               precision    recall  f1-score   support
#
#            0       0.75      0.80      0.78      1523
#            1       0.81      0.77      0.79      1712
#
#     accuracy                           0.78      3235
#    macro avg       0.78      0.78      0.78      3235
# weighted avg       0.78      0.78      0.78      3235
#
# First few predictions: [0 0 1 1 1]
# First few actual values: [0 1 1 0 1]

# %% [markdown]
# ##### Decision Tree

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

#read data
yes_df = pd.read_csv('clean_data/vpn120s_cleaned.csv')
no_df = pd.read_csv('clean_data/novpn120s_cleaned.csv')


# Create labels for dataset
yes_df['label'] = 1  
no_df['label'] = 0   

#combine 2 dataset
combined_df = pd.concat([yes_df, no_df], ignore_index=True)

# separate features and specify target variable
X = combined_df.drop(columns=['label'])
y = combined_df['label']

#split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#specifying the category and numerical columns
cate_cols=[cname for cname in X_train.columns if X_train[cname].dtype=="object"]
nume_cols=[cname for cname in X_train.columns if X_train[cname].dtype in ['int64','float64']]

# preprocessing to deal with different type of datas
# Preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy='constant')

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, nume_cols),
        ('cat', categorical_transformer, cate_cols)
    ])


# train the model
knn = Pipeline(steps=[('preprocessor', preprocessor),
                    ('model', DecisionTreeClassifier(max_leaf_nodes=1000))
                             ])
knn.fit(X_train, y_train)

# predicting some value
y_pred = knn.predict(X_test)

# evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# print the report
print(classification_report(y_test, y_pred))

# view some first prediction
print("First few predictions:", y_pred[:5])
print("First few actual values:", y_test[:5].values)

# Generate matrix
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No VPN', 'VPN'], yticklabels=['No VPN', 'VPN'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy: 0.84
#               precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83      1523
#            1       0.84      0.86      0.85      1712
#
#     accuracy                           0.84      3235
#    macro avg       0.84      0.84      0.84      3235
# weighted avg       0.84      0.84      0.84      3235
#
# First few predictions: [0 1 1 0 1]
# First few actual values: [0 1 1 0 1]

# %% [markdown]
# ##### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegressionCV
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

#read data
yes_df = pd.read_csv('clean_data/vpn120s_cleaned.csv')
no_df = pd.read_csv('clean_data/novpn120s_cleaned.csv')


# Create labels for dataset
yes_df['label'] = 1  
no_df['label'] = 0   

#combine 2 dataset
combined_df = pd.concat([yes_df, no_df], ignore_index=True)

# separate features and specify target variable
X = combined_df.drop(columns=['label'])
y = combined_df['label']

#split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#specifying the category and numerical columns
cate_cols=[cname for cname in X_train.columns if X_train[cname].dtype=="object"]
nume_cols=[cname for cname in X_train.columns if X_train[cname].dtype in ['int64','float64']]

# preprocessing to deal with different type of datas
# Preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy='constant')

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, nume_cols),
        ('cat', categorical_transformer, cate_cols)
    ])
cpu_cores=8
lr=Pipeline(steps=[('preprocessor', preprocessor),
                    ('model', LogisticRegressionCV(n_jobs=cpu_cores,solver='liblinear'))
                             ])
lr.fit(X_train,y_train)

# predicting some value
y_pred = lr.predict(X_test)

# evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# print the report
print(classification_report(y_test, y_pred))

# view some first prediction
print("First few predictions:", y_pred[:5])
print("First few actual values:", y_test[:5].values)

# Generate matrix
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No VPN', 'VPN'], yticklabels=['No VPN', 'VPN'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy: 0.63
#               precision    recall  f1-score   support
#
#            0       0.65      0.47      0.54      1523
#            1       0.62      0.78      0.69      1712
#
#     accuracy                           0.63      3235
#    macro avg       0.64      0.62      0.62      3235
# weighted avg       0.63      0.63      0.62      3235
#
# First few predictions: [1 0 1 1 1]
# First few actual values: [0 1 1 0 1]

# %% [markdown]
# ##### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

#read data
yes_df = pd.read_csv('clean_data/vpn120s_cleaned.csv')
no_df = pd.read_csv('clean_data/novpn120s_cleaned.csv')


# Create labels for dataset
yes_df['label'] = 1  
no_df['label'] = 0   

#combine 2 dataset
combined_df = pd.concat([yes_df, no_df], ignore_index=True)

# separate features and specify target variable
X = combined_df.drop(columns=['label'])
y = combined_df['label']

#split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#specifying the category and numerical columns
cate_cols=[cname for cname in X_train.columns if X_train[cname].dtype=="object"]
nume_cols=[cname for cname in X_train.columns if X_train[cname].dtype in ['int64','float64']]

# preprocessing to deal with different type of datas
# Preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy='constant')

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, nume_cols),
        ('cat', categorical_transformer, cate_cols)
    ])
cpu_cores=8
# Train the model based on best optimized args
rf=Pipeline(steps=[('preprocessor', preprocessor),
                    ('model', RandomForestClassifier(n_jobs=cpu_cores,n_estimators=7000))
                             ])
rf.fit(X_train,y_train)

# predicting some value
y_pred = rf.predict(X_test)

# evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# print the report
print(classification_report(y_test, y_pred))

# view some first prediction
print("First few predictions:", y_pred[:5])
print("First few actual values:", y_test[:5].values)

# Generate matrix
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No VPN', 'VPN'], yticklabels=['No VPN', 'VPN'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy: 0.87
#               precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86      1523
#            1       0.87      0.89      0.88      1712
#
#     accuracy                           0.87      3235
#    macro avg       0.87      0.87      0.87      3235
# weighted avg       0.87      0.87      0.87      3235
#
# First few predictions: [0 1 1 0 1]
# First few actual values: [0 1 1 0 1]

# %% [markdown]
# ### Kết luận:
#
# - KNN: Mô hình này có độ chính xác khá cao (0.78) và sự cân bằng giữa precision và recall cho cả hai lớp, cho thấy khả năng phân loại tốt. Tuy nhiên, KNN có thể không phải là lựa chọn tối ưu nếu kích thước dữ liệu lớn do độ phức tạp tính toán cao và thời gian dự đoán chậm.
# - Decision Tree: Với độ chính xác 0.84, mô hình này cho thấy khả năng phân biệt tốt giữa VPN và No VPN. Cây quyết định cũng dễ diễn giải và triển khai, nhưng có thể dễ bị overfitting nếu không được cắt tỉa đúng cách.
# - Logistic Regression: Mặc dù có độ chính xác thấp nhất (0.63), logistic regression là mô hình đơn giản và nhanh chóng trong việc huấn luyện và dự đoán. Tuy nhiên, kết quả cho thấy mô hình này có xu hướng dự đoán ‘VPN’ nhiều hơn, có thể không phù hợp cho việc điều chỉnh băng thông mạng một cách chính xác.
# - Random Forest: Đây là mô hình có hiệu suất cao nhất với độ chính xác 0.87 và sự cân bằng giữa precision và recall. Random Forest là sự kết hợp của nhiều cây quyết định, giúp giảm thiểu nguy cơ overfitting và tăng cường độ tin cậy của dự đoán.
#
# ##### -> Kết luận: Random Forest là mô hình phù hợp nhất cho mục tiêu của nhóm (phân loại VPN/No-VPN để điều chỉnh băng thông mạng) với hiệu suất cao và khả năng phân loại chính xác nhất.
