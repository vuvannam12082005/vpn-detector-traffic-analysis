# %% [markdown]
# # Applied Stats - Thống kê Ứng dụng

# %% [markdown]
# ## Phrase 1: Phân tích dữ liệu:

# %% [markdown]
# ### 1) Import các thư viện cần thiết:
# - `pandas` (pd): Thư viện này được sử dụng để xử lý và phân tích dữ liệu. Nó cung cấp các đối tượng như DataFrame và Series để làm việc với dữ liệu dạng bảng.
# - `pyscipy.io.arff`: Đây là một module trong thư viện SciPy, được sử dụng để đọc và ghi dữ liệu trong định dạng ARFF (Attribute-Relation File Format), một định dạng phổ biến trong lĩnh vực khoa học dữ liệu.
# - `numpy` (np): Thư viện này cung cấp hỗ trợ cho mảng và ma trận lớn, cùng với một bộ sưu tập lớn các hàm toán học để thao tác với các mảng này.
# - `matplotlib.pyplot` (plt): Đây là một thư viện vẽ đồ thị 2D trong Python, cho phép bạn vẽ nhiều loại đồ thị như đồ thị dạng line, bar, scatter, histogram, etc.
# - `warnings`: Ngăn chặn việc hiển thị các cảnh báo từ Python hoặc các thư viện khác. Giúp cho output trông gọn hơn.
# - `seaborn` (sns): Vẽ biểu đồ

# %%
import pandas as pd
from scipy.io import arff
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

plt.style.use('ggplot')

# %% [markdown]
# ### 2) Đọc file dataset và biểu diễn dạng bảng

# %% [markdown]
# a) VPN Dataset:

# %%
data = arff.loadarff('data/train_test/Merge-A1-A2-ARFF/merged_vpn_exact_30s.arff')
vpn30s = pd.DataFrame(data[0])
vpn30s.head()
# Out:
#      duration  total_fiat  total_biat   min_fiat    min_biat      max_fiat  \
# 0  26151647.0      9457.0     48233.0  8517197.0   8517186.0  2.905739e+06
# 1  29404503.0      1392.0     40153.0  7751306.0   7917270.0  2.100322e+06
# 2  29847959.0       967.0       950.0  5430769.0  12160328.0  1.789592e+06
# 3  20492817.0       109.0        61.0  5852512.0   5646046.0  1.707735e+06
# 4  26190082.0       136.0     38553.0  9282209.0   9075619.0  3.273751e+06
#
#        max_biat     mean_fiat     mean_biat  flowPktsPerSecond  ...  \
# 0  2.888253e+06  3.190008e+06  3.167353e+06           0.764770  ...
# 1  2.085601e+06  2.584444e+06  2.596018e+06           1.020252  ...
# 2  2.487320e+06  2.058710e+06  3.584690e+06           0.804075  ...
# 3  1.694148e+06  2.293824e+06  2.285484e+06           1.268737  ...
# 4  3.273751e+06  4.239128e+06  4.128681e+06           0.687283  ...
#
#     std_flowiat  min_active   mean_active  max_active    std_active  \
# 0  2.572436e+06   4885236.0  6.238666e+06   8517197.0  1.576727e+06
# 1  2.015264e+06   1506391.0  4.171218e+06   8165394.0  2.700421e+06
# 2  2.776994e+06   1026809.0  4.974660e+06  12160328.0  3.901737e+06
# 3  1.711699e+06   4101835.0  5.020141e+06   5646125.0  7.094181e+05
# 4  3.205951e+06   7536268.0  8.730002e+06   9378548.0  1.035095e+06
#
#     min_idle     mean_idle    max_idle      std_idle  class1
# 0  4876225.0  6.028045e+06   8517100.0  1.719114e+06  b'VPN'
# 1  1306411.0  3.872325e+06   7751306.0  2.510095e+06  b'VPN'
# 2  1026695.0  4.733906e+06  11952037.0  3.837996e+06  b'VPN'
# 3  3305510.0  4.536664e+06   5646046.0  1.116509e+06  b'VPN'
# 4  7116525.0  8.212348e+06   9075619.0  1.000036e+06  b'VPN'
#
# [5 rows x 24 columns]

# %% [markdown]
# b) No-VPN Dataset:

# %%
data = arff.loadarff('data/train_test/Merge-A1-A2-ARFF/merged_nonvpn_exact_30s.arff')
novpn30s = pd.DataFrame(data[0])
novpn30s.head()
# Out:
#      duration  total_fiat  total_biat    min_fiat    min_biat       max_fiat  \
# 0  22930417.0        18.0         4.0  10995965.0  10960941.0  314115.301370
# 1  25199304.0        16.0         4.0  11037969.0  10851858.0  359269.900000
# 2  29772995.0        17.0         7.0   4093396.0   3956161.0  261815.256637
# 3  29609149.0        22.0         6.0   3954677.0   3943698.0  271180.963303
# 4   7863522.0        30.0         8.0   2067690.0   2068091.0  244213.125000
#
#         max_biat     mean_fiat     mean_biat  flowPktsPerSecond  ...  \
# 0  360993.158730  1.306745e+06  1.389355e+06           6.018207  ...
# 1  387414.676923  1.373362e+06  1.392885e+06           5.436658  ...
# 2  310135.364583  6.445422e+05  6.512717e+05           7.086959  ...
# 3  287136.446602  6.685474e+05  6.590460e+05           7.227496  ...
# 4  252051.483871  5.718062e+05  5.628123e+05           8.266016  ...
#
#      std_flowiat  min_active   mean_active  max_active    std_active  \
# 0  952994.511204   1491627.0  5.011278e+06  11141326.0  4.507600e+06
# 1  976395.388090   1710925.0  4.164396e+06  14269600.0  4.973926e+06
# 2  462297.947930   1363299.0  2.706523e+06   6192566.0  1.445372e+06
# 3  472527.270988   1443143.0  2.937555e+06   4176130.0  8.769669e+05
# 4  400581.170736   2092947.0  2.535199e+06   3282729.0  6.509928e+05
#
#     min_idle     mean_idle    max_idle      std_idle      class1
# 0  1079974.0  3.668800e+06  10945954.0  4.855368e+06  b'Non-VPN'
# 1  1234883.0  3.150269e+06  10851858.0  3.797336e+06  b'Non-VPN'
# 2  1147658.0  1.955468e+06   3956161.0  8.938483e+05  b'Non-VPN'
# 3  1065834.0  2.022585e+06   3895269.0  9.303813e+05  b'Non-VPN'
# 4  1707343.0  1.897912e+06   2017289.0  1.667869e+05  b'Non-VPN'
#
# [5 rows x 24 columns]

# %% [markdown]
# ### 3) Nhận định cấu trúc dữ liệu

# %% [markdown]
# ##### - Đầu tiên, chúng ta sẽ chạy lệnh `describe()` để lấy thông tin đã được thống kê lại từ các cột trong dataset:

# %% [markdown]
# - count: Số lượng quan sát (entries) không bị thiếu trong dataset.
# - mean: Giá trị trung bình của dữ liệu.
# - std: Độ lệch chuẩn, đo lường mức độ phân tán của dữ liệu so với giá trị trung bình.
# - min: Giá trị nhỏ nhất trong dataset.
# - 25%: Phân vị thứ 25, còn được gọi là phân vị thứ nhất hoặc Q1, là giá trị mà 25% dữ liệu nằm dưới nó.
# - 50%: Phân vị thứ 50, còn được gọi là trung vị, là giá trị chia dataset làm đôi.
# - 75%: Phân vị thứ 75, còn được gọi là phân vị thứ ba hoặc Q3, là giá trị mà 75% dữ liệu nằm dưới nó.
# - max: Giá trị lớn nhất trong dataset.

# %% [markdown]
# ##### - Sau đó chúng ta sẽ chạy lệnh `columns` để in ra thông tin các cột trong bảng dữ liệu

# %% [markdown]
# a) VPN Dataset:

# %%
vpn30s.describe()
# Out:
#            duration    total_fiat    total_biat      min_fiat      min_biat  \
# count
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   duration            13834 non-null  float64
#  1   total_fiat          13834 non-null  float64
#  2   total_biat          13834 non-null  float64
#  3   min_fiat            13834 non-null  float64
#  4   min_biat            13834 non-null  float64
#  5   max_fiat            13834 non-null  float64
#  6   max_biat            13834 non-null  float64
#  7   mean_fiat           13834 non-null  float64
#  8   mean_biat           13834 non-null  float64
#  9   flowPktsPerSecond   13834 non-null  float64
#  10  flowBytesPerSecond  13834 non-null  float64
#  11  min_flowiat         13834 non-null  float64
#  12  max_flowiat         13834 non-null  float64
#  13  mean_flowiat        13834 non-null  float64
#  14  std_flowiat         13834 non-null  float64
#  15  min_active          13834 non-null  float64
#  16  mean_active         13834 non-null  float64
#  17  max_active          13834 non-null  float64
#  18  std_active          13834 non-null  float64
#  19  min_idle            13834 non-null  float64
#  20  mean_idle           13834 non-null  float64
#  21  max_idle            13834 non-null  float64
#  22  std_idle            13834 non-null  float64
#  23  class1              13834 non-null  object
# dtypes: float64(23), object(1)
# memory usage: 2.5+ MB

# %% [markdown]
# ##### - Giải thích qua về các cột trong dataset này:

# %% [markdown]
# - `duration`: Đây là thời gian tồn tại của một kết nối mạng.<br>

# %% [markdown]
# - `total_fiat` and `total_biat`: Đây là tổng thời gian chờ giữa các gói tin (FIAT và BIAT) theo hướng đi (từ nguồn đến đích) và hướng về (từ đích về nguồn) tương ứng.<br>

# %% [markdown]
# - `class1`: Đây có thể là nhãn hoặc phân loại được gán cho luồng mạng dựa trên các tiêu chí nhất định, như loại lưu lượng hoặc ứng dụng tạo ra lưu lượng (hiện tại chưa chắc chắn).<br>

# %% [markdown]
# - `min_idle`, `mean_idle`, `max_idle`, `std_idle`: Đây là thời gian nhàn rỗi tối thiểu, trung bình, tối đa, và độ lệch chuẩn trong một luồng mạng. Thời gian nhàn rỗi là khoảng thời gian khi luồng không truyền dữ liệu.<br>

# %% [markdown]
# - `min_active`, `mean_active`, `max_active`, `std_active`: Đây là thời gian hoạt động tối thiểu, trung bình, tối đa, và độ lệch chuẩn trong một luồng mạng. Thời gian hoạt động là khoảng thời gian khi luồng đang truyền dữ liệu một cách tích cực.<br>

# %% [markdown]
# - `min_flowiat`, `max_flowiat`, `mean_flowiat`, `std_flowiat`: Đây là thời gian chờ giữa các gói tin tối thiểu, tối đa, trung bình, và độ lệch chuẩn trong một luồng mạng.<br>

# %% [markdown]
# - `flowBytesPerSecond`: Đây là tốc độ dữ liệu được gửi hoặc nhận trong một luồng mạng, được đo bằng byte mỗi giây.<br>

# %% [markdown]
# - `flowPktsPerSecond`: Đây là tốc độ gói tin được gửi hoặc nhận trong một luồng mạng, được đo bằng gói tin mỗi giây.<br>

# %% [markdown]
# - `min_fiat`, `min_biat`, `max_fiat`, `max_biat`, `mean_fiat`, `mean_biat`: Đây là thời gian chờ giữa các gói tin tối thiểu, tối đa, và trung bình (trung bình cộng) theo hướng đi và hướng về tương ứng.<br>

# %% [markdown]
# ## Phase 2: Xử lý dữ liệu

# %% [markdown]
# ### 1) Khám phá dữ liệu ban đầu

# %% [markdown]
# - Khám phá dữ liệu ban đầu, kiểm tra xem có dữ liệu nào bị thiếu không

# %%
vpn30s.isna().sum()
# Out:
# duration              0
# total_fiat            0
# total_biat            0
# min_fiat              0
# min_biat              0
# max_fiat              0
# max_biat              0
# mean_fiat             0
# mean_biat             0
# flowPktsPerSecond     0
# flowBytesPerSecond    0
# min_flowiat           0
# max_flowiat           0
# mean_flowiat          0
# std_flowiat           0
# min_active            0
# mean_active           0
# max_active            0
# std_active            0
# min_idle              0
# mean_idle             0
# max_idle              0
# std_idle              0
# class1                0
# dtype: int64

# %%
novpn30s.isna().sum()
# Out:
# duration              0
# total_fiat            0
# total_biat            0
# min_fiat              0
# min_biat              0
# max_fiat              0
# max_biat              0
# mean_fiat             0
# mean_biat             0
# flowPktsPerSecond     0
# flowBytesPerSecond    0
# min_flowiat           0
# max_flowiat           0
# mean_flowiat          0
# std_flowiat           0
# min_active            0
# mean_active           0
# max_active            0
# std_active            0
# min_idle              0
# mean_idle             0
# max_idle              0
# std_idle              0
# class1                0
# dtype: int64

# %% [markdown]
# - Để dễ nhìn hơn thì chúng ta sẽ mô hình hóa dưới dạng bar chart sử dụng thư viện `missingno` (msno)

# %%
import missingno as msno

msno.bar(vpn30s)
plt.show()
msno.bar(novpn30s)
plt.show()

# %% [markdown]
# ### 2) Làm sạch dữ liệu:
#
# - Xử lí các giá trị bị thiếu (nếu có).
# - Loại bỏ hoặc điền (fill) các giá trị cho các hàng/cột bị thiếu đó.

# %%
# Giả sử có giá trị nào bị thiếu, bạn có thể xử lý như sau:
# vpn15s = vpn15s.fillna(method='ffill')
# novpn15s = novpn15s.fillna(method='ffill')

# %% [markdown]
# ### 3) Phân tích dữ liệu
#
# - Tính toán các thống kê dữ liệu mô tả (như `mean`, `median`, `std`, ...) và so sánh giữa hai nhóm VPN và No-VPN

# %%
# Thống kê mô tả
vpn_stats = vpn30s.describe()
novpn_stats = novpn30s.describe()

# So sánh thống kê mô tả
stats_comparison = pd.concat([vpn_stats, novpn_stats], axis=1, keys=['VPN', 'No-VPN'])
print(stats_comparison)
# Out:
#                 VPN                                                          \
#            duration    total_fiat    total_biat      min_fiat      min_biat
# count  1.546800e+04  1.546800e+04  1.546800e+04  1.546800e+04  1.546800e+04
# mean   1.517621e+07  7.785883e+06  7.872948e+06  3.537808e+06  3.627645e+06
# std    1.774697e+07  1.165550e+07  1.419968e+07  7.018080e+06  1.073594e+07
# min    0.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00
# 25%    2.765280e+05  2.200000e+01  7.000000e+00  2.200000e+01  7.000000e+00
# 50%    1.645010e+07  1.021535e+05  1.533000e+03  2.765750e+04  1.493000e+03
# 75%    2.881223e+07  1.837576e+07  1.739570e+07  3.835580e+06  3.759963e+06
# max    6.014050e+08  1.919551e+08  6.011851e+08  1.913169e+08  6.001097e+08
#
#                                                                \
#            max_fiat      max_biat     mean_fiat     mean_biat
# count  1.546800e+04  1.546800e+04  1.546800e+04  1.546800e+04
# mean   3.843389e+06  3.960053e+06  1.674202e+06  1.712029e+06
# std    6.995483e+06  1.073551e+07  4.024120e+06  4.348836e+06
# min   -1.000000e+00 -1.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.832547e+04  3.238977e+03  3.521378e+02  1.000000e+00
# 50%    3.269489e+05  3.091072e+05  1.040567e+05  8.314393e+04
# 75%    5.204968e+06  5.897514e+06  9.933780e+05  9.921981e+05
# max    1.913169e+08  6.001097e+08  7.230000e+07  9.800000e+07
#
#                          ...        No-VPN                              \
#       flowPktsPerSecond  ...  mean_flowiat   std_flowiat    min_active
# count      15468.000000  ...  1.383400e+04  1.383400e+04  1.383400e+04
# mean        3874.476326  ...  9.878067e+05  1.981526e+06  5.563640e+06
# std        22984.939938  ...  3.253660e+06  5.816345e+06  1.804645e+07
# min            0.000000  ...  0.000000e+00  0.000000e+00 -1.000000e+00
# 25%            1.240209  ...  8.844088e+03  5.456165e+03 -1.000000e+00
# 50%            6.406762  ...  3.531083e+04  2.895299e+04 -1.000000e+00
# 75%           76.495731  ...  4.731894e+05  1.265226e+06  3.138500e+06
# max       666666.666667  ...  6.070000e+07  1.360000e+08  3.036184e+08
#
#                                                                              \
#         mean_active    max_active    std_active      min_idle     mean_idle
# count  1.383400e+04  1.383400e+04  1.383400e+04  1.383400e+04  1.383400e+04
# mean   6.391502e+06  7.432642e+06  1.028695e+06  5.362066e+06  6.124968e+06
# std    1.822480e+07  1.898800e+07  4.348171e+06  1.796367e+07  1.814137e+07
# min    0.000000e+00 -1.000000e+00  0.000000e+00 -1.000000e+00  0.000000e+00
# 25%    0.000000e+00 -1.000000e+00  0.000000e+00 -1.000000e+00  0.000000e+00
# 50%    0.000000e+00 -1.000000e+00  0.000000e+00 -1.000000e+00  0.000000e+00
# 75%    5.939942e+06  9.760161e+06  0.000000e+00  2.613275e+06  5.117617e+06
# max    3.040000e+08  3.036184e+08  8.960000e+07  3.035957e+08  3.040000e+08
#
#
#            max_idle      std_idle
# count  1.383400e+04  1.383400e+04
# mean   7.110196e+06  9.680890e+05
# std    1.887512e+07  4.291180e+06
# min   -1.000000e+00  0.000000e+00
# 25%   -1.000000e+00  0.000000e+00
# 50%   -1.000000e+00  0.000000e+00
# 75%    8.622118e+06  0.000000e+00
# max    3.035957e+08  8.980000e+07
#
# [8 rows x 46 columns]

# %% [markdown]
# - Vẽ biểu đồ phân phối cho mỗi cột để so sánh giữa VPN và No-VPN

# %%
# Vẽ biểu đồ phân phối cho mỗi cột
import matplotlib.pyplot as plt
import seaborn as sns

# Số lượng biểu đồ bạn muốn hiển thị trên mỗi hàng và cột
num_rows = 6
num_cols = 4

# Tạo figure và axes
fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 30))

# Duyệt qua mỗi cột và vẽ biểu đồ
for i, column in enumerate(vpn30s.columns):
    if column != 'class1':  # Loại trừ cột 'class1' vì không rõ cột này để làm gì
        row = i // num_cols
        col = i % num_cols
        sns.distplot(vpn30s[column], ax=axes[row, col], label='VPN')
        sns.distplot(novpn30s[column], ax=axes[row, col], label='No-VPN')
        axes[row, col].set_title(f'Phân phối của {column}')
        axes[row, col].legend()

# Điều chỉnh layout để không có chồng chéo
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### - Phân tích biểu đồ phân phối:
# - Dữ liệu phân phối lệch nhiều về bên phải ở cả 2 dataset VPN và No-VPN.
# - Ta có thể thấy rằng:
#     + VPN: Phân phối nhiều hơn ở cột `duration`, `total_biat`, `max_biat`, `mean_biat`, `flowPktsPerSecond`, `min_flowiat`, `max_flowiat`, `min_active`, `mean_active`, `max_active`, `std_active`, `mean_idle`, `max_idle`, `std_idle`.
#     + Trong khi No-VPN sẽ phân phối nhiều hơn ở những cột còn lại.
# - Kết luận:
#     + VPN: Các cột như `duration`, `total_biat`, và `mean_biat` có phân phối nhiều hơn có thể liên quan đến đặc điểm của lưu lượng VPN, chẳng hạn như thời gian kết nối dài hơn hoặc thời gian giữa các gói tin lớn hơn.
#     + No-VPN: Các cột có phân phối nhiều hơn trong No-VPN có thể phản ánh đặc điểm của lưu lượng internet thông thường mà không qua VPN.
#
# <br>

# %% [markdown]
# - Thực hiện kiểm định thống kê cho mỗi cột để xác định sự khác biệt có ý nghĩa.

# %%
from scipy.stats import ttest_ind
from IPython.display import display

# Giả sử vpn15s và novpn15s là DataFrames của bạn chứa dữ liệu VPN và no-VPN

# Kiểm định t-test cho mỗi cột
results = []
for column in vpn30s.columns:
    if column != 'class1':  # Loại trừ cột 'class1'
        t_stat, p_val = ttest_ind(vpn30s[column].dropna(), novpn30s[column].dropna())
        results.append((column, t_stat, p_val))

# Chuyển kết quả thành DataFrame để dễ dàng xem và phân tích
results_df = pd.DataFrame(results, columns=['Column', 'T-statistic', 'P-value'])

# Hiển thị DataFrame
print(results_df)
# Out:
#                 Column  T-statistic       P-value
# 0             duration   -10.553609  5.442831e-26
# 1           total_fiat    -4.165855  3.110763e-05
# 2           total_biat     1.886784  5.919927e-02
# 3             min_fiat     1.425997  1.538799e-01
# 4             min_biat    10.227222  1.646607e-24
# 5             max_fiat     0.654220  5.129751e-01
# 6             max_biat    10.911674  1.146001e-27
# 7            mean_fiat     0.874022  3.821132e-01
# 8            mean_biat    12.283408  1.353128e-34
# 9    flowPktsPerSecond     6.903634  5.172139e-12
# 10  flowBytesPerSecond    -5.411859  6.286266e-08
# 11         min_flowiat    -1.328343  1.840753e-01
# 12         max_flowiat    -4.234567  2.296904e-05
# 13        mean_flowiat     2.526164  1.153679e-02
# 14         std_flowiat    -1.980051  4.770710e-02
# 15          min_active    -3.884024  1.029673e-04
# 16         mean_active    -3.394785  6.877349e-04
# 17          max_active    -2.681178  7.340449e-03
# 18          std_active     2.129261  3.324096e-02
# 19            min_idle    -4.955297  7.262226e-07
# 20           mean_idle    -4.691998  2.717709e-06
# 21            max_idle    -4.399664  1.088007e-05
# 22            std_idle     0.603884  5.459254e-01

# %% [markdown]
# ##### - Phân tích kết quả kiểm định thống kê:
# - Giá trị `T-statistic`: Giá trị cao (về âm hay dương) cho thấy sự khác biệt lớn giữa 2 nhóm.
# - Giá trị `P-value`: Một P-value thấp (thường dưới 0.05) cho thấy sự khác biệt có ý nghĩa thống kê. Trong trường hợp trên, các cột như `duration`, `total_fiat`, `min_fiat`, v.v., có P-value rất thấp, cho thấy sự khác biệt đáng kể giữa VPN và No-VPN.
#     + VD: `duration` có `T-statistic` là -10.306134 và `P-value` là 7.700747e−25 có nghĩa rằng có sự khác biệt rất lớn về thời gian kết nối (duration) giữa VPN và No-VPN
#
# <br>

# %% [markdown]
# - Tính toán ma trận tương quan cho toàn bộ cột và so sánh giữa hai nhóm.

# %%
# Loại bỏ cột 'class1' hoặc bất kỳ cột nào chứa chuỗi
vpn_numeric = vpn30s.select_dtypes(include=[np.number])
novpn_numeric = novpn30s.select_dtypes(include=[np.number])

# Ma trận tương quan cho VPN
vpn_corr = vpn_numeric.corr()

# Ma trận tương quan cho no-VPN
novpn_corr = novpn_numeric.corr()

# Thiết lập kích thước của biểu đồ
plt.figure(figsize=(30, 10))

# So sánh ma trận tương quan
corr_comparison = pd.concat([vpn_corr, novpn_corr], axis=1, keys=['VPN', 'No-VPN'])
sns.heatmap(corr_comparison, annot=True, fmt=".2f", annot_kws={'size': 8})
plt.show()

# %% [markdown]
# ##### - Trong ma trận tương quan, cần chú ý:
# - Đường chéo sẽ luôn bằng 1 vì một giá trị sẽ luôn có quan hệ chặt chẽ với chính nó.
# - Màu càng tối thì quan hệ càng yếu, màu càng sáng thì quan hệ với nhau càng chặt chẽ.
#
# <br>

# %% [markdown]
# - Mình sẽ remove đi một vài giá trị không sử dụng đến để quá trình phân tích trở nên đơn giản hơn:

# %%
to_drop = ['class1']

vpn30s.drop(to_drop, inplace = True, axis = 1)
novpn30s.drop(to_drop, inplace = True, axis = 1)

vpn30s.head(21)
# Out:
#       duration  total_fiat  total_biat    min_fiat    min_biat      max_fiat  \
# 0   26151647.0      9457.0     48233.0   8517197.0   8517186.0  2.905739e+06
# 1   29404503.0      1392.0     40153.0   7751306.0   7917270.0  2.100322e+06
.000000e+00        -1.0  0.000000e+00        -1.0  0.000000e+00
# 12  4.893508e+06   1197148.0  3.975399e+06  12973983.0  5.082650e+06
# 13  0.000000e+00  29944585.0  2.990000e+07  29944585.0  0.000000e+00
# 14  0.000000e+00  29941524.0  2.990000e+07  29941524.0  0.000000e+00
# 15  0.000000e+00  29941958.0  2.990000e+07  29941958.0  0.000000e+00
# 16  0.000000e+00  23521535.0  2.350000e+07  23521535.0  0.000000e+00
# 17  0.000000e+00  20434391.0  2.040000e+07  20434391.0  0.000000e+00
# 18  0.000000e+00  29941903.0  2.990000e+07  29941903.0  0.000000e+00
# 19  0.000000e+00  29944309.0  2.990000e+07  29944309.0  0.000000e+00
# 20  0.000000e+00  29941487.0  2.990000e+07  29941487.0  0.000000e+00
#
# [21 rows x 23 columns]

# %% [markdown]
# ##### - Kiểm tra lại mức độ chặt chẽ:

# %%
plt.figure(figsize = (18, 12))

vpn_corr = vpn30s.corr()
novpn_corr = novpn30s.corr()

# Thiết lập kích thước của biểu đồ
plt.figure(figsize=(30, 10))

# So sánh ma trận tương quan
corr_comparison = pd.concat([vpn_corr, novpn_corr], axis=1, keys=['VPN', 'No-VPN'])
sns.heatmap(corr_comparison, annot=True, fmt=".2f", annot_kws={'size': 8})
plt.show()

# %%
vpn30s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15468 entries, 0 to 15467
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   duration            15468 non-null  float64
#  1   total_fiat          15468 non-null  float64
#  2   total_biat          15468 non-null  float64
#  3   min_fiat            15468 non-null  float64
#  4   min_biat            15468 non-null  float64
#  5   max_fiat            15468 non-null  float64
#  6   max_biat            15468 non-null  float64
#  7   mean_fiat           15468 non-null  float64
#  8   mean_biat           15468 non-null  float64
#  9   flowPktsPerSecond   15468 non-null  float64
#  10  flowBytesPerSecond  15468 non-null  float64
#  11  min_flowiat         15468 non-null  float64
#  12  max_flowiat         15468 non-null  float64
#  13  mean_flowiat        15468 non-null  float64
#  14  std_flowiat         15468 non-null  float64
#  15  min_active          15468 non-null  float64
#  16  mean_active         15468 non-null  float64
#  17  max_active          15468 non-null  float64
#  18  std_active          15468 non-null  float64
#  19  min_idle            15468 non-null  float64
#  20  mean_idle           15468 non-null  float64
#  21  max_idle            15468 non-null  float64
#  22  std_idle            15468 non-null  float64
# dtypes: float64(23)
# memory usage: 2.7 MB

# %%
novpn30s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13834 entries, 0 to 13833
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   duration            13834 non-null  float64
#  1   total_fiat          13834 non-null  float64
#  2   total_biat          13834 non-null  float64
#  3   min_fiat            13834 non-null  float64
#  4   min_biat            13834 non-null  float64
#  5   max_fiat            13834 non-null  float64
#  6   max_biat            13834 non-null  float64
#  7   mean_fiat           13834 non-null  float64
#  8   mean_biat           13834 non-null  float64
#  9   flowPktsPerSecond   13834 non-null  float64
#  10  flowBytesPerSecond  13834 non-null  float64
#  11  min_flowiat         13834 non-null  float64
#  12  max_flowiat         13834 non-null  float64
#  13  mean_flowiat        13834 non-null  float64
#  14  std_flowiat         13834 non-null  float64
#  15  min_active          13834 non-null  float64
#  16  mean_active         13834 non-null  float64
#  17  max_active          13834 non-null  float64
#  18  std_active          13834 non-null  float64
#  19  min_idle            13834 non-null  float64
#  20  mean_idle           13834 non-null  float64
#  21  max_idle            13834 non-null  float64
#  22  std_idle            13834 non-null  float64
# dtypes: float64(23)
# memory usage: 2.4 MB

# %% [markdown]
# - Chuyển lại dataset đã được làm sạch về dạng csv để chuẩn bị cho việc train model

# %%
vpn30s.to_csv('./clean_data/vpn30s_cleaned.csv', index=False)
novpn30s.to_csv('./clean_data/novpn30s_cleaned.csv', index=False)

# %% [markdown]
# ## Phrase 3: Huấn luyện Model

# %% [markdown]
# #### Ở đây, với 2 dataset đã được xử lý, mình sẽ thử train thuật toán K-Nearest Neighbors và Decision Tree để xác định model nào hiệu quả hơn trong việc phân loại

# %% [markdown]
# ##### K-Nearest Neighbors:

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

#read data
yes_df = pd.read_csv('clean_data/vpn30s_cleaned.csv')
no_df = pd.read_csv('clean_data/novpn30s_cleaned.csv')


# Create labels for dataset
yes_df['label'] = 1  
no_df['label'] = 0   

#combine 2 dataset
combined_df = pd.concat([yes_df, no_df], ignore_index=True)

# separate features and specify target variable
X = combined_df.drop(columns=['label'])
y = combined_df['label']

#split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#specifying the category and numerical columns
cate_cols=[cname for cname in X_train.columns if X_train[cname].dtype=="object"]
nume_cols=[cname for cname in X_train.columns if X_train[cname].dtype in ['int64','float64']]

# preprocessing to deal with different type of datas
# Preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy='constant')

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, nume_cols),
        ('cat', categorical_transformer, cate_cols)
    ])


# train the model
knn = Pipeline(steps=[('preprocessor', preprocessor),
                    ('model', KNeighborsClassifier(n_neighbors=5))
                             ])
knn.fit(X_train, y_train)

# predicting some value
y_pred = knn.predict(X_test)

# evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# print the report
print(classification_report(y_test, y_pred))

# view some first prediction
print("First few predictions:", y_pred[:5])
print("First few actual values:", y_test[:5].values)

# Generate matrix
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No VPN', 'VPN'], yticklabels=['No VPN', 'VPN'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy: 0.81
#               precision    recall  f1-score   support
#
#            0       0.81      0.78      0.80      4130
#            1       0.81      0.84      0.83      4661
#
#     accuracy                           0.81      8791
#    macro avg       0.81      0.81      0.81      8791
# weighted avg       0.81      0.81      0.81      8791
#
# First few predictions: [1 0 1 1 0]
# First few actual values: [1 0 1 1 0]

# %% [markdown]
# ##### Decision Tree

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

#read data
yes_df = pd.read_csv('clean_data/vpn30s_cleaned.csv')
no_df = pd.read_csv('clean_data/novpn30s_cleaned.csv')


# Create labels for dataset
yes_df['label'] = 1  
no_df['label'] = 0   

#combine 2 dataset
combined_df = pd.concat([yes_df, no_df], ignore_index=True)

# separate features and specify target variable
X = combined_df.drop(columns=['label'])
y = combined_df['label']

#split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#specifying the category and numerical columns
cate_cols=[cname for cname in X_train.columns if X_train[cname].dtype=="object"]
nume_cols=[cname for cname in X_train.columns if X_train[cname].dtype in ['int64','float64']]

# preprocessing to deal with different type of datas
# Preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy='constant')

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, nume_cols),
        ('cat', categorical_transformer, cate_cols)
    ])


# train the model
knn = Pipeline(steps=[('preprocessor', preprocessor),
                    ('model', DecisionTreeClassifier(max_leaf_nodes=1000))
                             ])
knn.fit(X_train, y_train)

# predicting some value
y_pred = knn.predict(X_test)

# evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# print the report
print(classification_report(y_test, y_pred))

# view some first prediction
print("First few predictions:", y_pred[:5])
print("First few actual values:", y_test[:5].values)

# Generate matrix
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No VPN', 'VPN'], yticklabels=['No VPN', 'VPN'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy: 0.91
#               precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90      4130
#            1       0.91      0.92      0.92      4661
#
#     accuracy                           0.91      8791
#    macro avg       0.91      0.91      0.91      8791
# weighted avg       0.91      0.91      0.91      8791
#
# First few predictions: [1 0 1 1 0]
# First few actual values: [1 0 1 1 0]

# %% [markdown]
# ##### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegressionCV
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

#read data
yes_df = pd.read_csv('clean_data/vpn30s_cleaned.csv')
no_df = pd.read_csv('clean_data/novpn30s_cleaned.csv')


# Create labels for dataset
yes_df['label'] = 1  
no_df['label'] = 0   

#combine 2 dataset
combined_df = pd.concat([yes_df, no_df], ignore_index=True)

# separate features and specify target variable
X = combined_df.drop(columns=['label'])
y = combined_df['label']

#split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#specifying the category and numerical columns
cate_cols=[cname for cname in X_train.columns if X_train[cname].dtype=="object"]
nume_cols=[cname for cname in X_train.columns if X_train[cname].dtype in ['int64','float64']]

# preprocessing to deal with different type of datas
# Preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy='constant')

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, nume_cols),
        ('cat', categorical_transformer, cate_cols)
    ])
cpu_cores=8
lr=Pipeline(steps=[('preprocessor', preprocessor),
                    ('model', LogisticRegressionCV(n_jobs=cpu_cores,solver='liblinear'))
                             ])
lr.fit(X_train,y_train)

# predicting some value
y_pred = lr.predict(X_test)

# evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# print the report
print(classification_report(y_test, y_pred))

# view some first prediction
print("First few predictions:", y_pred[:5])
print("First few actual values:", y_test[:5].values)

# Generate matrix
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No VPN', 'VPN'], yticklabels=['No VPN', 'VPN'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy: 0.64
#               precision    recall  f1-score   support
#
#            0       0.68      0.43      0.53      4130
#            1       0.62      0.82      0.71      4661
#
#     accuracy                           0.64      8791
#    macro avg       0.65      0.63      0.62      8791
# weighted avg       0.65      0.64      0.62      8791
#
# First few predictions: [1 0 1 1 1]
# First few actual values: [1 0 1 1 0]

# %% [markdown]
# ##### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

#read data
yes_df = pd.read_csv('clean_data/vpn30s_cleaned.csv')
no_df = pd.read_csv('clean_data/novpn30s_cleaned.csv')


# Create labels for dataset
yes_df['label'] = 1  
no_df['label'] = 0   

#combine 2 dataset
combined_df = pd.concat([yes_df, no_df], ignore_index=True)

# separate features and specify target variable
X = combined_df.drop(columns=['label'])
y = combined_df['label']

#split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#specifying the category and numerical columns
cate_cols=[cname for cname in X_train.columns if X_train[cname].dtype=="object"]
nume_cols=[cname for cname in X_train.columns if X_train[cname].dtype in ['int64','float64']]

# preprocessing to deal with different type of datas
# Preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy='constant')

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, nume_cols),
        ('cat', categorical_transformer, cate_cols)
    ])
cpu_cores=8
# Train the model based on best optimized args
rf=Pipeline(steps=[('preprocessor', preprocessor),
                    ('model', RandomForestClassifier(n_jobs=cpu_cores,n_estimators=500))
                             ])
rf.fit(X_train,y_train)

# predicting some value
y_pred = rf.predict(X_test)

# evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# print the report
print(classification_report(y_test, y_pred))

# view some first prediction
print("First few predictions:", y_pred[:5])
print("First few actual values:", y_test[:5].values)

# Generate matrix
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No VPN', 'VPN'], yticklabels=['No VPN', 'VPN'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy: 0.92
#               precision    recall  f1-score   support
#
#            0       0.94      0.90      0.92      4130
#            1       0.91      0.95      0.93      4661
#
#     accuracy                           0.92      8791
#    macro avg       0.93      0.92      0.92      8791
# weighted avg       0.93      0.92      0.92      8791
#
# First few predictions: [1 0 1 1 0]
# First few actual values: [1 0 1 1 0]

# %% [markdown]
#  XG BOOTS

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, FunctionTransformer
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from xgboost.sklearn import XGBClassifier
import matplotlib.pyplot as plt
import seaborn as sns

def main():
    # 1. Đọc dữ liệu
    yes_df = pd.read_csv('clean_data/vpn60s_cleaned.csv')
    no_df  = pd.read_csv('clean_data/novpn60s_cleaned.csv')

    # 2. Gán nhãn
    yes_df['label'] = 1
    no_df['label']  = 0

    # 3. Kết hợp dữ liệu
    combined_df = pd.concat([yes_df, no_df], ignore_index=True)

    # 4. Tách features và target
    X = combined_df.drop(columns=['label'])
    y = combined_df['label']

    # 5. Chia train/test (giữ tỷ lệ nhãn với stratify)
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.3, random_state=42, stratify=y
    )

    # 6. Xác định cột số và cột phân loại
    cate_cols = [c for c in X_train.columns if X_train[c].dtype == "object"]
    nume_cols = [c for c in X_train.columns if X_train[c].dtype in ['int64', 'float64']]

    # 7. Tạo transformers cho preprocessing
    numerical_transformer = SimpleImputer(strategy='constant')
    categorical_transformer = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
    ])

    # 8. Kết hợp preprocessing với ColumnTransformer
    preprocessor = ColumnTransformer(transformers=[
        ('num', numerical_transformer, nume_cols),
        ('cat', categorical_transformer, cate_cols)
    ])

    # 9. Ép dtype về float32 (không bắt buộc với CPU, nhưng giữ để thống nhất)
    to_float32 = FunctionTransformer(lambda X: X.astype(np.float32))

    # 10. Định nghĩa XGBClassifier chạy trên CPU
    xgb_clf = XGBClassifier(
        tree_method='hist',           # histogram trên CPU
        predictor='cpu_predictor',    # predictor trên CPU
        use_label_encoder=False,
        eval_metric='logloss',
        random_state=42
    )

    # 11. Xây dựng pipeline hoàn chỉnh
    pipeline = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('cast', to_float32),
        ('model', xgb_clf)
    ])

    # 12. Huấn luyện model
    pipeline.fit(X_train, y_train)

    # 13. Dự đoán
    y_pred = pipeline.predict(X_test)

    # 14. Đánh giá
    accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy: {accuracy:.2f}\n")
    print("Classification Report:")
    print(classification_report(y_test, y_pred))
    print("First few predictions:", y_pred[:5])
    print("First few actual values:", y_test.values[:5])

    # 15. Vẽ ma trận nhầm lẫn
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(
        cm, annot=True, fmt='d', cmap='Blues',
        xticklabels=['No VPN', 'VPN'],
        yticklabels=['No VPN', 'VPN']
    )
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()

if __name__ == '__main__':
    main()
# Out:
# Accuracy: 0.89
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91      2574
#            1       0.91      0.85      0.88      2081
#
#     accuracy                           0.89      4655
#    macro avg       0.90      0.89      0.89      4655
# weighted avg       0.90      0.89      0.89      4655
#
# First few predictions: [0 1 0 0 1]
# First few actual values: [0 1 0 0 1]

# %% [markdown]
# ## Phase 4: Evaluate Model

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, roc_curve, auc, confusion_matrix
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# Define the evaluation function
def evaluate_model(model, X_train, y_train, X_test, y_test, model_name="Model", cv=5):
    """
    Function to evaluate a model with Cross-Validation, ROC/AUC, and other metrics.
    """
    print(f"\n=== Đánh giá {model_name} ===")
    
    # 1. Cross-Validation (5-fold)
    cv_scores = cross_val_score(model, X_train, y_train, cv=cv, scoring='accuracy')
    print("Cross-Validation Scores (5-fold):", cv_scores)
    print("Mean CV Accuracy:", cv_scores.mean())
    print("Standard Deviation:", cv_scores.std())
    
    # 2. Predict on test set
    y_pred = model.predict(X_test)
    
    # 3. Evaluate accuracy on test set
    accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy on Test Set: {accuracy:.2f}")
    
    # 4. Print classification report
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred))
    
    # 5. View some first predictions
    print("First few predictions:", y_pred[:5])
    print("First few actual values:", y_test[:5].values)
    
    # 6. Calculate ROC Curve and AUC Score (if model supports predict_proba)
    if hasattr(model, 'predict_proba'):
        y_pred_prob = model.predict_proba(X_test)[:, 1]
        fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
        roc_auc = auc(fpr, tpr)
        
        plt.figure(figsize=(8, 6))
        plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
        plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title(f'Receiver Operating Characteristic (ROC) Curve - {model_name}')
        plt.legend(loc="lower right")
        plt.show()
        
        print(f"AUC Score: {roc_auc:.2f}")
    else:
        print("Model does not support predict_proba, cannot calculate ROC/AUC.")
    
    # 7. Plot Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No VPN', 'VPN'], yticklabels=['No VPN', 'VPN'])
    plt.title(f'Confusion Matrix - {model_name}')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()

# %%
# Read data
yes_df = pd.read_csv('clean_data/vpn120s_cleaned.csv')
no_df = pd.read_csv('clean_data/novpn120s_cleaned.csv')

# Create labels for dataset
yes_df['label'] = 1  
no_df['label'] = 0   

# Combine 2 datasets
combined_df = pd.concat([yes_df, no_df], ignore_index=True)

# Check for invalid values (NaN, inf)
print("Checking for invalid values:")
print("NaN values:\n", combined_df.isna().sum())
print("Infinite values:\n", combined_df.select_dtypes(include=[np.number]).apply(lambda x: np.isinf(x)).sum())

# Replace infinite values with NaN and then handle them
combined_df = combined_df.replace([np.inf, -np.inf], np.nan)

# Separate features and target variable
X = combined_df.drop(columns=['label'])
y = combined_df['label']

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Specify category and numerical columns
cate_cols = [cname for cname in X_train.columns if X_train[cname].dtype == "object"]
nume_cols = [cname for cname in X_train.columns if X_train[cname].dtype in ['int64', 'float64']]

# Preprocessing for numerical data
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant')),
    ('scaler', StandardScaler())  # Scaling for numerical columns
])

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, nume_cols),
        ('cat', categorical_transformer, cate_cols)
    ])

cpu_cores = 8
# Out:
# Checking for invalid values:
# NaN values:
#  duration              0
# total_fiat            0
# total_biat            0
# min_fiat              0
# min_biat              0
# max_fiat              0
# max_biat              0
# mean_fiat             0
# mean_biat             0
# flowPktsPerSecond     0
# flowBytesPerSecond    0
# min_flowiat           0
# max_flowiat           0
# mean_flowiat          0
# std_flowiat           0
# min_active            0
# mean_active           0
# max_active            0
# std_active            0
# min_idle              0
# mean_idle             0
# max_idle              0
# std_idle              0
# label                 0
# dtype: int64
# Infinite values:
#  duration              0
# total_fiat            0
# total_biat            0
# min_fiat              0
# min_biat              0
# max_fiat              0
# max_biat              0
# mean_fiat             0
# mean_biat             0
# flowPktsPerSecond     0
# flowBytesPerSecond    0
# min_flowiat           0
# max_flowiat           0
# mean_flowiat          0
# std_flowiat           0
# min_active            0
# mean_active           0
# max_active            0
# std_active            0
# min_idle              0
# mean_idle             0
# max_idle              0
# std_idle              0
# label                 0
# dtype: int64

# %% [markdown]
# Random Forest

# %%
# Random Forest
rf = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', RandomForestClassifier(n_jobs=cpu_cores, n_estimators=500))
])

# Train the model
rf.fit(X_train, y_train)

# Evaluate the model
evaluate_model(rf, X_train, y_train, X_test, y_test, model_name="Random Forest")
# Out:
# === Đánh giá Random Forest ===
# Cross-Validation Scores (5-fold): [0.89632329 0.89731699 0.90725406 0.90626035 0.91020543]
# Mean CV Accuracy: 0.9034720242089476
# Standard Deviation: 0.005592963951701235
# Accuracy on Test Set: 0.91
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.90      0.91      3072
#            1       0.91      0.92      0.92      3398
#
#     accuracy                           0.91      6470
#    macro avg       0.91      0.91      0.91      6470
# weighted avg       0.91      0.91      0.91      6470
#
# First few predictions: [1 1 1 1 1]
# First few actual values: [1 1 1 1 0]
# AUC Score: 0.97

# %% [markdown]
# K-Nearest Neighbors

# %%
# KNN
knn = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', KNeighborsClassifier(n_neighbors=5))
])

# Train the model
knn.fit(X_train, y_train)

# Evaluate the model
evaluate_model(knn, X_train, y_train, X_test, y_test, model_name="KNN")
# Out:
# === Đánh giá KNN ===
# Cross-Validation Scores (5-fold): [0.7863531  0.79099039 0.79463398 0.79397151 0.79257787]
# Mean CV Accuracy: 0.7917053711736426
# Standard Deviation: 0.002954029707535369
# Accuracy on Test Set: 0.80
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.78      0.79      3072
#            1       0.80      0.82      0.81      3398
#
#     accuracy                           0.80      6470
#    macro avg       0.80      0.80      0.80      6470
# weighted avg       0.80      0.80      0.80      6470
#
# First few predictions: [1 1 1 1 1]
# First few actual values: [1 1 1 1 0]
# AUC Score: 0.88

# %% [markdown]
# Decison Tree

# %%
# Decision Tree
dt = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', DecisionTreeClassifier(random_state=42))
])

# Train the model
dt.fit(X_train, y_train)

# Evaluate the model
evaluate_model(dt, X_train, y_train, X_test, y_test, model_name="Decision Tree")
# Out:
# === Đánh giá Decision Tree ===
# Cross-Validation Scores (5-fold): [0.8787678  0.88473004 0.8777741  0.88837363 0.8952949 ]
# Mean CV Accuracy: 0.8849880950577862
# Standard Deviation: 0.006457436317220611
# Accuracy on Test Set: 0.90
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.87      0.89      3072
#            1       0.89      0.93      0.91      3398
#
#     accuracy                           0.90      6470
#    macro avg       0.90      0.90      0.90      6470
# weighted avg       0.90      0.90      0.90      6470
#
# First few predictions: [1 1 1 1 1]
# First few actual values: [1 1 1 1 0]
# AUC Score: 0.91

# %% [markdown]
# Logistic Regression

# %%
# Logistic Regression
lr = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', LogisticRegression(max_iter=1000, random_state=42))
])

# Train the model
lr.fit(X_train, y_train)

# Evaluate the model
evaluate_model(lr, X_train, y_train, X_test, y_test, model_name="Logistic Regression")
# Out:
# === Đánh giá Logistic Regression ===
# Cross-Validation Scores (5-fold): [0.57701226 0.58297449 0.60781716 0.58728056 0.57355865]
# Mean CV Accuracy: 0.5857286226331972
# Standard Deviation: 0.012016492376460455
# Accuracy on Test Set: 0.60
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.62      0.37      0.47      3072
#            1       0.58      0.80      0.67      3398
#
#     accuracy                           0.60      6470
#    macro avg       0.60      0.58      0.57      6470
# weighted avg       0.60      0.60      0.58      6470
#
# First few predictions: [1 1 1 1 1]
# First few actual values: [1 1 1 1 0]
# AUC Score: 0.64

# %% [markdown]
# XG Boots

# %%
from xgboost import XGBClassifier

xgb = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', XGBClassifier(n_estimators=100, random_state=42))
])

xgb.fit(X_train, y_train)

evaluate_model(xgb, X_train, y_train, X_test, y_test, model_name="XGBoost")
# Out:
# === Đánh giá XGBoost ===
# Cross-Validation Scores (5-fold): [0.908579   0.90460417 0.90725406 0.90957271 0.91219351]
# Mean CV Accuracy: 0.9084406885396245
# Standard Deviation: 0.002510425067982064
# Accuracy on Test Set: 0.92
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.91      3072
#            1       0.91      0.93      0.92      3398
#
#     accuracy                           0.92      6470
#    macro avg       0.92      0.92      0.92      6470
# weighted avg       0.92      0.92      0.92      6470
#
# First few predictions: [1 1 1 0 1]
# First few actual values: [1 1 1 1 0]
# AUC Score: 0.98

# %% [markdown]
# ### Kết luận:
#
# - KNN: Mô hình này có độ chính xác khá cao (0.8) và sự cân bằng giữa precision và recall cho cả hai lớp, cho thấy khả năng phân loại tốt. Tuy nhiên, KNN có thể không phải là lựa chọn tối ưu nếu kích thước dữ liệu lớn do độ phức tạp tính toán cao và thời gian dự đoán chậm.
# - Decision Tree: Với độ chính xác 0.9, mô hình này cho thấy khả năng phân biệt tốt giữa VPN và No VPN. Cây quyết định cũng dễ diễn giải và triển khai, nhưng có thể dễ bị overfitting nếu không được cắt tỉa đúng cách.
# - Logistic Regression: Mặc dù có độ chính xác thấp nhất (0.6), logistic regression là mô hình đơn giản và nhanh chóng trong việc huấn luyện và dự đoán. Tuy nhiên, kết quả cho thấy mô hình này có xu hướng dự đoán ‘VPN’ nhiều hơn, có thể không phù hợp cho việc điều chỉnh băng thông mạng một cách chính xác.
# - Random Forest: Đây là mô hình có hiệu suất cao nhất với độ chính xác 0.91 và sự cân bằng giữa precision và recall. Random Forest là sự kết hợp của nhiều cây quyết định, giúp giảm thiểu nguy cơ overfitting và tăng cường độ tin cậy của dự đoán.
# - XGBoost: Với độ chính xác 0.92, mô hình này đạt hiệu suất tương đương với Random Forest. Nhờ kỹ thuật boosting và khả năng xử lý dữ liệu thiếu, XGBoost tỏ ra mạnh mẽ, linh hoạt và ít bị overfitting hơn so với Decision Tree đơn lẻ. Thêm vào đó, XGBoost hỗ trợ các công cụ diễn giải như feature importance và SHAP, rất hữu ích trong việc kiểm tra mô hình. Với sự kết hợp giữa hiệu năng cao và tốc độ huấn luyện nhanh, XGBoost là một lựa chọn lý tưởng trong các hệ thống phát hiện VPN theo thời gian thực.
#
#
#
# ##### -> Kết luận: XG Boost là mô hình phù hợp nhất cho mục tiêu của nhóm (phân loại VPN/No-VPN để điều chỉnh băng thông mạng) với hiệu suất cao và khả năng phân loại chính xác nhất.
