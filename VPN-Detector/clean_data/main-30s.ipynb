# %% [markdown]
# # Applied Stats - Thống kê Ứng dụng

# %% [markdown]
# ## Phrase 1: Phân tích dữ liệu:

# %% [markdown]
# ### 1) Import các thư viện cần thiết:
# - `pandas` (pd): Thư viện này được sử dụng để xử lý và phân tích dữ liệu. Nó cung cấp các đối tượng như DataFrame và Series để làm việc với dữ liệu dạng bảng.
# - `pyscipy.io.arff`: Đây là một module trong thư viện SciPy, được sử dụng để đọc và ghi dữ liệu trong định dạng ARFF (Attribute-Relation File Format), một định dạng phổ biến trong lĩnh vực khoa học dữ liệu.
# - `numpy` (np): Thư viện này cung cấp hỗ trợ cho mảng và ma trận lớn, cùng với một bộ sưu tập lớn các hàm toán học để thao tác với các mảng này.
# - `matplotlib.pyplot` (plt): Đây là một thư viện vẽ đồ thị 2D trong Python, cho phép bạn vẽ nhiều loại đồ thị như đồ thị dạng line, bar, scatter, histogram, etc.
# - `warnings`: Ngăn chặn việc hiển thị các cảnh báo từ Python hoặc các thư viện khác. Giúp cho output trông gọn hơn.
# - `seaborn` (sns): Vẽ biểu đồ

# %%
import pandas as pd
from scipy.io import arff
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

plt.style.use('ggplot')

# %% [markdown]
# ### 2) Đọc file dataset và biểu diễn dạng bảng

# %% [markdown]
# a) VPN Dataset:

# %%
data = arff.loadarff('data/Scenario-A2-ARFF/TimeBasedFeatures-Dataset-30s-VPN.arff')
vpn30s = pd.DataFrame(data[0])
vpn30s.head()
# Out:
#      duration  total_fiat  total_biat  min_fiat  min_biat   max_fiat  \
# 0   2218398.0   2191528.0   2192676.0       9.0      17.0    60217.0
# 1   3517813.0   3517813.0   3304404.0       6.0       7.0   324059.0
# 2  24120341.0  23990439.0  23990943.0       4.0      14.0  4969763.0
# 3  21936793.0  21807309.0  21806667.0       0.0       0.0  3906748.0
# 4    270207.0    203681.0    244006.0      15.0      10.0    27147.0
#
#     max_biat     mean_fiat    mean_biat  flowPktsPerSecond  ...   std_flowiat  \
# 0    86113.0    601.077345   370.009450        4315.726934  ...   1815.741336
# 1   217426.0   1413.911977   998.912938        1648.183118  ...   8971.721519
# 2  4934103.0  19238.523657  8385.509612         170.395601  ...  91516.745986
# 3  3908013.0  17063.622066  8367.869148         177.145310  ...  94908.358540
# 4    66572.0    593.822157   363.104167        3763.781101  ...   2648.293598
#
#    min_active  mean_active  max_active    std_active   min_idle  mean_idle  \
# 0        -1.0         0.00        -1.0  0.000000e+00       -1.0        0.0
# 1        -1.0         0.00        -1.0  0.000000e+00       -1.0        0.0
# 2   1498361.0   4762398.40   6401974.0  1.910100e+06  1115996.0  2109615.4
# 3   1630161.0   5281245.75  11355159.0  4.444359e+06  1308911.0  2643748.5
# 4        -1.0         0.00        -1.0  0.000000e+00       -1.0        0.0
#
#     max_idle      std_idle           class1
# 0       -1.0  0.000000e+00  b'VPN-BROWSING'
# 1       -1.0  0.000000e+00  b'VPN-BROWSING'
# 2  4800946.0  1.580859e+06  b'VPN-BROWSING'
# 3  3777807.0  1.233624e+06  b'VPN-BROWSING'
# 4       -1.0  0.000000e+00  b'VPN-BROWSING'
#
# [5 rows x 24 columns]

# %% [markdown]
# b) No-VPN Dataset:

# %%
data = arff.loadarff('data/Scenario-A2-ARFF/TimeBasedFeatures-Dataset-30s-NO-VPN.arff')
novpn30s = pd.DataFrame(data[0])
novpn30s.head()
# Out:
#      duration  total_fiat  total_biat  min_fiat  min_biat   max_fiat  \
# 0  29999857.0  29999857.0  29975545.0       1.0       0.0  1014690.0
# 1  29882813.0  29882777.0  29873072.0       2.0       0.0  1399330.0
# 2  29998247.0  29998247.0  29971049.0       0.0       0.0   957051.0
# 3  29997301.0  29997301.0  29971643.0       0.0       0.0   823486.0
# 4  29999559.0  29999510.0  29999530.0       7.0       0.0   442870.0
#
#     max_biat    mean_fiat    mean_biat  flowPktsPerSecond  ...   std_flowiat  \
# 0  1016593.0  1756.329079   368.530638        3280.715638  ...   7523.122505
# 1  1211310.0  2145.826296   454.170612        2667.185315  ...  12122.834031
# 2   757034.0  1861.741885   457.608199        2720.492301  ...   7771.867721
# 3   854818.0  1589.345184   512.449655        2578.998691  ...   7672.912552
# 4   472021.0  7451.443120  1404.209418         846.412442  ...   6941.142026
#
#    min_active  mean_active  max_active    std_active   min_idle  mean_idle  \
# 0   9578088.0    9578088.0   9578088.0  0.000000e+00  1014624.0  1014624.0
# 1   1753114.0    6686453.5  19016135.0  8.246887e+06  1133281.0  1170766.0
# 2        -1.0          0.0        -1.0  0.000000e+00       -1.0        0.0
# 3        -1.0          0.0        -1.0  0.000000e+00       -1.0        0.0
# 4        -1.0          0.0        -1.0  0.000000e+00       -1.0        0.0
#
#     max_idle      std_idle       class1
# 0  1014624.0      0.000000  b'BROWSING'
# 1  1208289.0  31592.045017  b'BROWSING'
# 2       -1.0      0.000000  b'BROWSING'
# 3       -1.0      0.000000  b'BROWSING'
# 4       -1.0      0.000000  b'BROWSING'
#
# [5 rows x 24 columns]

# %% [markdown]
# ### 3) Nhận định cấu trúc dữ liệu

# %% [markdown]
# ##### - Đầu tiên, chúng ta sẽ chạy lệnh `describe()` để lấy thông tin đã được thống kê lại từ các cột trong dataset:

# %% [markdown]
# - count: Số lượng quan sát (entries) không bị thiếu trong dataset.
# - mean: Giá trị trung bình của dữ liệu.
# - std: Độ lệch chuẩn, đo lường mức độ phân tán của dữ liệu so với giá trị trung bình.
# - min: Giá trị nhỏ nhất trong dataset.
# - 25%: Phân vị thứ 25, còn được gọi là phân vị thứ nhất hoặc Q1, là giá trị mà 25% dữ liệu nằm dưới nó.
# - 50%: Phân vị thứ 50, còn được gọi là trung vị, là giá trị chia dataset làm đôi.
# - 75%: Phân vị thứ 75, còn được gọi là phân vị thứ ba hoặc Q3, là giá trị mà 75% dữ liệu nằm dưới nó.
# - max: Giá trị lớn nhất trong dataset.

# %% [markdown]
# ##### - Sau đó chúng ta sẽ chạy lệnh `columns` để in ra thông tin các cột trong bảng dữ liệu

# %% [markdown]
# a) VPN Dataset:

# %%
vpn30s.describe()
# Out:
#            duration    total_fiat    total_biat      min_fiat      min_biat  \
# count  7.734000e+03  7.734000e+03  7.734000e+03  7.734000e+03  7.734000e+03
# mean   1.517621e+07  1.403221e+07  1.424897e+07  1.539561e+06  1.496921e+06
# std    1.774754e+07  1.315409e+07  1.737406e+07  4.543725e+06  4.484622e+06
# min    0.000000e+00  0.000000e+00  0.000000e+00 -1.000000e+00 -1.000000e+00
# 25%
#
#        flowPktsPerSecond  ...  mean_flowiat   std_flowiat    min_active  \
# count        6917.000000  ...  6.917000e+03  6.917000e+03  6.917000e+03
# mean         2059.055718  ...  9.878067e+05  1.981526e+06  5.563640e+06
# std         21885.042157  ...  3.253778e+06  5.816556e+06  1.804710e+07
# min             0.000000  ...  0.000000e+00  0.000000e+00 -1.000000e+00
# 25%             1.860648  ...  8.844088e+03  5.456165e+03 -1.000000e+00
# 50%            18.628261  ...  3.531083e+04  2.895299e+04 -1.000000e+00
# 75%           104.580726  ...  4.731894e+05  1.265226e+06  3.138500e+06
# max       1000000.000000  ...  6.070000e+07  1.360000e+08  3.036184e+08
#
#         mean_active    max_active    std_active      min_idle     mean_idle  \
# count  6.917000e+03  6.917000e+03  6.917000e+03  6.917000e+03  6.917000e+03
# mean   6.391502e+06  7.432642e+06  1.028695e+06  5.362066e+06  6.124968e+06
# std    1.822546e+07  1.898869e+07  4.348328e+06  1.796432e+07  1.814202e+07
# min    0.000000e+00 -1.000000e+00  0.000000e+00 -1.000000e+00  0.000000e+00
# 25%    0.000000e+00 -1.000000e+00  0.000000e+00 -1.000000e+00  0.000000e+00
# 50%    0.000000e+00 -1.000000e+00  0.000000e+00 -1.000000e+00  0.000000e+00
# 75%    5.939942e+06  9.760161e+06  0.000000e+00  2.613275e+06  5.117617e+06
# max    3.040000e+08  3.036184e+08  8.960000e+07  3.035957e+08  3.040000e+08
#
#            max_idle      std_idle
# count  6.917000e+03  6.917000e+03
# mean   7.110196e+06  9.680890e+05
# std    1.887580e+07  4.291335e+06
# min   -1.000000e+00  0.000000e+00
# 25%   -1.000000e+00  0.000000e+00
# 50%   -1.000000e+00  0.000000e+00
# 75%    8.622118e+06  0.000000e+00
# max    3.035957e+08  8.980000e+07
#
# [8 rows x 23 columns]

# %%
novpn30s.columns
# Out:
# Index(['duration', 'total_fiat', 'total_biat', 'min_fiat', 'min_biat',
#        'max_fiat', 'max_biat', 'mean_fiat', 'mean_biat', 'flowPktsPerSecond',
#        'flowBytesPerSecond', 'min_flowiat', 'max_flowiat', 'mean_flowiat',
#        'std_flowiat', 'min_active', 'mean_active', 'max_active', 'std_active',
#        'min_idle', 'mean_idle', 'max_idle', 'std_idle', 'class1'],
#       dtype='object')

# %% [markdown]
# c) Tìm hiểu thêm về dataset này:

# %%
vpn30s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7734 entries, 0 to 7733
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   duration            7734 non-null   float64
#  1   total_fiat          7734 non-null   float64
#  2   total_biat          7734 non-null   float64
#  3   min_fiat            7734 non-null   float64
#  4   min_biat            7734 non-null   float64
#  5   max_fiat            7734 non-null   float64
#  6   max_biat            7734 non-null   float64
#  7   mean_fiat           7734 non-null   float64
#  8   mean_biat           7734 non-null   float64
#  9   flowPktsPerSecond   7734 non-null   float64
#  10  flowBytesPerSecond  7734 non-null   float64
#  11  min_flowiat         7734 non-null   float64
#  12  max_flowiat         7734 non-null   float64
#  13  mean_flowiat        7734 non-null   float64
#  14  std_flowiat         7734 non-null   float64
#  15  min_active          7734 non-null   float64
#  16  mean_active         7734 non-null   float64
#  17  max_active          7734 non-null   float64
#  18  std_active          7734 non-null   float64
#  19  min_idle            7734 non-null   float64
#  20  mean_idle           7734 non-null   float64
#  21  max_idle            7734 non-null   float64
#  22  std_idle            7734 non-null   float64
#  23  class1              7734 non-null   object
# dtypes: float64(23), object(1)
# memory usage: 1.4+ MB

# %%
novpn30s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6917 entries, 0 to 6916
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   duration            6917 non-null   float64
#  1   total_fiat          6917 non-null   float64
#  2   total_biat          6917 non-null   float64
#  3   min_fiat            6917 non-null   float64
#  4   min_biat            6917 non-null   float64
#  5   max_fiat            6917 non-null   float64
#  6   max_biat            6917 non-null   float64
#  7   mean_fiat           6917 non-null   float64
#  8   mean_biat           6917 non-null   float64
#  9   flowPktsPerSecond   6917 non-null   float64
#  10  flowBytesPerSecond  6917 non-null   float64
#  11  min_flowiat         6917 non-null   float64
#  12  max_flowiat         6917 non-null   float64
#  13  mean_flowiat        6917 non-null   float64
#  14  std_flowiat         6917 non-null   float64
#  15  min_active          6917 non-null   float64
#  16  mean_active         6917 non-null   float64
#  17  max_active          6917 non-null   float64
#  18  std_active          6917 non-null   float64
#  19  min_idle            6917 non-null   float64
#  20  mean_idle           6917 non-null   float64
#  21  max_idle            6917 non-null   float64
#  22  std_idle            6917 non-null   float64
#  23  class1              6917 non-null   object
# dtypes: float64(23), object(1)
# memory usage: 1.3+ MB

# %% [markdown]
# ##### - Giải thích qua về các cột trong dataset này:

# %% [markdown]
# - `duration`: Đây là thời gian tồn tại của một kết nối mạng.<br>

# %% [markdown]
# - `total_fiat` and `total_biat`: Đây là tổng thời gian chờ giữa các gói tin (FIAT và BIAT) theo hướng đi (từ nguồn đến đích) và hướng về (từ đích về nguồn) tương ứng.<br>

# %% [markdown]
# - `class1`: Đây có thể là nhãn hoặc phân loại được gán cho luồng mạng dựa trên các tiêu chí nhất định, như loại lưu lượng hoặc ứng dụng tạo ra lưu lượng (hiện tại chưa chắc chắn).<br>

# %% [markdown]
# - `min_idle`, `mean_idle`, `max_idle`, `std_idle`: Đây là thời gian nhàn rỗi tối thiểu, trung bình, tối đa, và độ lệch chuẩn trong một luồng mạng. Thời gian nhàn rỗi là khoảng thời gian khi luồng không truyền dữ liệu.<br>

# %% [markdown]
# - `min_active`, `mean_active`, `max_active`, `std_active`: Đây là thời gian hoạt động tối thiểu, trung bình, tối đa, và độ lệch chuẩn trong một luồng mạng. Thời gian hoạt động là khoảng thời gian khi luồng đang truyền dữ liệu một cách tích cực.<br>

# %% [markdown]
# - `min_flowiat`, `max_flowiat`, `mean_flowiat`, `std_flowiat`: Đây là thời gian chờ giữa các gói tin tối thiểu, tối đa, trung bình, và độ lệch chuẩn trong một luồng mạng.<br>

# %% [markdown]
# - `flowBytesPerSecond`: Đây là tốc độ dữ liệu được gửi hoặc nhận trong một luồng mạng, được đo bằng byte mỗi giây.<br>

# %% [markdown]
# - `flowPktsPerSecond`: Đây là tốc độ gói tin được gửi hoặc nhận trong một luồng mạng, được đo bằng gói tin mỗi giây.<br>

# %% [markdown]
# - `min_fiat`, `min_biat`, `max_fiat`, `max_biat`, `mean_fiat`, `mean_biat`: Đây là thời gian chờ giữa các gói tin tối thiểu, tối đa, và trung bình (trung bình cộng) theo hướng đi và hướng về tương ứng.<br>

# %% [markdown]
# ## Phase 2: Xử lý dữ liệu

# %% [markdown]
# ### 1) Khám phá dữ liệu ban đầu

# %% [markdown]
# - Khám phá dữ liệu ban đầu, kiểm tra xem có dữ liệu nào bị thiếu không

# %%
vpn30s.isna().sum()
# Out:
# duration              0
# total_fiat            0
# total_biat            0
# min_fiat              0
# min_biat              0
# max_fiat              0
# max_biat              0
# mean_fiat             0
# mean_biat             0
# flowPktsPerSecond     0
# flowBytesPerSecond    0
# min_flowiat           0
# max_flowiat           0
# mean_flowiat          0
# std_flowiat           0
# min_active            0
# mean_active           0
# max_active            0
# std_active            0
# min_idle              0
# mean_idle             0
# max_idle              0
# std_idle              0
# class1                0
# dtype: int64

# %%
novpn30s.isna().sum()
# Out:
# duration              0
# total_fiat            0
# total_biat            0
# min_fiat              0
# min_biat              0
# max_fiat              0
# max_biat              0
# mean_fiat             0
# mean_biat             0
# flowPktsPerSecond     0
# flowBytesPerSecond    0
# min_flowiat           0
# max_flowiat           0
# mean_flowiat          0
# std_flowiat           0
# min_active            0
# mean_active           0
# max_active            0
# std_active            0
# min_idle              0
# mean_idle             0
# max_idle              0
# std_idle              0
# class1                0
# dtype: int64

# %% [markdown]
# - Để dễ nhìn hơn thì chúng ta sẽ mô hình hóa dưới dạng bar chart sử dụng thư viện `missingno` (msno)

# %%
import missingno as msno

msno.bar(vpn30s)
plt.show()
msno.bar(novpn30s)
plt.show()

# %% [markdown]
# ### 2) Làm sạch dữ liệu:
#
# - Xử lí các giá trị bị thiếu (nếu có).
# - Loại bỏ hoặc điền (fill) các giá trị cho các hàng/cột bị thiếu đó.

# %%
# Giả sử có giá trị nào bị thiếu, bạn có thể xử lý như sau:
# vpn15s = vpn15s.fillna(method='ffill')
# novpn15s = novpn15s.fillna(method='ffill')

# %% [markdown]
# ### 3) Phân tích dữ liệu
#
# - Tính toán các thống kê dữ liệu mô tả (như `mean`, `median`, `std`, ...) và so sánh giữa hai nhóm VPN và No-VPN

# %%
# Thống kê mô tả
vpn_stats = vpn30s.describe()
novpn_stats = novpn30s.describe()

# So sánh thống kê mô tả
stats_comparison = pd.concat([vpn_stats, novpn_stats], axis=1, keys=['VPN', 'No-VPN'])
print(stats_comparison)
# Out:
#                 VPN                                                          \
#            duration    total_fiat    total_biat      min_fiat      min_biat
# count  7.734000e+03  7.734000e+03  7.734000e+03  7.734000e+03  7.734000e+03
# mean   1.517621e+07  1.403221e+07  1.424897e+07  1.539561e+06  1.496921e+06
# std    1.774754e+07  1.315409e+07  1.737406e+07  4.543725e+06  4.484622e+06
# min    0.000000e+00  0.000000e+00  0.000000e+00 -1.000000e+00 -1.000000e+00
# 25%    2.765322e+05  2.105335e+05  2.730200e+04  9.000000e+00  4.000000e+00
# 50%    1.645010e+07  1.525439e+07  1.475092e+07  4.600000e+01  2.700000e+01
# 75%    2.881080e+07  2.830104e+07  2.816430e+07  7.416250e+03  1.112000e+03
# max    6.014050e+08  1.919551e+08  6.011851e+08  3.000000e+07  2.999987e+07
#
#                                                                \
#            max_fiat      max_biat     mean_fiat     mean_biat
# count  7.734000e+03  7.734000e+03  7.734000e+03  7.734000e+03
# mean   5.536056e+06  5.758370e+06  2.150722e+06  2.161737e+06
# std    8.359473e+06  1.418953e+07  4.718912e+06  4.765062e+06
# min   -1.000000e+00 -1.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.876950e+04  2.304025e+04  1.180006e+04  2.611365e+03
# 50%    9.612880e+05  9.614420e+05  2.352641e+05  1.690484e+05
# 75%    1.003862e+07  1.003864e+07  9.604009e+05  9.604448e+05
# max    1.913169e+08  6.001097e+08  3.000000e+07  4.000000e+07
#
#                          ...        No-VPN                              \
#       flowPktsPerSecond  ...  mean_flowiat   std_flowiat    min_active
# count       7734.000000  ...  6.917000e+03  6.917000e+03  6.917000e+03
# mean        3874.476326  ...  9.878067e+05  1.981526e+06  5.563640e+06
# std        22985.683006  ...  3.253778e+06  5.816556e+06  1.804710e+07
# min            0.000000  ...  0.000000e+00  0.000000e+00 -1.000000e+00
# 25%            1.240273  ...  8.844088e+03  5.456165e+03 -1.000000e+00
# 50%            6.406762  ...  3.531083e+04  2.895299e+04 -1.000000e+00
# 75%           76.408529  ...  4.731894e+05  1.265226e+06  3.138500e+06
# max       666666.666667  ...  6.070000e+07  1.360000e+08  3.036184e+08
#
#                                                                              \
#         mean_active    max_active    std_active      min_idle     mean_idle
# count  6.917000e+03  6.917000e+03  6.917000e+03  6.917000e+03  6.917000e+03
# mean   6.391502e+06  7.432642e+06  1.028695e+06  5.362066e+06  6.124968e+06
# std    1.822546e+07  1.898869e+07  4.348328e+06  1.796432e+07  1.814202e+07
# min    0.000000e+00 -1.000000e+00  0.000000e+00 -1.000000e+00  0.000000e+00
# 25%    0.000000e+00 -1.000000e+00  0.000000e+00 -1.000000e+00  0.000000e+00
# 50%    0.000000e+00 -1.000000e+00  0.000000e+00 -1.000000e+00  0.000000e+00
# 75%    5.939942e+06  9.760161e+06  0.000000e+00  2.613275e+06  5.117617e+06
# max    3.040000e+08  3.036184e+08  8.960000e+07  3.035957e+08  3.040000e+08
#
#
#            max_idle      std_idle
# count  6.917000e+03  6.917000e+03
# mean   7.110196e+06  9.680890e+05
# std    1.887580e+07  4.291335e+06
# min   -1.000000e+00  0.000000e+00
# 25%   -1.000000e+00  0.000000e+00
# 50%   -1.000000e+00  0.000000e+00
# 75%    8.622118e+06  0.000000e+00
# max    3.035957e+08  8.980000e+07
#
# [8 rows x 46 columns]

# %% [markdown]
# - Vẽ biểu đồ phân phối cho mỗi cột để so sánh giữa VPN và No-VPN

# %%
# Vẽ biểu đồ phân phối cho mỗi cột
import matplotlib.pyplot as plt
import seaborn as sns

# Số lượng biểu đồ bạn muốn hiển thị trên mỗi hàng và cột
num_rows = 6
num_cols = 4

# Tạo figure và axes
fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 30))

# Duyệt qua mỗi cột và vẽ biểu đồ
for i, column in enumerate(vpn30s.columns):
    if column != 'class1':  # Loại trừ cột 'class1' vì không rõ cột này để làm gì
        row = i // num_cols
        col = i % num_cols
        sns.distplot(vpn30s[column], ax=axes[row, col], label='VPN')
        sns.distplot(novpn30s[column], ax=axes[row, col], label='No-VPN')
        axes[row, col].set_title(f'Phân phối của {column}')
        axes[row, col].legend()

# Điều chỉnh layout để không có chồng chéo
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### - Phân tích biểu đồ phân phối:
# - Dữ liệu phân phối lệch nhiều về bên phải ở cả 2 dataset VPN và No-VPN.
# - Ta có thể thấy rằng:
#     + VPN: Phân phối nhiều hơn ở cột `duration`, `total_biat`, `max_biat`, `mean_biat`, `flowPktsPerSecond`, `min_flowiat`, `max_flowiat`, `min_active`, `mean_active`, `max_active`, `std_active`, `mean_idle`, `max_idle`, `std_idle`.
#     + Trong khi No-VPN sẽ phân phối nhiều hơn ở những cột còn lại.
# - Kết luận:
#     + VPN: Các cột như `duration`, `total_biat`, và `mean_biat` có phân phối nhiều hơn có thể liên quan đến đặc điểm của lưu lượng VPN, chẳng hạn như thời gian kết nối dài hơn hoặc thời gian giữa các gói tin lớn hơn.
#     + No-VPN: Các cột có phân phối nhiều hơn trong No-VPN có thể phản ánh đặc điểm của lưu lượng internet thông thường mà không qua VPN.
#
# <br>

# %% [markdown]
# - Thực hiện kiểm định thống kê cho mỗi cột để xác định sự khác biệt có ý nghĩa.

# %%
from scipy.stats import ttest_ind
from IPython.display import display

# Giả sử vpn15s và novpn15s là DataFrames của bạn chứa dữ liệu VPN và no-VPN

# Kiểm định t-test cho mỗi cột
results = []
for column in vpn30s.columns:
    if column != 'class1':  # Loại trừ cột 'class1'
        t_stat, p_val = ttest_ind(vpn30s[column].dropna(), novpn30s[column].dropna())
        results.append((column, t_stat, p_val))

# Chuyển kết quả thành DataFrame để dễ dàng xem và phân tích
results_df = pd.DataFrame(results, columns=['Column', 'T-statistic', 'P-value'])

# Hiển thị DataFrame
print(results_df)
# Out:
#                 Column  T-statistic       P-value
# 0             duration    -7.462274  8.982020e-14
# 1           total_fiat    -7.910098  2.754860e-15
# 2           total_biat    -0.785053  4.324351e-01
# 3             min_fiat    12.165155  6.942501e-34
# 4             min_biat    12.187067  5.321603e-34
# 5             max_fiat    -2.171848  2.988309e-02
# 6             max_biat     7.018194  2.346244e-12
# 7            mean_fiat     7.826974  5.338176e-15
# 8            mean_biat    13.517523  2.182315e-41
# 9    flowPktsPerSecond     4.881440  1.064236e-06
# 10  flowBytesPerSecond    -3.826632  1.304484e-04
# 11         min_flowiat    -0.939248  3.476189e-01
# 12         max_flowiat    -2.994189  2.756351e-03
# 13        mean_flowiat     1.786207  7.408650e-02
# 14         std_flowiat    -1.400060  1.615165e-01
# 15          min_active    -2.746326  6.034041e-03
# 16         mean_active    -2.400394  1.638984e-02
# 17          max_active    -1.895815  5.800422e-02
# 18          std_active     1.505564  1.322008e-01
# 19            min_idle    -3.503804  4.600309e-04
# 20           mean_idle    -3.317630  9.100567e-04
# 21            max_idle    -3.110926  1.868597e-03
# 22            std_idle     0.426996  6.693886e-01

# %% [markdown]
# ##### - Phân tích kết quả kiểm định thống kê:
# - Giá trị `T-statistic`: Giá trị cao (về âm hay dương) cho thấy sự khác biệt lớn giữa 2 nhóm.
# - Giá trị `P-value`: Một P-value thấp (thường dưới 0.05) cho thấy sự khác biệt có ý nghĩa thống kê. Trong trường hợp trên, các cột như `duration`, `total_fiat`, `min_fiat`, v.v., có P-value rất thấp, cho thấy sự khác biệt đáng kể giữa VPN và No-VPN.
#     + VD: `duration` có `T-statistic` là -10.306134 và `P-value` là 7.700747e−25 có nghĩa rằng có sự khác biệt rất lớn về thời gian kết nối (duration) giữa VPN và No-VPN
#
# <br>

# %% [markdown]
# - Tính toán ma trận tương quan cho toàn bộ cột và so sánh giữa hai nhóm.

# %%
# Loại bỏ cột 'class1' hoặc bất kỳ cột nào chứa chuỗi
vpn_numeric = vpn30s.select_dtypes(include=[np.number])
novpn_numeric = novpn30s.select_dtypes(include=[np.number])

# Ma trận tương quan cho VPN
vpn_corr = vpn_numeric.corr()

# Ma trận tương quan cho no-VPN
novpn_corr = novpn_numeric.corr()

# Thiết lập kích thước của biểu đồ
plt.figure(figsize=(30, 10))

# So sánh ma trận tương quan
corr_comparison = pd.concat([vpn_corr, novpn_corr], axis=1, keys=['VPN', 'No-VPN'])
sns.heatmap(corr_comparison, annot=True, fmt=".2f", annot_kws={'size': 8})
plt.show()

# %% [markdown]
# ##### - Trong ma trận tương quan, cần chú ý:
# - Đường chéo sẽ luôn bằng 1 vì một giá trị sẽ luôn có quan hệ chặt chẽ với chính nó.
# - Màu càng tối thì quan hệ càng yếu, màu càng sáng thì quan hệ với nhau càng chặt chẽ.
#
# <br>

# %% [markdown]
# - Mình sẽ remove đi một vài giá trị không sử dụng đến để quá trình phân tích trở nên đơn giản hơn:

# %%
to_drop = ['class1']

vpn30s.drop(to_drop, inplace = True, axis = 1)
novpn30s.drop(to_drop, inplace = True, axis = 1)

vpn30s.head(21)
# Out:
#        duration  total_fiat   total_biat  min_fiat  min_biat    max_fiat  \
# 0     2218398.0   2191528.0    2192676.0       9.0      17.0     60217.0
# 1     3517813.0   3517813.0    3304404.0       6.0       7.0    324059.0
# 2    24120341.0  23990439.0   23990943.0       4.0      14.0   4969763.0
# 3    21936793.0  21807309.0   21806667.0       0.0       0.0   3906748.0
# 4      270207.0    203681.0     244006.0      15.0      10.0     27147.0
# 5      386584.0    319144.0     360487.0      23.0      10.0     37637.0
# 6    24630316.0  24460265.0   24496889.0      46.0      23.0  23772662.0
# 7    10897973.0  10897973.0   10758647.0      13.0      10.0   7696125.0
# 8     1314540.0   1314535.0    1183635.0       7.0      17.0    132666.0
# 9    16859667.0  16834434.0   16834136.0       8.0      11.0  15188495.0
# 10   25450000.0  25423961.0   25424577.0       4.0      10.0  20661527.0
# 11    6613711.0   6548606.0    6588175.0      11.0      11.0   6146080.0
# 12   25693300.0  25627850.0   25667740.0       2.0      12.0   5379801.0
# 13    1301009.0   1301009.0    1060668.0       2.0      17.0    231368.0
# 14    6496273.0   6431093.0    6470928.0      28.0      18.0   5323248.0
# 15    1356118.0   1330893.0    1330434.0      22.0      14.0    862241.0
# 16    6881637.0   6856085.0    6856099.0       6.0      13.0   1358719.0
# 17   23114507.0  22985242.0   22980279.0      46.0      22.0  10156934.0
# 18    1301313.0   1123688.0    1095209.0      57.0      29.0    433543.0
# 19   11918514.0  11788396.0   11787325.0       4.0      19.0   2514227.0
# 20  601185075.0   1114228.0  600965621.0      20.0      22.0    224169.0
#
#        max_biat      mean_fiat     mean_biat  flowPktsPerSecond  ...  \
# 
0.000000e+00         -1.0  0.000000e+00         -1.0  0.000000e+00
# 20  0.000000e+00         -1.0  0.000000e+00         -1.0  0.000000e+00
#
# [21 rows x 23 columns]

# %% [markdown]
# ##### - Kiểm tra lại mức độ chặt chẽ:

# %%
plt.figure(figsize = (18, 12))

vpn_corr = vpn30s.corr()
novpn_corr = novpn30s.corr()

# Thiết lập kích thước của biểu đồ
plt.figure(figsize=(30, 10))

# So sánh ma trận tương quan
corr_comparison = pd.concat([vpn_corr, novpn_corr], axis=1, keys=['VPN', 'No-VPN'])
sns.heatmap(corr_comparison, annot=True, fmt=".2f", annot_kws={'size': 8})
plt.show()

# %%
vpn30s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7734 entries, 0 to 7733
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   duration            7734 non-null   float64
#  1   total_fiat          7734 non-null   float64
#  2   total_biat          7734 non-null   float64
#  3   min_fiat            7734 non-null   float64
#  4   min_biat            7734 non-null   float64
#  5   max_fiat            7734 non-null   float64
#  6   max_biat            7734 non-null   float64
#  7   mean_fiat           7734 non-null   float64
#  8   mean_biat           7734 non-null   float64
#  9   flowPktsPerSecond   7734 non-null   float64
#  10  flowBytesPerSecond  7734 non-null   float64
#  11  min_flowiat         7734 non-null   float64
#  12  max_flowiat         7734 non-null   float64
#  13  mean_flowiat        7734 non-null   float64
#  14  std_flowiat         7734 non-null   float64
#  15  min_active          7734 non-null   float64
#  16  mean_active         7734 non-null   float64
#  17  max_active          7734 non-null   float64
#  18  std_active          7734 non-null   float64
#  19  min_idle            7734 non-null   float64
#  20  mean_idle           7734 non-null   float64
#  21  max_idle            7734 non-null   float64
#  22  std_idle            7734 non-null   float64
# dtypes: float64(23)
# memory usage: 1.4 MB

# %%
novpn30s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6917 entries, 0 to 6916
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   duration            6917 non-null   float64
#  1   total_fiat          6917 non-null   float64
#  2   total_biat          6917 non-null   float64
#  3   min_fiat            6917 non-null   float64
#  4   min_biat            6917 non-null   float64
#  5   max_fiat            6917 non-null   float64
#  6   max_biat            6917 non-null   float64
#  7   mean_fiat           6917 non-null   float64
#  8   mean_biat           6917 non-null   float64
#  9   flowPktsPerSecond   6917 non-null   float64
#  10  flowBytesPerSecond  6917 non-null   float64
#  11  min_flowiat         6917 non-null   float64
#  12  max_flowiat         6917 non-null   float64
#  13  mean_flowiat        6917 non-null   float64
#  14  std_flowiat         6917 non-null   float64
#  15  min_active          6917 non-null   float64
#  16  mean_active         6917 non-null   float64
#  17  max_active          6917 non-null   float64
#  18  std_active          6917 non-null   float64
#  19  min_idle            6917 non-null   float64
#  20  mean_idle           6917 non-null   float64
#  21  max_idle            6917 non-null   float64
#  22  std_idle            6917 non-null   float64
# dtypes: float64(23)
# memory usage: 1.2 MB

# %% [markdown]
# - Chuyển lại dataset đã được làm sạch về dạng csv để chuẩn bị cho việc train model

# %%
vpn30s.to_csv('./clean_data/vpn30s_cleaned.csv', index=False)
novpn30s.to_csv('./clean_data/novpn30s_cleaned.csv', index=False)

# %% [markdown]
# ## Phrase 3: Huấn luyện Model

# %% [markdown]
# #### Ở đây, với 2 dataset đã được xử lý, mình sẽ thử train thuật toán K-Nearest Neighbors và Decision Tree để xác định model nào hiệu quả hơn trong việc phân loại

# %% [markdown]
# ##### K-Nearest Neighbors:

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

#read data
yes_df = pd.read_csv('clean_data/vpn30s_cleaned.csv')
no_df = pd.read_csv('clean_data/novpn30s_cleaned.csv')


# Create labels for dataset
yes_df['label'] = 1  
no_df['label'] = 0   

#combine 2 dataset
combined_df = pd.concat([yes_df, no_df], ignore_index=True)

# separate features and specify target variable
X = combined_df.drop(columns=['label'])
y = combined_df['label']

#split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#specifying the category and numerical columns
cate_cols=[cname for cname in X_train.columns if X_train[cname].dtype=="object"]
nume_cols=[cname for cname in X_train.columns if X_train[cname].dtype in ['int64','float64']]

# preprocessing to deal with different type of datas
# Preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy='constant')

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, nume_cols),
        ('cat', categorical_transformer, cate_cols)
    ])


# train the model
knn = Pipeline(steps=[('preprocessor', preprocessor),
                    ('model', KNeighborsClassifier(n_neighbors=5))
                             ])
knn.fit(X_train, y_train)

# predicting some value
y_pred = knn.predict(X_test)

# evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# print the report
print(classification_report(y_test, y_pred))

# view some first prediction
print("First few predictions:", y_pred[:5])
print("First few actual values:", y_test[:5].values)

# Generate matrix
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No VPN', 'VPN'], yticklabels=['No VPN', 'VPN'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy: 0.79
#               precision    recall  f1-score   support
#
#            0       0.77      0.80      0.78      2082
#            1       0.81      0.79      0.80      2314
#
#     accuracy                           0.79      4396
#    macro avg       0.79      0.79      0.79      4396
# weighted avg       0.79      0.79      0.79      4396
#
# First few predictions: [1 0 0 0 0]
# First few actual values: [1 0 0 0 1]

# %% [markdown]
# ##### Decision Tree

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

#read data
yes_df = pd.read_csv('clean_data/vpn30s_cleaned.csv')
no_df = pd.read_csv('clean_data/novpn30s_cleaned.csv')


# Create labels for dataset
yes_df['label'] = 1  
no_df['label'] = 0   

#combine 2 dataset
combined_df = pd.concat([yes_df, no_df], ignore_index=True)

# separate features and specify target variable
X = combined_df.drop(columns=['label'])
y = combined_df['label']

#split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#specifying the category and numerical columns
cate_cols=[cname for cname in X_train.columns if X_train[cname].dtype=="object"]
nume_cols=[cname for cname in X_train.columns if X_train[cname].dtype in ['int64','float64']]

# preprocessing to deal with different type of datas
# Preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy='constant')

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, nume_cols),
        ('cat', categorical_transformer, cate_cols)
    ])


# train the model
knn = Pipeline(steps=[('preprocessor', preprocessor),
                    ('model', DecisionTreeClassifier(max_leaf_nodes=1000))
                             ])
knn.fit(X_train, y_train)

# predicting some value
y_pred = knn.predict(X_test)

# evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# print the report
print(classification_report(y_test, y_pred))

# view some first prediction
print("First few predictions:", y_pred[:5])
print("First few actual values:", y_test[:5].values)

# Generate matrix
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No VPN', 'VPN'], yticklabels=['No VPN', 'VPN'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy: 0.87
#               precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86      2082
#            1       0.87      0.88      0.88      2314
#
#     accuracy                           0.87      4396
#    macro avg       0.87      0.87      0.87      4396
# weighted avg       0.87      0.87      0.87      4396
#
# First few predictions: [1 0 0 0 1]
# First few actual values: [1 0 0 0 1]

# %% [markdown]
# ##### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegressionCV
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

#read data
yes_df = pd.read_csv('clean_data/vpn30s_cleaned.csv')
no_df = pd.read_csv('clean_data/novpn30s_cleaned.csv')


# Create labels for dataset
yes_df['label'] = 1  
no_df['label'] = 0   

#combine 2 dataset
combined_df = pd.concat([yes_df, no_df], ignore_index=True)

# separate features and specify target variable
X = combined_df.drop(columns=['label'])
y = combined_df['label']

#split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#specifying the category and numerical columns
cate_cols=[cname for cname in X_train.columns if X_train[cname].dtype=="object"]
nume_cols=[cname for cname in X_train.columns if X_train[cname].dtype in ['int64','float64']]

# preprocessing to deal with different type of datas
# Preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy='constant')

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, nume_cols),
        ('cat', categorical_transformer, cate_cols)
    ])
cpu_cores=8
lr=Pipeline(steps=[('preprocessor', preprocessor),
                    ('model', LogisticRegressionCV(n_jobs=cpu_cores,solver='liblinear'))
                             ])
lr.fit(X_train,y_train)

# predicting some value
y_pred = lr.predict(X_test)

# evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# print the report
print(classification_report(y_test, y_pred))

# view some first prediction
print("First few predictions:", y_pred[:5])
print("First few actual values:", y_test[:5].values)

# Generate matrix
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No VPN', 'VPN'], yticklabels=['No VPN', 'VPN'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy: 0.64
#               precision    recall  f1-score   support
#
#            0       0.70      0.42      0.52      2082
#            1       0.62      0.84      0.71      2314
#
#     accuracy                           0.64      4396
#    macro avg       0.66      0.63      0.62      4396
# weighted avg       0.66      0.64      0.62      4396
#
# First few predictions: [1 1 0 0 1]
# First few actual values: [1 0 0 0 1]

# %% [markdown]
# ##### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

#read data
yes_df = pd.read_csv('clean_data/vpn30s_cleaned.csv')
no_df = pd.read_csv('clean_data/novpn30s_cleaned.csv')


# Create labels for dataset
yes_df['label'] = 1  
no_df['label'] = 0   

#combine 2 dataset
combined_df = pd.concat([yes_df, no_df], ignore_index=True)

# separate features and specify target variable
X = combined_df.drop(columns=['label'])
y = combined_df['label']

#split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#specifying the category and numerical columns
cate_cols=[cname for cname in X_train.columns if X_train[cname].dtype=="object"]
nume_cols=[cname for cname in X_train.columns if X_train[cname].dtype in ['int64','float64']]

# preprocessing to deal with different type of datas
# Preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy='constant')

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, nume_cols),
        ('cat', categorical_transformer, cate_cols)
    ])
cpu_cores=8
# Train the model based on best optimized args
rf=Pipeline(steps=[('preprocessor', preprocessor),
                    ('model', RandomForestClassifier(n_jobs=cpu_cores,n_estimators=7000))
                             ])
rf.fit(X_train,y_train)

# predicting some value
y_pred = rf.predict(X_test)

# evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# print the report
print(classification_report(y_test, y_pred))

# view some first prediction
print("First few predictions:", y_pred[:5])
print("First few actual values:", y_test[:5].values)

# Generate matrix
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No VPN', 'VPN'], yticklabels=['No VPN', 'VPN'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy: 0.90
#               precision    recall  f1-score   support
#
#            0       0.91      0.88      0.90      2082
#            1       0.90      0.93      0.91      2314
#
#     accuracy                           0.90      4396
#    macro avg       0.90      0.90      0.90      4396
# weighted avg       0.90      0.90      0.90      4396
#
# First few predictions: [1 0 0 0 1]
# First few actual values: [1 0 0 0 1]

# %% [markdown]
# ### Kết luận:
#
# - KNN: Mô hình này có độ chính xác khá cao (0.79) và sự cân bằng giữa precision và recall cho cả hai lớp, cho thấy khả năng phân loại tốt. Tuy nhiên, KNN có thể không phải là lựa chọn tối ưu nếu kích thước dữ liệu lớn do độ phức tạp tính toán cao và thời gian dự đoán chậm.
# - Decision Tree: Với độ chính xác 0.87, mô hình này cho thấy khả năng phân biệt tốt giữa VPN và No VPN. Cây quyết định cũng dễ diễn giải và triển khai, nhưng có thể dễ bị overfitting nếu không được cắt tỉa đúng cách.
# - Logistic Regression: Mặc dù có độ chính xác thấp nhất (0.64), logistic regression là mô hình đơn giản và nhanh chóng trong việc huấn luyện và dự đoán. Tuy nhiên, kết quả cho thấy mô hình này có xu hướng dự đoán ‘VPN’ nhiều hơn, có thể không phù hợp cho việc điều chỉnh băng thông mạng một cách chính xác.
# - Random Forest: Đây là mô hình có hiệu suất cao nhất với độ chính xác 0.90 và sự cân bằng giữa precision và recall. Random Forest là sự kết hợp của nhiều cây quyết định, giúp giảm thiểu nguy cơ overfitting và tăng cường độ tin cậy của dự đoán.
#
# ##### -> Kết luận: Random Forest là mô hình phù hợp nhất cho mục tiêu của nhóm (phân loại VPN/No-VPN để điều chỉnh băng thông mạng) với hiệu suất cao và khả năng phân loại chính xác nhất.
