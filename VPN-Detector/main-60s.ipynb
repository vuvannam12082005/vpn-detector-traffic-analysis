# %% [markdown]
# # Applied Stats - Thống kê Ứng dụng

# %% [markdown]
# ## Phrase 1: Phân tích dữ liệu:

# %% [markdown]
# ### 1) Import các thư viện cần thiết:
# - `pandas` (pd): Thư viện này được sử dụng để xử lý và phân tích dữ liệu. Nó cung cấp các đối tượng như DataFrame và Series để làm việc với dữ liệu dạng bảng.
# - `pyscipy.io.arff`: Đây là một module trong thư viện SciPy, được sử dụng để đọc và ghi dữ liệu trong định dạng ARFF (Attribute-Relation File Format), một định dạng phổ biến trong lĩnh vực khoa học dữ liệu.
# - `numpy` (np): Thư viện này cung cấp hỗ trợ cho mảng và ma trận lớn, cùng với một bộ sưu tập lớn các hàm toán học để thao tác với các mảng này.
# - `matplotlib.pyplot` (plt): Đây là một thư viện vẽ đồ thị 2D trong Python, cho phép bạn vẽ nhiều loại đồ thị như đồ thị dạng line, bar, scatter, histogram, etc.
# - `warnings`: Ngăn chặn việc hiển thị các cảnh báo từ Python hoặc các thư viện khác. Giúp cho output trông gọn hơn.
# - `seaborn` (sns): Vẽ biểu đồ

# %%
import pandas as pd
from scipy.io import arff
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

plt.style.use('ggplot')

# %% [markdown]
# ### 2) Đọc file dataset và biểu diễn dạng bảng

# %% [markdown]
# a) VPN Dataset:

# %%
data = arff.loadarff('data/Scenario-A2-ARFF/TimeBasedFeatures-Dataset-60s-VPN.arff')
vpn60s = pd.DataFrame(data[0])
vpn60s.head()
# Out:
#      duration  total_fiat  total_biat  min_fiat  min_biat    max_fiat  \
# 0   2218398.0   2191528.0   2192676.0       9.0      17.0     60217.0
# 1  48738520.0  48524188.0  48525131.0       6.0       7.0  45006375.0
# 2    270207.0    203681.0    244006.0      15.0      10.0     27147.0
# 3  59069229.0  59069229.0  59004989.0      23.0      10.0  58685690.0
# 4  55595001.0  55424950.0  55464526.0      32.0      23.0  23772662.0
#
#      max_biat      mean_fiat     mean_biat  flowPktsPerSecond  ...  \
# 0     86113.0     601.077345    370.009450        4315.726934  ...
# 1  45220727.0   19495.455203  14664.590813         119.002383  ...
# 2     66572.0     593.822157    363.104167        3763.781101  ...
# 3  58644456.0  191162.553398  86138.670073          16.861571  ...
# 4  23731260.0  170015.184049  88038.930159          17.231765  ...
#
#     std_flowiat  min_active  mean_active  max_active    std_active  \
# 0  1.815741e+03        -1.0          0.0        -1.0  0.000000e+00
# 1  5.910799e+05  48524188.0   48500000.0  48524188.0  0.000000e+00
# 2  2.648294e+03        -1.0          0.0        -1.0  0.000000e+00
# 3  1.858312e+06  59004834.0   59000000.0  59004834.0  0.000000e+00
# 4  1.023973e+06  15447930.0   18400000.0  24327021.0  5.106593e+06
#
#      min_idle   mean_idle    max_idle      std_idle           class1
# 0        -1.0         0.0        -1.0  0.000000e+00  b'VPN-BROWSING'
# 1  45006375.0  45000000.0  45006375.0  0.000000e+00  b'VPN-BROWSING'
# 2        -1.0         0.0        -1.0  0.000000e+00  b'VPN-BROWSING'
# 3  58618250.0  58600000.0  58618250.0  0.000000e+00  b'VPN-BROWSING'
# 4  14941349.0  17800000.0  23598957.0  4.979308e+06  b'VPN-BROWSING'
#
# [5 rows x 24 columns]

# %% [markdown]
# b) No-VPN Dataset:

# %%
data = arff.loadarff('data/Scenario-A2-ARFF/TimeBasedFeatures-Dataset-60s-NO-VPN.arff')
novpn60s = pd.DataFrame(data[0])
novpn60s.head()
# Out:
#       duration   total_fiat  total_biat  min_fiat  min_biat     max_fiat  \
# 0   59883459.0   59883459.0  59849438.0       1.0       0.0    1399330.0
# 1   59999989.0   59998050.0  59972809.0       0.0       0.0     957051.0
# 2  143704195.0  143704195.0  42106019.0       0.0       0.0  101572528.0
# 3   59162045.0   59161897.0  59160676.0       7.0       0.0     819852.0
# 4   59856466.0   59856466.0  59824081.0       7.0       0.0     719610.0
#
#     max_biat     mean_fiat    mean_biat  flowPktsPerSecond  ...  \
# 0  1211310.0   1931.226103   406.823538        2974.510875  ...
# 1   757034.0   2979.345019   690.469606        1783.300327  ...
# 2   854818.0   6986.105737   636.898837         603.204381  ...
# 3   819602.0   9619.820650  2218.164898         554.798266  ...
# 4   757561.0  10661.999644  2438.315916         503.721686  ...
#
#      std_flowiat   min_active  mean_active   max_active  std_active  \
# 0    9850.495335    1753114.0   11300000.0   39438693.0  16000000.0
# 1    7590.960502         -1.0          0.0         -1.0         0.0
# 2  345078.175888  143704195.0  144000000.0  143704195.0         0.0
# 3   16392.609675         -1.0          0.0         -1.0         0.0
# 4   18541.554847         -1.0          0.0         -1.0         0.0
#
#       min_idle    mean_idle     max_idle      std_idle       class1
# 0    1014624.0    1139537.6    1208289.0  74997.385381  b'BROWSING'
# 1         -1.0          0.0         -1.0      0.000000  b'BROWSING'
# 2  101572528.0  102000000.0  101572528.0      0.000000  b'BROWSING'
# 3         -1.0          0.0         -1.0      0.000000  b'BROWSING'
# 4         -1.0          0.0         -1.0      0.000000  b'BROWSING'
#
# [5 rows x 24 columns]

# %% [markdown]
# ### 3) Nhận định cấu trúc dữ liệu

# %% [markdown]
# ##### - Đầu tiên, chúng ta sẽ chạy lệnh `describe()` để lấy thông tin đã được thống kê lại từ các cột trong dataset:

# %% [markdown]
# - count: Số lượng quan sát (entries) không bị thiếu trong dataset.
# - mean: Giá trị trung bình của dữ liệu.
# - std: Độ lệch chuẩn, đo lường mức độ phân tán của dữ liệu so với giá trị trung bình.
# - min: Giá trị nhỏ nhất trong dataset.
# - 25%: Phân vị thứ 25, còn được gọi là phân vị thứ nhất hoặc Q1, là giá trị mà 25% dữ liệu nằm dưới nó.
# - 50%: Phân vị thứ 50, còn được gọi là trung vị, là giá trị chia dataset làm đôi.
# - 75%: Phân vị thứ 75, còn được gọi là phân vị thứ ba hoặc Q3, là giá trị mà 75% dữ liệu nằm dưới nó.
# - max: Giá trị lớn nhất trong dataset.

# %% [markdown]
# ##### - Sau đó chúng ta sẽ chạy lệnh `columns` để in ra thông tin các cột trong bảng dữ liệu

# %% [markdown]
# a) VPN Dataset:

# %%
vpn60s.describe()
# Out:
#            duration    total_fiat    total_biat      min_fiat      min_biat  \
# count
.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8580 entries, 0 to 8579
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   duration            8580 non-null   float64
#  1   total_fiat          8580 non-null   float64
#  2   total_biat          8580 non-null   float64
#  3   min_fiat            8580 non-null   float64
#  4   min_biat            8580 non-null   float64
#  5   max_fiat            8580 non-null   float64
#  6   max_biat            8580 non-null   float64
#  7   mean_fiat           8580 non-null   float64
#  8   mean_biat           8580 non-null   float64
#  9   flowPktsPerSecond   8580 non-null   float64
#  10  flowBytesPerSecond  8580 non-null   float64
#  11  min_flowiat         8580 non-null   float64
#  12  max_flowiat         8580 non-null   float64
#  13  mean_flowiat        8580 non-null   float64
#  14  std_flowiat         8580 non-null   float64
#  15  min_active          8580 non-null   float64
#  16  mean_active         8580 non-null   float64
#  17  max_active          8580 non-null   float64
#  18  std_active          8580 non-null   float64
#  19  min_idle            8580 non-null   float64
#  20  mean_idle           8580 non-null   float64
#  21  max_idle            8580 non-null   float64
#  22  std_idle            8580 non-null   float64
#  23  class1              8580 non-null   object
# dtypes: float64(23), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# ##### - Giải thích qua về các cột trong dataset này:

# %% [markdown]
# - `duration`: Đây là thời gian tồn tại của một kết nối mạng.<br>

# %% [markdown]
# - `total_fiat` and `total_biat`: Đây là tổng thời gian chờ giữa các gói tin (FIAT và BIAT) theo hướng đi (từ nguồn đến đích) và hướng về (từ đích về nguồn) tương ứng.<br>

# %% [markdown]
# - `class1`: Đây có thể là nhãn hoặc phân loại được gán cho luồng mạng dựa trên các tiêu chí nhất định, như loại lưu lượng hoặc ứng dụng tạo ra lưu lượng (hiện tại chưa chắc chắn).<br>

# %% [markdown]
# - `min_idle`, `mean_idle`, `max_idle`, `std_idle`: Đây là thời gian nhàn rỗi tối thiểu, trung bình, tối đa, và độ lệch chuẩn trong một luồng mạng. Thời gian nhàn rỗi là khoảng thời gian khi luồng không truyền dữ liệu.<br>

# %% [markdown]
# - `min_active`, `mean_active`, `max_active`, `std_active`: Đây là thời gian hoạt động tối thiểu, trung bình, tối đa, và độ lệch chuẩn trong một luồng mạng. Thời gian hoạt động là khoảng thời gian khi luồng đang truyền dữ liệu một cách tích cực.<br>

# %% [markdown]
# - `min_flowiat`, `max_flowiat`, `mean_flowiat`, `std_flowiat`: Đây là thời gian chờ giữa các gói tin tối thiểu, tối đa, trung bình, và độ lệch chuẩn trong một luồng mạng.<br>

# %% [markdown]
# - `flowBytesPerSecond`: Đây là tốc độ dữ liệu được gửi hoặc nhận trong một luồng mạng, được đo bằng byte mỗi giây.<br>

# %% [markdown]
# - `flowPktsPerSecond`: Đây là tốc độ gói tin được gửi hoặc nhận trong một luồng mạng, được đo bằng gói tin mỗi giây.<br>

# %% [markdown]
# - `min_fiat`, `min_biat`, `max_fiat`, `max_biat`, `mean_fiat`, `mean_biat`: Đây là thời gian chờ giữa các gói tin tối thiểu, tối đa, và trung bình (trung bình cộng) theo hướng đi và hướng về tương ứng.<br>

# %% [markdown]
# ## Phase 2: Xử lý dữ liệu

# %% [markdown]
# ### 1) Khám phá dữ liệu ban đầu

# %% [markdown]
# - Khám phá dữ liệu ban đầu, kiểm tra xem có dữ liệu nào bị thiếu không

# %%
vpn60s.isna().sum()
# Out:
# duration              0
# total_fiat            0
# total_biat            0
# min_fiat              0
# min_biat              0
# max_fiat              0
# max_biat              0
# mean_fiat             0
# mean_biat             0
# flowPktsPerSecond     0
# flowBytesPerSecond    0
# min_flowiat           0
# max_flowiat           0
# mean_flowiat          0
# std_flowiat           0
# min_active            0
# mean_active           0
# max_active            0
# std_active            0
# min_idle              0
# mean_idle             0
# max_idle              0
# std_idle              0
# class1                0
# dtype: int64

# %%
novpn60s.isna().sum()
# Out:
# duration              0
# total_fiat            0
# total_biat            0
# min_fiat              0
# min_biat              0
# max_fiat              0
# max_biat              0
# mean_fiat             0
# mean_biat             0
# flowPktsPerSecond     0
# flowBytesPerSecond    0
# min_flowiat           0
# max_flowiat           0
# mean_flowiat          0
# std_flowiat           0
# min_active            0
# mean_active           0
# max_active            0
# std_active            0
# min_idle              0
# mean_idle             0
# max_idle              0
# std_idle              0
# class1                0
# dtype: int64

# %% [markdown]
# - Để dễ nhìn hơn thì chúng ta sẽ mô hình hóa dưới dạng bar chart sử dụng thư viện `missingno` (msno)

# %%
import missingno as msno

msno.bar(vpn60s)
plt.show()
msno.bar(novpn60s)
plt.show()

# %% [markdown]
# ### 2) Làm sạch dữ liệu:
#
# - Xử lí các giá trị bị thiếu (nếu có).
# - Loại bỏ hoặc điền (fill) các giá trị cho các hàng/cột bị thiếu đó.

# %%
# Giả sử có giá trị nào bị thiếu, bạn có thể xử lý như sau:
# vpn15s = vpn15s.fillna(method='ffill')
# novpn15s = novpn15s.fillna(method='ffill')

# %% [markdown]
# ### 3) Phân tích dữ liệu
#
# - Tính toán các thống kê dữ liệu mô tả (như `mean`, `median`, `std`, ...) và so sánh giữa hai nhóm VPN và No-VPN

# %%
# Thống kê mô tả
vpn_stats = vpn60s.describe()
novpn_stats = novpn60s.describe()

# So sánh thống kê mô tả
stats_comparison = pd.concat([vpn_stats, novpn_stats], axis=1, keys=['VPN', 'No-VPN'])
print(stats_comparison)
# Out:
#                 VPN                                                          \
#            duration    total_fiat    total_biat      min_fiat      min_biat
# count  6.935000e+03  6.935000e+03  6.935000e+03  6.935000e+03  6.935000e+03
# mean   2.753693e+07  2.615223e+07  2.589795e+07  4.413670e+06  4.247112e+06
# std    2.903729e+07  2.616241e+07  2.852536e+07  1.186144e+07  1.194853e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00 -1.000000e+00 -1.000000e+00
# 25%    1.630965e+05  1.180000e+02  0.000000e+00  2.000000e+00 -1.000000e+00
# 50%    1.784395e+07  1.558075e+07  1.385717e+07  3.900000e+01  2.000000e+01
# 75%    5.602581e+07  5.342353e+07  5.293347e+07  1.277050e+05  6.990000e+02
# max    6.014050e+08  1.919551e+08  6.011851e+08  5.549178e+07  5.992242e+07
#
#                                                                \
#            max_fiat      max_biat     mean_fiat     mean_biat
# count  6.935000e+03  6.935000e+03  6.935000e+03  6.935000e+03
# mean   1.283738e+07  1.282497e+07  5.947396e+06  5.876929e+06
# std    1.833283e+07  2.186392e+07  1.216692e+07  1.228089e+07
# min   -1.000000e+00 -1.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.010000e+02 -1.000000e+00  9.350000e+01  0.000000e+00
# 50%    1.214855e+06  8.920710e+05  2.682695e+05  1.406178e+05
# 75%    2.001225e+07  1.997825e+07  4.586355e+06  4.592881e+06
# max    1.913169e+08  6.001097e+08  5.890000e+07  5.990000e+07
#
#                          ...        No-VPN                              \
#       flowPktsPerSecond  ...  mean_flowiat   std_flowiat    min_active
# count      6.935000e+03  ...  8.580000e+03  8.580000e+03  8.580000e+03
# mean       4.855019e+03  ...  1.738444e+06  4.272096e+06  1.236245e+07
# std        3.543909e+04  ...  5.314956e+06  1.509049e+07  4.827458e+07
# min        0.000000e+00  ...  0.000000e+00  0.000000e+00 -1.000000e+00
# 25%        2.747942e-01  ...  9.999858e+03  6.948425e+03 -1.000000e+00
# 50%        3.997092e+00  ...  1.277427e+05  1.662183e+05 -1.000000e+00
# 75%        4.005677e+01  ...  1.275890e+06  3.740426e+06  7.020704e+06
# max        2.000000e+06  ...  6.470000e+07  2.040000e+08  6.465660e+08
#
#                                                                              \
#         mean_active    max_active    std_active      min_idle     mean_idle
# count  8.580000e+03  8.580000e+03  8.580000e+03  8.580000e+03  8.580000e+03
# mean   1.383458e+07  1.598613e+07  1.930230e+06  1.197025e+07  1.333750e+07
# std    4.829754e+07  4.888606e+07  6.423210e+06  4.815127e+07  4.818478e+07
# min    0.000000e+00 -1.000000e+00  0.000000e+00 -1.000000e+00  0.000000e+00
# 25%    0.000000e+00 -1.000000e+00  0.000000e+00 -1.000000e+00  0.000000e+00
# 50%    0.000000e+00 -1.000000e+00  0.000000e+00 -1.000000e+00  0.000000e+00
# 75%    1.010000e+07  1.339510e+07  3.477389e+04  5.363180e+06  1.000000e+07
# max    6.470000e+08  6.465660e+08  1.840000e+08  6.462877e+08  6.460000e+08
#
#
#            max_idle      std_idle
# count  8.580000e+03  8.580000e+03
# mean   1.529949e+07  1.798066e+06
# std    4.876907e+07  6.305425e+06
# min   -1.000000e+00  0.000000e+00
# 25%   -1.000000e+00  0.000000e+00
# 50%   -1.000000e+00  0.000000e+00
# 75%    1.067287e+07  1.995258e+04
# max    6.462877e+08  1.850000e+08
#
# [8 rows x 46 columns]

# %% [markdown]
# - Vẽ biểu đồ phân phối cho mỗi cột để so sánh giữa VPN và No-VPN

# %%
# Vẽ biểu đồ phân phối cho mỗi cột
import matplotlib.pyplot as plt
import seaborn as sns

# Số lượng biểu đồ bạn muốn hiển thị trên mỗi hàng và cột
num_rows = 6
num_cols = 4

# Tạo figure và axes
fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 30))

# Duyệt qua mỗi cột và vẽ biểu đồ
for i, column in enumerate(vpn60s.columns):
    if column != 'class1':  # Loại trừ cột 'class1' vì không rõ cột này để làm gì
        row = i // num_cols
        col = i % num_cols
        sns.distplot(vpn60s[column], ax=axes[row, col], label='VPN')
        sns.distplot(novpn60s[column], ax=axes[row, col], label='No-VPN')
        axes[row, col].set_title(f'Phân phối của {column}')
        axes[row, col].legend()

# Điều chỉnh layout để không có chồng chéo
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### - Phân tích biểu đồ phân phối:
# - Dữ liệu phân phối lệch nhiều về bên phải ở cả 2 dataset VPN và No-VPN.
# - Ta có thể thấy rằng:
#     + VPN: Phân phối nhiều hơn ở cột `duration`, `total_biat`, `max_biat`, `mean_biat`, `flowPktsPerSecond`, `min_flowiat`, `max_flowiat`, `min_active`, `mean_active`, `max_active`, `std_active`, `mean_idle`, `max_idle`, `std_idle`.
#     + Trong khi No-VPN sẽ phân phối nhiều hơn ở những cột còn lại.
# - Kết luận:
#     + VPN: Các cột như `duration`, `total_biat`, và `mean_biat` có phân phối nhiều hơn có thể liên quan đến đặc điểm của lưu lượng VPN, chẳng hạn như thời gian kết nối dài hơn hoặc thời gian giữa các gói tin lớn hơn.
#     + No-VPN: Các cột có phân phối nhiều hơn trong No-VPN có thể phản ánh đặc điểm của lưu lượng internet thông thường mà không qua VPN.
#
# <br>

# %% [markdown]
# - Thực hiện kiểm định thống kê cho mỗi cột để xác định sự khác biệt có ý nghĩa.

# %%
from scipy.stats import ttest_ind
from IPython.display import display

# Giả sử vpn15s và novpn15s là DataFrames của bạn chứa dữ liệu VPN và no-VPN

# Kiểm định t-test cho mỗi cột
results = []
for column in vpn60s.columns:
    if column != 'class1':  # Loại trừ cột 'class1'
        t_stat, p_val = ttest_ind(vpn60s[column].dropna(), novpn60s[column].dropna())
        results.append((column, t_stat, p_val))

# Chuyển kết quả thành DataFrame để dễ dàng xem và phân tích
results_df = pd.DataFrame(results, columns=['Column', 'T-statistic', 'P-value'])

# Hiển thị DataFrame
print(results_df)
# Out:
#                 Column  T-statistic        P-value
# 0             duration   -12.725175   6.553346e-37
# 1           total_fiat   -11.526545   1.292024e-30
# 2           total_biat    -2.622565   8.735592e-03
# 3             min_fiat    15.382897   5.248245e-53
# 4             min_biat    19.897010   5.242079e-87
# 5             max_fiat    -3.009105   2.624391e-03
# 6             max_biat    13.297396   3.974152e-40
# 7            mean_fiat    11.091685   1.761646e-28
# 8            mean_biat    23.659535  1.328206e-121
# 9    flowPktsPerSecond     4.462844   8.144836e-06
# 10  flowBytesPerSecond    -2.757707   5.827653e-03
# 11         min_flowiat     4.373266   1.231989e-05
# 12         max_flowiat    -2.821520   4.785743e-03
# 13        mean_flowiat     9.740577   2.345734e-22
# 14         std_flowiat     1.958963   5.013500e-02
# 15          min_active    -2.360723   1.825163e-02
# 16         mean_active    -2.442647   1.459106e-02
# 17          max_active    -2.944345   3.241194e-03
# 18          std_active    -2.566645   1.027806e-02
# 19            min_idle    -2.208035   2.725641e-02
# 20           mean_idle    -2.331947   1.971623e-02
# 21            max_idle    -2.832139   4.629725e-03
# 22            std_idle    -2.667980   7.638807e-03

# %% [markdown]
# ##### - Phân tích kết quả kiểm định thống kê:
# - Giá trị `T-statistic`: Giá trị cao (về âm hay dương) cho thấy sự khác biệt lớn giữa 2 nhóm.
# - Giá trị `P-value`: Một P-value thấp (thường dưới 0.05) cho thấy sự khác biệt có ý nghĩa thống kê. Trong trường hợp trên, các cột như `duration`, `total_fiat`, `min_fiat`, v.v., có P-value rất thấp, cho thấy sự khác biệt đáng kể giữa VPN và No-VPN.
#     + VD: `duration` có `T-statistic` là -10.306134 và `P-value` là 7.700747e−25 có nghĩa rằng có sự khác biệt rất lớn về thời gian kết nối (duration) giữa VPN và No-VPN
#
# <br>

# %% [markdown]
# - Tính toán ma trận tương quan cho toàn bộ cột và so sánh giữa hai nhóm.

# %%
# Loại bỏ cột 'class1' hoặc bất kỳ cột nào chứa chuỗi
vpn_numeric = vpn60s.select_dtypes(include=[np.number])
novpn_numeric = novpn60s.select_dtypes(include=[np.number])

# Ma trận tương quan cho VPN
vpn_corr = vpn_numeric.corr()

# Ma trận tương quan cho no-VPN
novpn_corr = novpn_numeric.corr()

# Thiết lập kích thước của biểu đồ
plt.figure(figsize=(30, 10))

# So sánh ma trận tương quan
corr_comparison = pd.concat([vpn_corr, novpn_corr], axis=1, keys=['VPN', 'No-VPN'])
sns.heatmap(corr_comparison, annot=True, fmt=".2f", annot_kws={'size': 8})
plt.show()

# %% [markdown]
# ##### - Trong ma trận tương quan, cần chú ý:
# - Đường chéo sẽ luôn bằng 1 vì một giá trị sẽ luôn có quan hệ chặt chẽ với chính nó.
# - Màu càng tối thì quan hệ càng yếu, màu càng sáng thì quan hệ với nhau càng chặt chẽ.
#
# <br>

# %% [markdown]
# - Mình sẽ remove đi một vài giá trị không sử dụng đến để quá trình phân tích trở nên đơn giản hơn:

# %%
to_drop = ['class1']

vpn60s.drop(to_drop, inplace = True, axis = 1)
novpn60s.drop(to_drop, inplace = True, axis = 1)

vpn60s.head(21)
# Out:
#       duration  total_fiat  total_biat  min_fiat  min_biat    max_fiat  \
# 0    2218398.0   2191528.0   2192676.0       9.0      17.0     60217.0
# 1   48738520.0  48524188.0  48525131.0       6.0       7.0  45006375.0
# 2     270207.0    203681.0    244006.0      15.0      10.0     27147.0
# 3   59069229.0  59069229.0  59004989.0      23.0      10.0  58685690.0
# 4   55595001.0  55424950.0  55464526.0      32.0      23.0  23772662.0
# 5   70879295.0  55916114.0  70739980.0      13.0      10.0  45018141.0
# 6    1314540.0   1314535.0   1183635.0       7.0      17.0    132666.0
# 7   16859667.0  16834434.0  16834136.0       8.0      11.0  15188495.0
# 8   59999177.0  59999144.0  59999127.0       4.0       9.0  20661527.0
# 9    6613711.0   6548606.0   6588175.0      11.0      11.0   6146080.0
# 10  55831711.0  55766885.0  55806151.0       2.0      12.0  16115344.0
# 11  46524546.0  46325039.0  46323261.0       2.0      17.0  45024030.0
# 12   6496273.0   6431093.0   6470928.0      28.0      18.0   5323248.0
# 13  59898537.0  59657471.0  59714032.0       3.0       0.0   3516152.0
# 14  59953499.0  59953499.0  59785930.0       3.0       0.0   7010702.0
# 15  59641091.0  59641091.0  59576916.0      22.0      14.0  58246240.0
# 16  59927836.0  59880370.0  59927262.0       3.0       0.0   5376010.0
# 17   6881637.0   6856085.0   6856099.0       6.0      13.0   1358719.0
# 18  53546642.0  53417270.0  53412414.0      46.0      22.0  10156934.0
# 19   1301313.0   1123688.0   1095209.0      57.0      29.0    433543.0
# 20  59696147.0  59388599.0  59623729.0       3.0       0.0   7349706.0
#
#       max_biat      mean_fiat      mean_biat  flowPktsPerSecond  ...  \
# 0      86113.0     601.077345     370.009450        4315.726934  ...
# 1   45220727.0   19495.455203   14664.590813         119.002383  ...
# 2      66572.0     593.822157     363.104167        3763.781101  ...
# 3   58644456.0  191162.553398   86138.670073          16.861571  ...
# 4   23731260.0  170015.184049   88038.930159          17.231765  ...
# 5   45157574.0  122354.735230  123455.462478          14.559964  ...
# 6     131525.0    4095.124611    2320.852941         633.681744  ...
# 7   15255781.0   66017.388235   30831.750916          47.628461  ...
# 8   20661725.0  178039.002967  101349.876689          15.516880  ...
# 9    6106525.0   34107.322917   17429.034392          86.486996  ...
# 10  16052021.0  189683.282313  139865.040100          12.448123  ...
# 11  45262593.0  477577.721649  264704.348571           5.889364  ...
# 12    820398.0  18966.174880   5632.252085         230.209179  ...
# 13  26433361.0  15751.537869   9809.073522         165.403854  ...
# 14  45022250.0  23429.933775  21583.087283          89.013316  ...
# 15    276417.0    823.900290    451.855383        3406.768033  ...
# 16   3399087.0  11586.011263   2680.770880         458.898931  ...
# 17    274048.0   4027.665738   1091.928734        1160.798216  ...
# 18   6734903.0  26697.774876  18345.316475          91.844681  ...
# 19     50970.0    722.404912    298.027297        4660.894383  ...
# 20    112797.0    497.058357    261.200674        5734.424671  ...
#
#     mean_flowiat    std_flowiat   min_active  mean_active   max_active  \
# 0     336.191615    9850.495335    1753114.0   11300000.0   39438693.0
# 1     560.763283    7590.960502         -1.0          0.0         -1.0
# 2    1657.832018  345078.175888  143704195.0  144000000.0  143704195.0
# 3    1802.511882   16392.609675         -1.0          0.0         -1.0
# 4    1985.289088   18541.554847         -1.0          0.0         -1.0
# 5    1955.499524   15721.579232         -1.0          0.0         -1.0
# 6    2321.710957   27458.196383    2210292.0    8537785.5   14865279.0
# 7    2271.231146   18705.720735         -1.0          0.0         -1.0
# 8    3816.604699   63608.655919    3440026.0    5681338.0    7922650.0
# 9    3921.037979   35330.204420         -1.0          0.0         -1.0
# 10   4233.203274   39452.537123         -1.0          0.0         -1.0
# 11   4462.138751   37942.051532         -1.0          0.0         -1.0
# 12   4344.215960   38123.462437         -1.0          0.0         -1.0
# 13   6046.425074  268968.567017    2548643.0   11800000.0   29153302.0
# 14  11237.017582  703203.490676   45992960.0   46000000.0   45992960.0
# 15    293.563595    4089.822648         -1.0          0.0         -1.0
# 16   2179.458838   43961.755182   14129077.0   14100000.0   14129077.0
# 17    861.604499    6416.809427         -1.0          0.0         -1.0
# 18  10889.946373  101103.418064    2650978.0   14700000.0   29243722.0
# 19    214.595489    1762.201003         -1.0          0.0         -1.0
# 20    174.420080    2022.359043         -1.0          0.0         -1.0
#
#       std_active     min_idle     mean_idle     max_idle      std_idle
# 0   1.600000e+07    1014624.0  1.139538e+06    1208289.0  7.499739e+04
# 1   0.000000e+00         -1.0  0.000000e+00         -1.0  0.000000e+00
# 2   0.000000e+00  101572528.0  1.020000e+08  101572528.0  0.000000e+00
# 3   0.000000e+00         -1.0  0.000000e+00         -1.0  0.000000e+00
# 4   0.000000e+00         -1.0  0.000000e+00         -1.0  0.000000e+00
# 5   0.000000e+00         -1.0  0.000000e+00         -1.0  0.000000e+00
# 6   8.948427e+06    1799762.0  2.347216e+06    2894671.0  7.742176e+05
# 7   0.000000e+00         -1.0  0.000000e+00         -1.0  0.000000e+00
# 8   3.169694e+06    1015521.0  4.077856e+06    7140191.0  4.330796e+06
# 9   0.000000e+00         -1.0  0.000000e+00         -1.0  0.000000e+00
# 10  0.000000e+00         -1.0  0.000000e+00         -1.0  0.000000e+00
# 11  0.000000e+00         -1.0  0.000000e+00         -1.0  0.000000e+00
# 12  0.000000e+00         -1.0  0.000000e+00         -1.0  0.000000e+00
# 13  1.260000e+07    1044783.0  6.858037e+06   26261644.0  1.090000e+07
# 14  0.000000e+00   44999613.0  4.500000e+07   44999613.0  0.000000e+00
# 15  0.000000e+00         -1.0  0.000000e+00         -1.0  0.000000e+00
# 16  0.000000e+00    3374489.0  3.374489e+06    3374489.0  0.000000e+00
# 17  0.000000e+00         -1.0  0.000000e+00         -1.0  0.000000e+00
# 18  1.390000e+07    1125937.0  2.806189e+06    6603093.0  2.550868e+06
# 19  0.000000e+00         -1.0  0.000000e+00         -1.0  0.000000e+00
# 20  0.000000e+00         -1.0  0.000000e+00         -1.0  0.000000e+00
#
# [21 rows x 23 columns]

# %% [markdown]
# ##### - Kiểm tra lại mức độ chặt chẽ:

# %%
plt.figure(figsize = (18, 12))

vpn_corr = vpn60s.corr()
novpn_corr = novpn60s.corr()

# Thiết lập kích thước của biểu đồ
plt.figure(figsize=(30, 10))

# So sánh ma trận tương quan
corr_comparison = pd.concat([vpn_corr, novpn_corr], axis=1, keys=['VPN', 'No-VPN'])
sns.heatmap(corr_comparison, annot=True, fmt=".2f", annot_kws={'size': 8})
plt.show()

# %%
vpn60s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6935 entries, 0 to 6934
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   duration            6935 non-null   float64
#  1   total_fiat          6935 non-null   float64
#  2   total_biat          6935 non-null   float64
#  3   min_fiat            6935 non-null   float64
#  4   min_biat            6935 non-null   float64
#  5   max_fiat            6935 non-null   float64
#  6   max_biat            6935 non-null   float64
#  7   mean_fiat           6935 non-null   float64
#  8   mean_biat           6935 non-null   float64
#  9   flowPktsPerSecond   6935 non-null   float64
#  10  flowBytesPerSecond  6935 non-null   float64
#  11  min_flowiat         6935 non-null   float64
#  12  max_flowiat         6935 non-null   float64
#  13  mean_flowiat        6935 non-null   float64
#  14  std_flowiat         6935 non-null   float64
#  15  min_active          6935 non-null   float64
#  16  mean_active         6935 non-null   float64
#  17  max_active          6935 non-null   float64
#  18  std_active          6935 non-null   float64
#  19  min_idle            6935 non-null   float64
#  20  mean_idle           6935 non-null   float64
#  21  max_idle            6935 non-null   float64
#  22  std_idle            6935 non-null   float64
# dtypes: float64(23)
# memory usage: 1.2 MB

# %%
novpn60s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8580 entries, 0 to 8579
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   duration            8580 non-null   float64
#  1   total_fiat          8580 non-null   float64
#  2   total_biat          8580 non-null   float64
#  3   min_fiat            8580 non-null   float64
#  4   min_biat            8580 non-null   float64
#  5   max_fiat            8580 non-null   float64
#  6   max_biat            8580 non-null   float64
#  7   mean_fiat           8580 non-null   float64
#  8   mean_biat           8580 non-null   float64
#  9   flowPktsPerSecond   8580 non-null   float64
#  10  flowBytesPerSecond  8580 non-null   float64
#  11  min_flowiat         8580 non-null   float64
#  12  max_flowiat         8580 non-null   float64
#  13  mean_flowiat        8580 non-null   float64
#  14  std_flowiat         8580 non-null   float64
#  15  min_active          8580 non-null   float64
#  16  mean_active         8580 non-null   float64
#  17  max_active          8580 non-null   float64
#  18  std_active          8580 non-null   float64
#  19  min_idle            8580 non-null   float64
#  20  mean_idle           8580 non-null   float64
#  21  max_idle            8580 non-null   float64
#  22  std_idle            8580 non-null   float64
# dtypes: float64(23)
# memory usage: 1.5 MB

# %% [markdown]
# - Chuyển lại dataset đã được làm sạch về dạng csv để chuẩn bị cho việc train model

# %%
vpn60s.to_csv('./clean_data/vpn60s_cleaned.csv', index=False)
novpn60s.to_csv('./clean_data/novpn60s_cleaned.csv', index=False)

# %% [markdown]
# ## Phrase 3: Huấn luyện Model

# %% [markdown]
# #### Ở đây, với 2 dataset đã được xử lý, mình sẽ thử train thuật toán K-Nearest Neighbors và Decision Tree để xác định model nào hiệu quả hơn trong việc phân loại

# %% [markdown]
# ##### K-Nearest Neighbors:

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

#read data
yes_df = pd.read_csv('clean_data/vpn60s_cleaned.csv')
no_df = pd.read_csv('clean_data/novpn60s_cleaned.csv')


# Create labels for dataset
yes_df['label'] = 1  
no_df['label'] = 0   

#combine 2 dataset
combined_df = pd.concat([yes_df, no_df], ignore_index=True)

# separate features and specify target variable
X = combined_df.drop(columns=['label'])
y = combined_df['label']

#split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#specifying the category and numerical columns
cate_cols=[cname for cname in X_train.columns if X_train[cname].dtype=="object"]
nume_cols=[cname for cname in X_train.columns if X_train[cname].dtype in ['int64','float64']]

# preprocessing to deal with different type of datas
# Preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy='constant')

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, nume_cols),
        ('cat', categorical_transformer, cate_cols)
    ])


# train the model
knn = Pipeline(steps=[('preprocessor', preprocessor),
                    ('model', KNeighborsClassifier(n_neighbors=5))
                             ])
knn.fit(X_train, y_train)

# predicting some value
y_pred = knn.predict(X_test)

# evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# print the report
print(classification_report(y_test, y_pred))

# view some first prediction
print("First few predictions:", y_pred[:5])
print("First few actual values:", y_test[:5].values)

# Generate matrix
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No VPN', 'VPN'], yticklabels=['No VPN', 'VPN'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy: 0.79
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81      2569
#            1       0.77      0.77      0.77      2086
#
#     accuracy                           0.79      4655
#    macro avg       0.79      0.79      0.79      4655
# weighted avg       0.79      0.79      0.79      4655
#
# First few predictions: [0 1 0 1 0]
# First few actual values: [0 1 0 1 0]

# %% [markdown]
# ##### Decision Tree

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

#read data
yes_df = pd.read_csv('clean_data/vpn60s_cleaned.csv')
no_df = pd.read_csv('clean_data/novpn60s_cleaned.csv')


# Create labels for dataset
yes_df['label'] = 1  
no_df['label'] = 0   

#combine 2 dataset
combined_df = pd.concat([yes_df, no_df], ignore_index=True)

# separate features and specify target variable
X = combined_df.drop(columns=['label'])
y = combined_df['label']

#split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#specifying the category and numerical columns
cate_cols=[cname for cname in X_train.columns if X_train[cname].dtype=="object"]
nume_cols=[cname for cname in X_train.columns if X_train[cname].dtype in ['int64','float64']]

# preprocessing to deal with different type of datas
# Preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy='constant')

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, nume_cols),
        ('cat', categorical_transformer, cate_cols)
    ])


# train the model
knn = Pipeline(steps=[('preprocessor', preprocessor),
                    ('model', DecisionTreeClassifier(max_leaf_nodes=1000))
                             ])
knn.fit(X_train, y_train)

# predicting some value
y_pred = knn.predict(X_test)

# evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# print the report
print(classification_report(y_test, y_pred))

# view some first prediction
print("First few predictions:", y_pred[:5])
print("First few actual values:", y_test[:5].values)

# Generate matrix
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No VPN', 'VPN'], yticklabels=['No VPN', 'VPN'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy: 0.85
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.87      2569
#            1       0.85      0.82      0.83      2086
#
#     accuracy                           0.85      4655
#    macro avg       0.85      0.85      0.85      4655
# weighted avg       0.85      0.85      0.85      4655
#
# First few predictions: [0 0 0 1 0]
# First few actual values: [0 1 0 1 0]

# %% [markdown]
# ##### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegressionCV
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

#read data
yes_df = pd.read_csv('clean_data/vpn60s_cleaned.csv')
no_df = pd.read_csv('clean_data/novpn60s_cleaned.csv')


# Create labels for dataset
yes_df['label'] = 1  
no_df['label'] = 0   

#combine 2 dataset
combined_df = pd.concat([yes_df, no_df], ignore_index=True)

# separate features and specify target variable
X = combined_df.drop(columns=['label'])
y = combined_df['label']

#split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#specifying the category and numerical columns
cate_cols=[cname for cname in X_train.columns if X_train[cname].dtype=="object"]
nume_cols=[cname for cname in X_train.columns if X_train[cname].dtype in ['int64','float64']]

# preprocessing to deal with different type of datas
# Preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy='constant')

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, nume_cols),
        ('cat', categorical_transformer, cate_cols)
    ])
cpu_cores=8
lr=Pipeline(steps=[('preprocessor', preprocessor),
                    ('model', LogisticRegressionCV(n_jobs=cpu_cores,solver='liblinear'))
                             ])
lr.fit(X_train,y_train)

# predicting some value
y_pred = lr.predict(X_test)

# evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# print the report
print(classification_report(y_test, y_pred))

# view some first prediction
print("First few predictions:", y_pred[:5])
print("First few actual values:", y_test[:5].values)

# Generate matrix
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No VPN', 'VPN'], yticklabels=['No VPN', 'VPN'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy: 0.62
#               precision    recall  f1-score   support
#
#            0       0.69      0.56      0.62      2569
#            1       0.56      0.69      0.62      2086
#
#     accuracy                           0.62      4655
#    macro avg       0.63      0.63      0.62      4655
# weighted avg       0.63      0.62      0.62      4655
#
# First few predictions: [1 0 1 0 1]
# First few actual values: [0 1 0 1 0]

# %% [markdown]
# ##### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

#read data
yes_df = pd.read_csv('clean_data/vpn60s_cleaned.csv')
no_df = pd.read_csv('clean_data/novpn60s_cleaned.csv')


# Create labels for dataset
yes_df['label'] = 1  
no_df['label'] = 0   

#combine 2 dataset
combined_df = pd.concat([yes_df, no_df], ignore_index=True)

# separate features and specify target variable
X = combined_df.drop(columns=['label'])
y = combined_df['label']

#split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#specifying the category and numerical columns
cate_cols=[cname for cname in X_train.columns if X_train[cname].dtype=="object"]
nume_cols=[cname for cname in X_train.columns if X_train[cname].dtype in ['int64','float64']]

# preprocessing to deal with different type of datas
# Preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy='constant')

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, nume_cols),
        ('cat', categorical_transformer, cate_cols)
    ])
cpu_cores=8
# Train the model based on best optimized args
rf=Pipeline(steps=[('preprocessor', preprocessor),
                    ('model', RandomForestClassifier(n_jobs=cpu_cores,n_estimators=7000))
                             ])
rf.fit(X_train,y_train)

# predicting some value
y_pred = rf.predict(X_test)

# evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# print the report
print(classification_report(y_test, y_pred))

# view some first prediction
print("First few predictions:", y_pred[:5])
print("First few actual values:", y_test[:5].values)

# Generate matrix
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No VPN', 'VPN'], yticklabels=['No VPN', 'VPN'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy: 0.89
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90      2569
#            1       0.90      0.85      0.87      2086
#
#     accuracy                           0.89      4655
#    macro avg       0.89      0.88      0.89      4655
# weighted avg       0.89      0.89      0.89      4655
#
# First few predictions: [0 0 0 0 0]
# First few actual values: [0 1 0 1 0]

# %% [markdown]
# ### Kết luận:
#
# - KNN: Mô hình này có độ chính xác khá cao (0.79) và sự cân bằng giữa precision và recall cho cả hai lớp, cho thấy khả năng phân loại tốt. Tuy nhiên, KNN có thể không phải là lựa chọn tối ưu nếu kích thước dữ liệu lớn do độ phức tạp tính toán cao và thời gian dự đoán chậm.
# - Decision Tree: Với độ chính xác 0.85, mô hình này cho thấy khả năng phân biệt tốt giữa VPN và No VPN. Cây quyết định cũng dễ diễn giải và triển khai, nhưng có thể dễ bị overfitting nếu không được cắt tỉa đúng cách.
# - Logistic Regression: Mặc dù có độ chính xác thấp nhất (0.62), logistic regression là mô hình đơn giản và nhanh chóng trong việc huấn luyện và dự đoán. Tuy nhiên, kết quả cho thấy mô hình này có xu hướng dự đoán ‘VPN’ nhiều hơn, có thể không phù hợp cho việc điều chỉnh băng thông mạng một cách chính xác.
# - Random Forest: Đây là mô hình có hiệu suất cao nhất với độ chính xác 0.89 và sự cân bằng giữa precision và recall. Random Forest là sự kết hợp của nhiều cây quyết định, giúp giảm thiểu nguy cơ overfitting và tăng cường độ tin cậy của dự đoán.
#
# ##### -> Kết luận: Random Forest là mô hình phù hợp nhất cho mục tiêu của nhóm (phân loại VPN/No-VPN để điều chỉnh băng thông mạng) với hiệu suất cao và khả năng phân loại chính xác nhất.
